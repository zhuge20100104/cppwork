# %%
# %%sh
#
#
# PGPASSWORD='2mHdFW6%#REu' psql -h 10.2.25.198  -U app_bdp_usage_qa -d dna -p 6432 << EOF
# set search_path=public;
#
# -- universal_id : company id
# -- parent_id : parent id
# -- select * from dna_universal_company_parent where universal_id = 1000200000003635 limit 5
# -- select * from ( select universal_id, count(universal_id) from dna_universal_company_parent where start_date is not null and end_date is not null group by universal_id ) as prod limit 5
#
# select * from dna_universal_company_parent where start_date < '2012-01-01' limit 1;
#
#
# -- universal_id : company id
# -- company id : publisher id
# -- select * from dna_universal_company_mapping where company_id=542280115   limit 2;
#
# select * from dna_universal_company_parent where universal_id=1000200000000122   limit 2;
# select * from dna_universal_company_mapping where universal_id = 1000200000000122 limit 3
#
# EOF

# %%
# %%sh
# PGPASSWORD='wZw8cfBuuklIskVG' psql -h 10.2.6.141  -U citus_bdp_prod_app_int_qa -d aa_store_db -p 5432 << EOF
# set search_path=store;
#
# -- daily
# select * from store_est_fact_v2 where date between '2019-08-01' and '2019-08-01' and app_id In (284882215) and country_code='US' order by date desc limit 1 ;
# select * from store_est_category_fact_v1 where date between '2019-08-01' and '2019-08-01' and app_id In (284882215) and country_code='US' order by date desc limit 1 ;
#
# -- pre-agg w/m/q/y
# select * from store_est_t_w_fact_v2 where  app_id In (284882215) and country_code='WW' and device_code='ios-phone' limit 1 ;
# select * from store_est_category_t_w_fact_v1 where  app_id In (284882215) and country_code='WW' and device_code='ios-phone' limit 1 ;
#
#
#
#
# EOF

# %%
# %%sh
# select * from store_est_t_m_fact_v2 where  app_id In (284882215) and country_code='WW' and device_code='ios-phone' limit 1 ;
# select * from store_est_category_t_m_fact_v1 where  app_id In (284882215) and country_code='WW' and device_code='ios-phone' limit 1 ;
#
#
# select * from store_est_t_q_fact_v2 where  app_id In (284882215) and country_code='WW' and device_code='ios-phone' limit 1 ;
# select * from store_est_category_t_q_fact_v1 where  app_id In (284882215) and country_code='WW' and device_code='ios-phone' limit 1 ;
#
#
# select * from store_est_t_y_fact_v2 where  app_id In (284882215) and country_code='WW' and device_code='ios-phone' limit 1 ;
# select * from store_est_category_t_y_fact_v1 where  app_id In (284882215) and country_code='WW' and device_code='ios-phone' limit 1 ;

# %%
# %%sh
# pip install aws_requests_auth

# %%
# %python
import requests
import json
import time
import requests
from aws_requests_auth.boto_utils import BotoAWSRequestsAuth


auth_prod = BotoAWSRequestsAuth(
    aws_host='6tx93muepa.execute-api.us-east-1.amazonaws.com', aws_region='us-east-1', aws_service='execute-api'
)

url = "https://6tx93muepa.execute-api.us-east-1.amazonaws.com/prod/ingest/bounded/qa"
headers = {"Content-Type": "application/json"}
json_data = {
  "namespace": "aa.qa.app-est-qa-pre-agg.v1",
  "job_type": "routine",
  "options": {
    "start_date": "2017-11-01",
    "end_date" : "2018-03-31",
    "granularity": "daily",
    "qa_granularity": "monthly"
  },
  "source" : []
  
}
print json_data
response = requests.post(url, data=json.dumps(json_data), headers=headers, auth=auth_prod)
print response.text

# %%
# %python
