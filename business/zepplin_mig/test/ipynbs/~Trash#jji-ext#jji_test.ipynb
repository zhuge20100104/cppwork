# %%
# %%sh
# aws s3 ls s3://b2c-prod-data-pipeline-unified-usage/unified/usage.basic-kpi.v1/fact/granularity=weekly/date=2019-10-05/

# %%
# %%sh
# aws s3 ls s3://aardvark-prod-pdx-mdm-to-int/basic_kpi/version=v3.0.0/range_type=WEEK/
# aws s3 ls s3://aardvark-prod-pdx-mdm-to-int/basic_kpi/version=v3.0.0/range_type=WEEK/date=2019-10-05/platform=1/
# aws s3 ls s3://aardvark-prod-pdx-mdm-to-int/basic_kpi/version=v3.0.0/range_type=WEEK/date=2019-10-05/platform=2/

# %%
unified_path = 's3://b2c-prod-data-pipeline-unified-usage/unified/usage.basic-kpi.v1/fact/granularity=weekly/date=2019-10-05/'
df_unified = spark.read.parquet(unified_path)
print df_unified.schema
