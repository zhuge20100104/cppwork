# %%
# %%sh
# aws s3 ls s3://b2c-prod-data-pipeline-unified-store-paid/unified/store.app-est.v3/fact/granularity=daily/ --recursive | sort -n

# %%
df_routine = spark.read.option("delta").load("s3://b2c-prod-data-pipeline-unified-store-paid/unified/store.app-est.v3/fact/").where("granularity='daily' and date='2020-03-05' and data_stage='final' and device_code='ios-phone'")
df_routine = spark.read.option("delta").load("s3://b2c-prod-data-pipeline-unified-store-paid/unified/store.app-est.v3/fact/").where("granularity='daily' and date='2020-03-05' and data_stage='final' and device_code='ios-phone'")
