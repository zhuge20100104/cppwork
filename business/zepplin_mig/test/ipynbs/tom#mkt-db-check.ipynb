# %%
# %%sh
# # DIMENSION
# # SELECT update_date,count(*) FROM market.market_creative_map_dimension_v1 WHERE update_date between '2019-04-01' AND '2019-10-15' GROUP BY update_date ORDER BY update_date DESC ;
# # SELECT update_date,count(*) FROM market.market_campaign_map_dimension_v1 WHERE update_date between '2019-04-01' AND '2019-10-15' GROUP BY update_date ORDER BY update_date DESC ;
# # SELECT update_date,count(*) FROM market.market_creative_meta_dimension_v1 WHERE update_date between '2010-01-01' AND '2019-10-15' GROUP BY update_date ORDER BY update_date DESC ;
#
# # LOG
# # SELECT date,count(distinct(ad_platform_id)) FROM market.market_creative_log_fact_v1 WHERE date between '2019-01-01' AND '2019-10-15' GROUP BY date;
# # SELECT date,count(distinct(country_code)) FROM market.market_creative_log_fact_v1 WHERE date between '2019-01-01' AND '2019-10-15' GROUP BY date;
# # SELECT date,count(distinct(device_code)) FROM market.market_creative_log_fact_v1 WHERE date between '2019-01-01' AND '2019-10-15' GROUP BY date;

# %%
# %%sh
# PGPASSWORD='rn*Wh%osCl2C' psql -h internal-aa-citus-mkt-elb-1511434527.us-east-1.elb.amazonaws.com  -U citus_mkt_qa -d aa_mkt_db -p 7432 << EOF
#
# # select count(*) from market.market_creative_adapp_fact_v1 where date='2019-10-12' AND ad_platform_id=324;
# # select count(*) from market.market_adapp_pubapp_fact_v1 where date='2019-10-12' AND ad_platform_id=324;
# # select count(*) from market.market_adapp_fact_v1 where date='2019-10-12' AND ad_platform_id=324;
# # select count(*) from market.market_adapp_publisher_fact_v1 where date='2019-10-12' AND ad_platform_id=324;
# # select count(*) from market.market_pubapp_fact_v1 where date='2019-10-12' AND ad_platform_id=324;
#
# # select count(*) from market.market_creative_adapp_seen_fact_v1 where first_seen_date='2019-10-12' AND ad_platform_id=324;
# # select count(*) from market.market_adapp_pubapp_seen_fact_v1 where first_seen_date='2019-10-12' AND ad_platform_id=324;
# # select count(*) from market.market_adapp_pubapp_seen_fact_v1 where first_seen_date='2019-10-05' AND ad_platform_id=324;
# # select count(*) from market.market_adapp_pubapp_seen_fact_v1 where first_seen_date='2019-09-28' AND ad_platform_id=324;
#
# # select * from market.market_adapp_pubapp_seen_fact_v1 where first_seen_date='2019-10-12' AND ad_platform_id=324 limit 5;
# # select * from market.market_adapp_pubapp_seen_fact_v1 where first_seen_date='2019-10-05' AND ad_platform_id=324 limit 5;
# # select * from market.market_adapp_pubapp_seen_fact_v1 where first_seen_date='2019-09-28' AND ad_platform_id=324;
#
# # select count(*) from market.market_adapp_pubapp_seen_fact_v1 where ad_platform_id=324;
# select distinct(country_code) from market.market_adapp_fact_v1 where date = '2019-10-12';
# select distinct(country_code) from market.market_adapp_publisher_fact_v1 where date = '2019-10-12';.
# select distinct(country_code) from market.market_pubapp_fact_v1 where date = '2019-10-12';
# select distinct(country_code) from market.market_adapp_pubapp_fact_v1 where date = '2019-10-12';
# select distinct(country_code) from market.market_creative_adapp_fact_v1 where date = '2019-10-12';
#
# EOF

# %%
# %%sh
# PGPASSWORD='rn*Wh%osCl2C' psql -h internal-aa-citus-mkt-elb-1511434527.us-east-1.elb.amazonaws.com  -U citus_mkt_qa -d aa_mkt_db -p 7432 << EOF
#
# SELECT last_seen_date,count(distinct(device_code)) FROM market.market_creative_adapp_seen_fact_v1 WHERE last_seen_date between '2019-04-01' AND '2019-10-15' GROUP BY last_seen_date ORDER BY last_seen_date DESC ;
# SELECT last_seen_date,count(distinct(country_code)) FROM market.market_creative_adapp_seen_fact_v1 WHERE last_seen_date between '2019-04-01' AND '2019-10-15' GROUP BY last_seen_date ORDER BY last_seen_date DESC ;
# SELECT last_seen_date,count(distinct(ad_platform_id)) FROM market.market_creative_adapp_seen_fact_v1 WHERE last_seen_date between '2019-04-01' AND '2019-10-15' GROUP BY last_seen_date ORDER BY last_seen_date DESC ;
#
#
#
# SELECT first_seen_date,count(distinct(device_code)) FROM market.market_creative_adapp_seen_fact_v1 WHERE first_seen_date between '2019-04-01' AND '2019-10-15' GROUP BY first_seen_date ORDER BY first_seen_date DESC ;
# SELECT first_seen_date,count(distinct(country_code)) FROM market.market_creative_adapp_seen_fact_v1 WHERE first_seen_date between '2019-04-01' AND '2019-10-15' GROUP BY first_seen_date ORDER BY first_seen_date DESC ;
# SELECT first_seen_date,count(distinct(ad_platform_id)) FROM market.market_creative_adapp_seen_fact_v1 WHERE first_seen_date between '2019-04-01' AND '2019-10-15' GROUP BY first_seen_date ORDER BY first_seen_date DESC ;
#
#
# EOF

# %%
# %%sh
# PGPASSWORD='rn*Wh%osCl2C' psql -h internal-aa-citus-mkt-elb-1511434527.us-east-1.elb.amazonaws.com  -U citus_mkt_qa -d aa_mkt_db -p 7432 << EOF
#
#
# select distinct(ad_platform_id) FROM market.market_creative_log_fact_v1 where date= '2019-09-09';
# select distinct(ad_platform_id) FROM market.market_creative_log_fact_v1 where date= '2019-09-10';
# select max(date) FROM market.market_creative_log_fact_v1 where ad_platform_id = 114 AND date between '2019-01-01' AND '2019-05-20';
#
# // SELECT date,count(distinct(ad_platform_id)) FROM market.market_creative_log_fact_v1 WHERE date between '2019-09-01' AND '2019-10-22' GROUP BY date;
# // SELECT date,count(distinct(country_code)) FROM market.market_creative_log_fact_v1 WHERE date between '2019-10-01' AND '2019-10-22' GROUP BY date;
# // SELECT date,count(distinct(device_code)) FROM market.market_creative_log_fact_v1 WHERE date between '2019-10-01' AND '2019-10-22' GROUP BY date;
#
#
# EOF

# %%
# %%sh
# PGPASSWORD='rn*Wh%osCl2C' psql -h internal-aa-citus-mkt-elb-1511434527.us-east-1.elb.amazonaws.com  -U citus_mkt_qa -d aa_mkt_db -p 7432 << EOF
#
# WITH log AS (
# 	select
# 		creative_id, pub_app_id, ad_app_id
# 	from
# 		market.market_creative_log_fact_v1
# 	where
# 		device_code = 'ios-phone'
# 		AND country_code = 'US'
# 		AND ad_platform_id = 101
# 		AND date = '2018-08-25'
# 		AND pub_app_id = 1076070950
# 		AND ad_app_id in
# 			(
# 				select ad_app_id
# 				from market.market_adapp_cat_rank_fact_v1
# 				where
# 				    granularity = 'weekly'
# 					AND device_code = 'ios-phone'
# 					AND country_code = 'US'
# 					AND category_id = 100001
# 					AND date = '2018-08-25'
# 			)
# )
# SELECT
# 	app.ad_app_id, app.creative_id, ad_platform_count, ad_platform_list, pub_app_count, pub_app_list, country_count, country_list, creative_share_of_ad_platform, creative_share_of_advertiser,
# 	ad_type_id, creative_type_id, extension, height, width, size_bytes, first_seen_date, last_seen_date, active_days
# from
# (
# 	select * from
# 		market.market_creative_adapp_seen_fact_v1
# 	where
# 		device_code = 'ios-phone' and
# 		country_code = 'US' and
# 		ad_platform_id = 101 and
# 		ad_app_id in (select ad_app_id from log) and
# 		creative_id in (select creative_id from log)
# ) vis
# join
# (
# 	select * from market.market_creative_meta_dimension_v1
# 	where creative_id in (select creative_id from log)
# ) meta
# on meta.creative_id = vis.creative_id
# join (
# 	select *
# 	from
# 		market.market_creative_adapp_fact_v1
# 	where
# 		granularity = 'weekly' and
# 		device_code = 'ios-phone' and
# 		country_code = 'US' and
# 		ad_platform_id = 101 and
# 	    date = '2018-08-25' and
# 		ad_app_id in (select ad_app_id from log) and
# 		creative_id in (select creative_id from log)
# ) as app on vis.creative_id = app.creative_id and vis.ad_app_id = app.ad_app_id
# order by date, app.creative_share_of_ad_platform
# limit 1000
#
#
# EOF

# %%
# Copyright (c) 2018 App Annie Inc. All rights reserved.

"""
DB Check modules
"""
from aaintdatapipeline.application.app_qa.common.db_check_utils import _get_date_from_refresh_routing_config, query, \
    send_report
from aaintdatapipeline.core.urn import Urn
from aaintdatapipeline.application.app_qa.conf.settings import CITUS_MKT_NAME, CITUS_MKT_ACCESS_ID, \
    CITUS_MKT_HOSTS, CITUS_MKT_SECRET_KEY, CITUS_MKT_HOSTS


SUPPORTED_AD_PLATFORM_ID = sorted([1, 203, 324, 101, 136, 201, 202, 171, 109, 110, 111, 112, 200, 114, 116, 142, 311, 121, 316, 325])
SUPPORTED_DEVICE_CODE = sorted(["ios-phone", "ios-tablet", "android-phone", "android-tablet"])
SUPPORTED_COUNTRY_CODE = sorted(['AU', 'BR', 'CA', 'CN', 'DE', 'DK', 'ES', 'FI', 'FR', 'GB', 'HK', 'ID', 'IN', 'IT', 'JP', 'KR', 'MX', 'NO', 'NZ', 'RU', 'SE', 'TH', 'TR', 'TW', 'US', 'WW'])

SUPPORTED_DIMENSIONS = {
    "ad_platform_id": SUPPORTED_AD_PLATFORM_ID,
    "device_code": SUPPORTED_DEVICE_CODE,
    "country_code": SUPPORTED_COUNTRY_CODE
}

citus_dsn = (
    "dbname='{db}' user='{user}' password='{password}' "
    "host='{host}' port='{port}'".format(
        db=CITUS_MKT_NAME,
        user=CITUS_MKT_ACCESS_ID,
        host=CITUS_MKT_HOSTS[0][0],
        password=CITUS_MKT_SECRET_KEY,
        port=CITUS_MKT_HOSTS[0][1]
    )
)


urn = Urn(
    namespace='app-qa.db-check.v1',
    owner='app_qa'
)


def check_market(params):
    project_name = params['project_name']
    if project_name == 'All_Products':
        # daily check
        granularity = "daily"
        refresh_config = ("0 9 * * *", 1)
        check_date = _get_date_from_refresh_routing_config(refresh_config)
        check_date = "2019-10-01"
        market_daily_check(check_date, granularity)

        # # weekly check
        # granularity = "weekly"
        # refresh_config = ("0 10 * * 0", 7)
        # check_date = _get_date_from_refresh_routing_config(refresh_config)
        # market_weekly_check(check_date, granularity)

        # # monthly check
        # granularity = "monthly"
        # refresh_config = ("0 10 6 * * ", 6)
        # check_date = _get_date_from_refresh_routing_config(refresh_config)
        # market_weekly_check(check_date, granularity)


def market_daily_check(date, granularity):
    granularity = 'daily'
    market_creative_map_dimension_v1_test(date=date, granularity=granularity)
    # market_campaign_map_dimension_v1_test(date=date, granularity=granularity)
    # market_creative_meta_dimension_v1_test(date=date, granularity=granularity)
    # market_creative_log_fact_v1_test(date=date, granularity=granularity)


def market_weekly_check(date, granularity):
    granularity = 'weekly'
    market_metric_facts_v1_test(date=date, granularity=granularity)
    market_rank_facts_v1_test(date=date, granularity=granularity)
    market_seen_facts_v1_test(date=date, granularity=granularity)


def market_monthly_check(date, granularity):
    granularity = 'monthly'
    market_metric_facts_v1_test(date=date, granularity=granularity)
    market_rank_facts_v1_test(date=date, granularity=granularity)
    market_seen_facts_v1_test(date=date, granularity=granularity)


@send_report(source="market_creative_map_dimension_v1")
def market_creative_map_dimension_v1_test(date, granularity):
    sql = "SELECT COUNT(*) FROM market.market_creative_map_dimension_v1 WHERE update_date='{date}'".format(date=date)
    result = query(citus_dsn, sql)
    print result
    count = result[0][0]
    assert count > 0
    assert count > 1000  # TODO need to determine what is the better check for this


@send_report(source="market_campaign_map_dimension_v1")
def market_campaign_map_dimension_v1_test(date, granularity):
    sql = "SELECT COUNT(*) FROM market.market_campaign_map_dimension_v1 WHERE update_date='{date}'".format(date=date)
    result = query(citus_dsn, sql)
    count = result[0][0]
    print result
    assert count > 0
    assert count > 1000  # TODO need to determine what is the better check for this


@send_report(source="market_creative_meta_dimension_v1")
def market_creative_meta_dimension_v1_test(date, granularity):
    sql = "SELECT COUNT(*) FROM market.market_creative_meta_dimension_v1 WHERE update_date='{date}'".format(date=date)
    result = query(citus_dsn, sql)
    count = result[0][0]
    print result
    assert count > 0
    assert count > 1000  # TODO need to determine what is the better check for this


@send_report(source="market_creative_log_fact_v1")
def market_creative_log_fact_v1_test(date, granularity):
    table = "market_creative_log_fact_v1"
    filter = {"date": date}
    _completeness_check_on_dimension(table, "country_code", filter)
    _completeness_check_on_dimension(table, "device_code", filter)
    _completeness_check_on_dimension(table, "ad_platform_id", filter)


@send_report(source="Market Metric Fact Tables")
def market_metric_facts_v1_test(date, granularity):
    tables = [
        "market_creative_adapp_fact_v1",
        "market_adapp_pubapp_fact_v1",
        "market_adapp_fact_v1",
        "market_adapp_publisher_fact_v1",
        "market_pubapp_fact_v1",
    ]
    filter = {"date": date, "granularity": granularity}
    for table in tables:
        _completeness_check_on_dimension(table, "country_code", filter)
        _completeness_check_on_dimension(table, "device_code", filter)
        _completeness_check_on_dimension(table, "ad_platform_id", filter)


@send_report(source="Market Rank Fact Tables")
def market_rank_facts_v1_test(date, granularity):
    tables = [
        "market_creative_cat_rank_fact_v1",
        "market_adapp_cat_rank_fact_v1",
        "market_pubapp_cat_rank_fact_v1",
    ]
    filter = {"date": date, "granularity": granularity}
    for table in tables:
        _completeness_check_on_dimension(table, "country_code", filter)
        _completeness_check_on_dimension(table, "device_code", filter)
        _completeness_check_on_dimension(table, "ad_platform_id", filter)
        # _completeness_check_on_dimension(table, "category_id", filter)


@send_report(source="Market Seen Fact Tables")
def market_seen_facts_v1_test(date, granularity):
    tables = [
        "market_creative_adapp_seen_fact_v1"
        "market_adapp_pubapp_seen_fact_v1"
    ]
    seens = ["first_seen", "last_seen"]
    for table in tables:
        for seen in seens:
            filter = {seen: date}
            _completeness_check_on_dimension(table, "country_code", filter)
            _completeness_check_on_dimension(table, "device_code", filter)
            _completeness_check_on_dimension(table, "ad_platform_id", filter)


def _completeness_check_on_dimension(table, dimension, filter):
    condition = " AND ".join(["{}='{}'".format(key, value)for key, value in dict.iteritems()]) if filter else "True"
    sql = "SELECT DISTINCT({dimension}) FROM market.{table} WHERE {condition}".format(
        dimension=dimension, table=table, condition=condition)
    result = query(citus_dsn, sql)
    actual_list = sorted([obj[0] for obj in result])
    if actual_list != SUPPORTED_DIMENSIONS[dimension]:
        error_msg = "dimensions miss matched on {} table where {} : expected {} - actual {}".format(
            table, condition,  SUPPORTED_DIMENSIONS[dimension], actual_list)
        raise RuntimeError(error_msg)

# debug for zepplin
check_market({"project_name": "All_Products"})

# %%
from aaintdatapipeline.application.app_qa.db_check_v1.db_check_market_v1 import check_market
from aaintdatapipeline.application.app_qa.conf.settings import CITUS_MKT_NAME, CITUS_MKT_ACCESS_ID, \
    CITUS_MKT_HOSTS, CITUS_MKT_SECRET_KEY, CITUS_MKT_HOSTS, DEFAULT_RECIPIENTS, PAGERDUTY_RECIPIENTS

print DEFAULT_RECIPIENTS
print PAGERDUTY_RECIPIENTS

check_market({"project_name": "All_Products"})

# %%
# %%sh
#
# pwd
#
# # env
#
# ls -al /home/hadoop/bdp/application/aaintdatapipeline/application/app_qa/db_check_v1/
#
# cat /home/hadoop/bdp/application/aaintdatapipeline/application/app_qa/db_check_v1/db_check_market_v1.py

# %%
# Copyright (c) 2018 App Annie Inc. All rights reserved.

"""
DB Check modules
"""
from aaintdatapipeline.application.app_qa.common.db_check_utils import _get_date_from_refresh_routing_config, query, \
    send_report
from aaintdatapipeline.core.urn import Urn
from aaintdatapipeline.application.app_qa.conf.settings import CITUS_MKT_NAME, CITUS_MKT_ACCESS_ID, \
    CITUS_MKT_SECRET_KEY, CITUS_MKT_HOSTS


# TODO ad_platform_id = 316 missed in db, and it is a known issue @ 2019-10-20
AD_PLATFORM_ID_ALL_PLATFORM = [1]
AD_PLATFORM_ID_BASIC = sorted([203, 101, 136, 201, 202, 171, 109, 110, 111, 112, 200, 116, 142, 311, 121, 325])
AD_PLATFORM_ID_CREATIVE_ONLY = [324]

COUNTRY_CODE_BASIC = sorted(["AU", "BR", "CA", "CN", "DE", "DK", "ES", "FI", "FR", "GB", "HK", "ID", "IN", "IT", "JP",
                             "KR", "MX", "NO", "NZ", "RU", "SE", "TH", "TR", "TW", "US"])
COUNTRY_CODE_WW = ["WW"]


SUPPORTED_DEVICE_CODE = sorted(["ios-phone", "ios-tablet", "android-phone", "android-tablet"])

SUPPORTED_DIMENSIONS = {
    "ad_platform_id": sorted(AD_PLATFORM_ID_BASIC + AD_PLATFORM_ID_ALL_PLATFORM + AD_PLATFORM_ID_CREATIVE_ONLY),
    "ad_platform_id_non_creative_only": sorted(AD_PLATFORM_ID_BASIC + AD_PLATFORM_ID_ALL_PLATFORM),
    "ad_platform_id_non_creative_only_non_all_platform": sorted(AD_PLATFORM_ID_BASIC),
    "device_code": sorted(SUPPORTED_DEVICE_CODE),
    "country_code": sorted(COUNTRY_CODE_BASIC + COUNTRY_CODE_WW),
    "country_code_non_ww": sorted(COUNTRY_CODE_BASIC),
}

citus_dsn = (
    "dbname='{db}' user='{user}' password='{password}' "
    "host='{host}' port='{port}'".format(
        db=CITUS_MKT_NAME,
        user=CITUS_MKT_ACCESS_ID,
        host=CITUS_MKT_HOSTS[0][0],
        password=CITUS_MKT_SECRET_KEY,
        port=CITUS_MKT_HOSTS[0][1]
    )
)


urn = Urn(
    namespace="app-qa.db-check.v1",
    owner="app_qa"
)


def check_market(params):
    project_name = params['project_name']
    if project_name == 'All_Products':
        market_daily_check()
        market_weekly_check()
        market_monthly_check()


def market_daily_check():
    granularity = "daily"
    # dimension check, the update_date is the db load date
    refresh_config = ("0 9 * * *", 0)
    check_date = _get_date_from_refresh_routing_config(refresh_config)
    market_dimension_v1_test(date=check_date, granularity=granularity)

    # logs fact and seen check, the date should be 1 days ago
    refresh_config = ("0 9 * * *", 1)
    check_date = _get_date_from_refresh_routing_config(refresh_config)
    market_creative_log_fact_v1_test(date=check_date, granularity=granularity)
    market_seen_facts_v1_test(date=check_date, granularity=granularity)


def market_weekly_check():
    granularity = "weekly"
    refresh_config = ("0 10 * * 0", 8)
    check_date = _get_date_from_refresh_routing_config(refresh_config)

    market_metric_facts_v1_test(date=check_date, granularity=granularity)
    market_rank_facts_v1_test(date=check_date, granularity=granularity)


def market_monthly_check():
    granularity = "monthly"
    refresh_config = ("0 10 6 * * ", 6)
    check_date = _get_date_from_refresh_routing_config(refresh_config)

    market_metric_facts_v1_test(date=check_date, granularity=granularity)
    market_rank_facts_v1_test(date=check_date, granularity=granularity)


@send_report(source="Market Dimensions")
def market_dimension_v1_test(date):
    tables = [
        "market_creative_map_dimension_v1",
        "market_campaign_map_dimension_v1",
        "market_creative_meta_dimension_v1"
    ]
    for table in tables:
        sql = "SELECT COUNT(*) FROM market.{table} WHERE update_date='{date}'".format(date=date, table=table)
        result = query(citus_dsn, sql)
        count = result[0][0]
        assert count > 0


@send_report(source="Market Creative Log Fact")
def market_creative_log_fact_v1_test(date):
    table = "market_creative_log_fact_v1"
    filter = {"date": date}
    _completeness_check_on_dimension(table, "country_code", filter)
    _completeness_check_on_dimension(table, "device_code", filter)
    _completeness_check_on_dimension(table, "ad_platform_id", filter)


@send_report(source="Market Metric Fact")
def market_metric_facts_v1_test(date, granularity):
    tables = [
        "market_creative_adapp_fact_v1",
        "market_adapp_pubapp_fact_v1",
        "market_adapp_fact_v1",
        "market_adapp_publisher_fact_v1",
        "market_pubapp_fact_v1",
    ]
    filter = {"date": date, "granularity": granularity}

    for table in tables:
        if table == "market_adapp_publisher_fact_v1":
            _completeness_check_on_dimension(table, "country_code", filter,
                                             SUPPORTED_DIMENSIONS["country_code_non_ww"])
            _completeness_check_on_dimension(table, "ad_platform_id", filter,
                                             SUPPORTED_DIMENSIONS["ad_platform_id_non_creative_only_non_all_platform"])
        elif "pub" in table:
            _completeness_check_on_dimension(table, "country_code", filter)
            _completeness_check_on_dimension(table, "ad_platform_id", filter,
                                             SUPPORTED_DIMENSIONS["ad_platform_id_non_creative_only"])
        else:
            _completeness_check_on_dimension(table, "ad_platform_id", filter)
            _completeness_check_on_dimension(table, "country_code", filter)
        _completeness_check_on_dimension(table, "device_code", filter)


@send_report(source="Market Rank Fact")
def market_rank_facts_v1_test(date, granularity):
    tables = [
        "market_creative_cat_rank_fact_v1",
        "market_adapp_cat_rank_fact_v1",
        "market_pubapp_cat_rank_fact_v1",
    ]
    filter = {"date": date, "granularity": granularity}
    for table in tables:
        _completeness_check_on_dimension(table, "country_code", filter)
        _completeness_check_on_dimension(table, "device_code", filter)
        # _completeness_check_on_dimension(table, "category_id", filter)


@send_report(source="Market Seen Fact")
def market_seen_facts_v1_test(date):
    tables = [
        "market_creative_adapp_seen_fact_v1",
        "market_adapp_pubapp_seen_fact_v1"
    ]
    seens = ["first_seen_date", "last_seen_date"]
    for table in tables:
        for seen in seens:
            filter = {seen: date}
            _completeness_check_on_dimension(table, "country_code", filter)
            _completeness_check_on_dimension(table, "device_code", filter)
            _completeness_check_on_dimension(table, "ad_platform_id", filter)


def _completeness_check_on_dimension(table, dimension, filter, expected_dimensions=None):
    condition = " AND ".join(["{}='{}'".format(key, value)for key, value in filter.iteritems()]) if filter else "True"
    sql = "SELECT DISTINCT({dimension}) FROM market.{table} WHERE {condition}".format(
        dimension=dimension, table=table, condition=condition)
    result = query(citus_dsn, sql)
    actual_list = sorted([obj[0] for obj in result])
    expected_dimensions = SUPPORTED_DIMENSIONS[dimension] if expected_dimensions is None else expected_dimensions

    # TODO ad_platform_id = 316 missed in db from 2019-09, and it is a known issue @ 2019-10-20
    if 'date' in filter and filter['date'] == '2019-09-30' and dimension == "ad_platform_id":
        expected_dimensions = sorted(expected_dimensions + [316])
    if expected_dimensions is None:
        raise RuntimeError("expected_dimensions is None")
    if actual_list != expected_dimensions:
        error_msg = "dimensions miss matched on {} table where {} : expected {} - actual {}. " \
                    "FYI, there is known issue with ad platform 316.".format(
                            table, condition, expected_dimensions, actual_list)
        raise RuntimeError(error_msg)

# debug for zepplin
# check_market({"project_name": "All_Products"})



# debug for zepplin
check_market({"project_name": "All_Products"})
