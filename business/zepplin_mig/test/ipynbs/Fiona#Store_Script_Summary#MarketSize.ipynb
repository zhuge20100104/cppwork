# %%
# %%sh
# PGPASSWORD='dNzWtSV3pKTx' psql -h 10.2.10.132 -U citus_bdp_usage_qa -d aa_citus_db -p 5432 << EOF
# SELECT date, count(1) FROM store.store_market_size_fact_v1 where date between '2018-10-01' and '2018-10-05' group by date order by date limit 6;
# EOF

# %%
# %%sh
# aws s3 ls s3://b2c-prod-data-pipeline-unified-store-paid/unified/store.market-size-latest-date.v1/fact/granularity=daily/ | sort -n

# %%
spark.read.parquet("s3://b2c-prod-data-pipeline-unified-store-paid/unified/store.market-size-latest-date.v1/fact/granularity=daily").show()

# %%
spark.read.parquet("s3://b2c-prod-data-pipeline-unified-store-paid/_obselete/app-tech.store.market-size.v1/fact/granularity=daily/date=2019-12-14/").createOrReplaceTempView("temp")
spark.sql("select distinct device_code from temp").show()
