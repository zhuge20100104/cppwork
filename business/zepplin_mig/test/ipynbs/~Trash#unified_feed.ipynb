# %%
# %%sh
# aws s3api list-objects --bucket b2c-prod-data-pipeline-unified-ugc --prefix unified/ugc.unified-alert-feed.v1/

# %%
# %%sh
# aws s3 ls s3://b2c-prod-data-pipeline-unified-ugc/unified/ugc.unified-feed.v1/*

# %%
# %%sh
