# %%
# %%sh
# PGPASSWORD='dNzWtSV3pKTx' psql -h 10.2.10.132 -Ucitus_bdp_usage_qa -d aa_citus_db -p 5432 << EOF
# SET search_path=advancedreview;
# \dn
#
# SELECT * FROM advancedreview_term_fact_v2 limit 3
# EOF

# %%
# %sh
# aws s3 ls s3://b2c-prod-advanced-review/oss/ADVRVW_RELEVANT_TERMS/version=1.0.0/platform=2/process_date=2019-10-16/country=AU/language=en/

# aws s3 ls s3://b2c-prod-advanced-review/oss/ADVRVW_TOPIC_EFFECTIVE_PREDICTIONS/version=1.0.0/platform=2/process_date=2019-07-08/country=AU/



aws s3 ls s3://b2c-prod-data-pipeline-unified-advancedreview/unified/app-int.advancedreview.term.v1/
 
aws s3 ls s3://b2c-prod-data-pipeline-raw-market/raw/app-tech.market.log-fact.v1/insert/
aws s3 ls s3://b2c-prod-data-pipeline-raw-market/raw/app-tech.market.v1/insert/
aws s3 ls s3://b2c-prod-data-pipeline-unified-market/unified/app-tech.market.

# %%
spark.read.parquet("s3://b2c-prod-advanced-review/oss/ADVRVW_RELEVANT_TERMS/version=1.0.0/platform=2/process_date=2019-10-16/country=AU/language=en/").show()

spark.read.parquet("s3://b2c-prod-advanced-review/oss/ADVRVW_TOPIC_EFFECTIVE_PREDICTIONS/version=1.0.0/platform=2/process_date=2019-10-14/country=AU/language=en/").show()

# %%
# %%sh
# # PGPASSWORD='rn*Wh%osCl2C' psql -h internal-aa-citus-mkt-elb-1511434527.us-east-1.elb.amazonaws.com  -U citus_mkt_qa -d aa_citus_db -p 7432 << EOF
# # set search_path;
# # select * from advancedreview_term_fact_v1 limit 3
# # EOF
#
# PGPASSWORD='rn*Wh%osCl2C' psql -h internal-aa-citus-mkt-elb-1511434527.us-east-1.elb.amazonaws.com  -U citus_mkt_qa -d aa_mkt_db -p 7432 << EOF
# select * from market.market_creative_adapp_seen_fact_v1 where ad_platform_id='109' order by first_seen_date desc limit 10;
# -- select * from market.market_adapp_pubapp_seen_fact_v1 where ad_platform_id='109' order by last_seen_date desc limit 5
#
# EOF

# %%
# %%sh
# #raw data
#
# # df1=spark.read.parquet("s3://prod.appannie.mktint.data/oss/SEARCH_VOLUME/routine/granularity=daily/date=2019-09-12/platform=1/").filter("country_code='AE'")#.filter("keyword_id=5198892 and country_code='NL' and platform=1 and device_id=0 ")#.show(20,False)
# # # # print df1.distinct().count()
# # df2=spark.read.parquet("s3://prod.appannie.mktint.data/oss/KEYWORD_DIFFICULTY/routine/granularity=daily/date=2019-09-12/platform=1/").filter("country_code='AE'")#.filter("keyword_id=5198892 and country_code='NL' and platform=1 and device_id=0 ")#.show(20,False)
# # # # df2.show()
# # df1.join(df2, df1.keyword_id==df2.keyword_id, 'outer').distinct().count()
#
#
# # df2=spark.read.parquet("s3://prod.appannie.mktint.data/oss/KEYWORD_DIFFICULTY/routine/granularity=daily/date=2018-07-07/platform=1/").filter("keyword_id='4999617' and country_code='US'")#.filter("keyword_id=5198892 and country_code='NL' and platform=1 and device_id=0 ")#.show(20,False)
#
# # print result
#
# # df1 = spark.read.parquet("s3://b2c-prod-data-pipeline-unified-aso/unified/app-tech.aso.keyword-difficulty-search-volume.v1/fact/granularity=daily/date=2019-09-12").filter("device_code='android-all' and country_code='AE'")
# # df1.show()
#
# # df1.createOrReplaceTempView("table1")
# # spark.sql("SELECT country_code,  difficulty,search_volume from table1 where keyword_id='793364' ").show()
#
#
# # df2=spark.read.parquet("s3://prod.appannie.mktint.data/oss/KEYWORD_DIFFICULTY/routine/granularity=daily/date=2016-10-11/").filter("country_code='US' and platform=2 and device_id=1 and difficulty is null ").count()
# # print df2
#
#
# # df1=spark.read.parquet("s3://prod.appannie.mktint.data/oss/SEARCH_VOLUME/routine/granularity=daily/date=2017-07-06/platform=1/").filter("country_code='us'").show()#.filter("keyword_id=5198892 and country_code='NL' and platform=1 and device_id=0 ")#.show(20,False)
#
# # spark.read.csv(["s3://prod.appannie.aso/ckl/MONTH//2019-08-31/android/android_AE.tsv","s3://prod.appannie.aso/ckl/INCREMENTAL/2019-09-01/android/android_AE.tsv","s3://prod.appannie.aso/ckl/INCREMENTAL/2019-09-02/android/android_AE.tsv","s3://prod.appannie.aso/ckl/INCREMENTAL/2019-09-03/android/android_AE.tsv","s3://prod.appannie.aso/ckl/INCREMENTAL/2019-09-04/android/android_AE.tsv","s3://prod.appannie.aso/ckl/INCREMENTAL/2019-09-05/android/android_AE.tsv","s3://prod.appannie.aso/ckl/INCREMENTAL/2019-09-06/android/android_AE.tsv","s3://prod.appannie.aso/ckl/INCREMENTAL/2019-09-07/android/android_AE.tsv","s3://prod.appannie.aso/ckl/INCREMENTAL/2019-09-08/android/android_AE.tsv","s3://prod.appannie.aso/ckl/INCREMENTAL/2019-09-09/android/android_AE.tsv","s3://prod.appannie.aso/ckl/INCREMENTAL/2019-09-10/android/android_AE.tsv","s3://prod.appannie.aso/ckl/INCREMENTAL/2019-09-11/android/android_AE.tsv","s3://prod.appannie.aso/ckl/INCREMENTAL/2019-09-12/android/android_AE.tsv"],sep="\t").distinct().count()
#
# # spark.read.csv(["s3://prod.appannie.aso/ckl/INCREMENTAL/2019-09-08/android/android_AE.tsv","s3://prod.appannie.aso/ckl/INCREMENTAL/2019-09-07/android/android_AE.tsv","s3://prod.appannie.aso/ckl/INCREMENTAL/2019-09-03/android/android_AE.tsv"],sep="\t").show()

# %%
import unittest
from random import choice, randint

from aaintdatapipeline.application.app_qa.common.utils import get_month_start_end_date
from aaintdatapipeline.application.app_qa.data_validation_v1.constants import IOS_PHONE, IOS_TABLET, \
    ANDROID_ALL, ASO_TS_RAW_DATA_HEAD
from aaintdatapipeline.application.app_qa.data_validation_v1.pysparktest import PySparkTest
from aaintdatapipeline.application.app_qa.data_validation_v1.utils import (
    get_random_date, get_aso_ts_raw_df, get_aso_svi_raw_df, get_aso_kd_raw_df,
    check_parquet_exist, get_date_list_from_granularity, get_aso_ts_unified_data_path)
from aaintdatapipeline.core.fs.device import S3Bucket
from aaintdatapipeline.core.conf import Conf
from aaintdatapipeline.application.app_qa.data_validation_v1.utils import (
    get_aso_citus_connection, datetime_to_string)
from aaintdatapipeline.application.app_qa.data_validation_v1.pysparktest import PySparkTest

from aaintdatapipeline.application.app_qa.data_validation_v1.constants import \
    urn
from decimal import Decimal
import decimal

mkt_new_bucket = "b2c-prod-int-data-pipeline-unified-paid-aso"
ts_unified_path = \
    "s3://{}/unified/app-tech.market.aso-keyword-trafficshare.v1/fact/granularity=daily/date={}/device_code={}/"
svi_kd_unified_path = "s3://{}/unified/app-tech.market.aso-keyword-difficulty-search-volume.v1/fact/" \
                      "granularity=monthly/date={}/device_code={}/"


date = "2018-06-01"
platform = "1"
device_code="ios-tablet"

aso_sv_kd_raw_bucket = "prod.appannie.mktint.data"
aso_sv_raw_bucket_path = "s3://{}/oss/SEARCH_VOLUME/routine/granularity=daily/date={}/platform={}/"
aso_kd_raw_bucket_path = "s3://{}/oss/KEYWORD_DIFFICULTY/routine/granularity=daily/date={}/platform={}"


aso_sv_kd_unified_bucket = "b2c-prod-data-pipeline-unified-aso"
aso_sv_kd_unified_bucket_path = "s3://{}/unified/app-tech.aso.keyword-difficulty-search-volume.v1/fact/granularity=daily/date={}/device_code={}/"




def get_aso_sv_raw_df_root(path, aso_sv_raw_bucket, date, platform):
    return path.format(aso_sv_raw_bucket, date, platform)

def get_aso_kd_raw_df_root(path, aso_kd_raw_bucket, date, platform):
    return path.format(aso_kd_raw_bucket, date, platform)

def get_aso_sv_kd_unified_df_root(path, aso_sv_kd_unified_bucket,  date, device_code):
    return path.format(aso_sv_kd_unified_bucket, date,  device_code)


aso_sv_raw_parquet_path = get_aso_sv_raw_df_root(aso_sv_raw_bucket_path, aso_sv_kd_raw_bucket,
                                                           date,
                                                           platform)
aso_kd_raw_parquet_path = get_aso_kd_raw_df_root(aso_kd_raw_bucket_path, aso_sv_kd_raw_bucket,
                                                           date,
                                                           platform)

aso_sv_kd_unified_parquet_path = get_aso_sv_kd_unified_df_root(aso_sv_kd_unified_bucket_path,
                                                                   aso_sv_kd_unified_bucket,
                                                                   date,
                                                                   device_code
                                                                   )
def test_android_sv_kd_keyword_count():
    print 'test android all sv keyword count with different country'
    country_iterate="US"
    print country_iterate
    expected_sv_count = spark.read.parquet(aso_sv_raw_parquet_path.split("platform")[0]).filter(
        "platform=2 and device_id=1 and country_code='{}'".format(
            country_iterate)) #.count()
    expected_kd_count = spark.read.parquet(aso_kd_raw_parquet_path.split("platform")[0]).filter(
        "platform=2 and device_id=1 and country_code='{}'".format(
            country_iterate)) #.count()
    
    result=expected_sv_count.join(expected_kd_count, expected_sv_count.keyword_id==expected_kd_count.keyword_id, 'outer').select(expected_kd_count.keyword_id).collect()
    print len(result)
    unified_count = spark.read.parquet(aso_sv_kd_unified_parquet_path.split("device_code")[0]).filter(
        "country_code='{}'and device_code='ios-phone'".format(
            country_iterate)).select(
        "keyword_id").distinct().count()
        
    print unified_count
    
    
def test_android_sv_kd_keyword_count_citus():
    country_code_android_list=['US']
    print 'test android all sv-kd keyword count with different country'
    for country_iterate in country_code_android_list:
        print country_iterate
        expected_sv_count = spark.read.parquet(aso_sv_raw_parquet_path.split("platform")[0]).filter(
            "platform=1 and device_id=0 and country_code='{}'".format(
                country_iterate))
        expected_kd_count = spark.read.parquet(aso_kd_raw_parquet_path.split("platform")[0]).filter(
            "platform=1 and device_id=0 and country_code='{}'".format(
                country_iterate))
        print expected_kd_count

        result = expected_sv_count.join(expected_kd_count,
                                        expected_sv_count.keyword_id == expected_kd_count.keyword_id,
                                        'outer').select(expected_kd_count.keyword_id).collect()
        print len(result)
        sql = "select count(distinct keyword_id) from aso.aso_sv_kd_fact_v1 where device_code='{}' and country_code='{}' and date='{}'".format('android-all',country_iterate,date)
        db_result = get_aso_citus_connection(urn, sql)

        # unified_count = .spark.read.parquet(.aso_sv_kd_unified_parquet_path.split("device_code")[0]).filter(
        #     "country_code='{}' and device_code='android-all'".format(
        #         country_iterate)).select(
        #     "keyword_id").distinct().count()
        print db_result
    
    # selassertNotEqual(expected_sv_count or expected_kd_count, 0)
    # self.assertEqual(max(expected_sv_count, expected_kd_count), unified_count,
    #                  msg='{}~{}'.format(max(expected_sv_count, expected_kd_count), unified_count))

print "########################"

keyword_id=1387
def test_android_sv_kd_value():
    print 'test android all sv-kd keyword count with different country'
    country_code = 'US'
    expected_sv_count = spark.read.parquet(aso_sv_raw_parquet_path.split("platform")[0]).filter(
        "platform=1 and device_id=0 and country_code='{}' and keyword_id={}".format(
            country_code,keyword_id))
    expected_kd_count = spark.read.parquet(aso_kd_raw_parquet_path.split("platform")[0]).filter(
        "platform=1 and device_id=0 and country_code='{}' and keyword_id={}".format(
        country_code, keyword_id))

    result = expected_sv_count.join(expected_kd_count,
                                    expected_sv_count.keyword_id == expected_kd_count.keyword_id,
                                    'outer').collect()[:]

    unified_result = spark.read.parquet(aso_sv_kd_unified_parquet_path.split("device_code")[0]).filter(
        "country_code='{}' and device_code='android-all' and keyword_id={}".format(
            country_code, keyword_id)).collect()[:]
            
    print result
    print unified_result
    print result[0]["search_volume"]
    print unified_result[0]["search_volume"]
    print result[0]["difficulty"]
    print unified_result[0]["difficulty"]
    
keyword_id=1387
def test_android_sv_kd_value_citus():
    print 'test android all sv-kd keyword count with different country'
    sql = "select search_volume, difficulty from aso.aso_sv_kd_fact_v1 where device_code='{}' and country_code='{}' and date='{}' and keyword_id='{}'".format('android-all','US', date,keyword_id)

    country_code = 'US'
    expected_sv_count = spark.read.parquet(aso_sv_raw_parquet_path.split("platform")[0]).filter(
        "platform=1 and device_id=0 and country_code='{}' and keyword_id={}".format(
            country_code,keyword_id))
    expected_kd_count = spark.read.parquet(aso_kd_raw_parquet_path.split("platform")[0]).filter(
        "platform=1 and device_id=0 and country_code='{}' and keyword_id={}".format(
        country_code, keyword_id))

    result = expected_sv_count.join(expected_kd_count,
                                    expected_sv_count.keyword_id == expected_kd_count.keyword_id,
                                    'outer').collect()[:]
    print result
    print result[0]["search_volume"]
    print type(result[0]["search_volume"])
    print result[0]["difficulty"]

    db_result = get_aso_citus_connection(urn, sql)
    print db_result[0]

    
    print abs(decimal.Decimal(round(result[0]["search_volume"],6))-db_result[0][0])<0.01
    print abs(decimal.Decimal(round(result[0]["difficulty"],1))-db_result[0][1])<0.01




mkt_new_bucket = "b2c-prod-data-pipeline-unified-aso"
conf = Conf(
    bucket_name=mkt_new_bucket
)

start_date = '2016-10-11'
end_date = '2019-06-30'

def test_android_ts_date_period_completeness():
    date_list = get_date_list_from_granularity(start_date, end_date, 'daily')
    print date_list
    path_fail, data_fail = dict(), dict()
    path_fail[device_code], data_fail[device_code] = list(), list()
    for date in date_list:
        unified_parquet_path = "unified/app-tech.aso.keyword-difficulty-search-volume.v1/fact/granularity=daily/date={}".format(date) #get_aso_ts_unified_data_path(date, device_code)
        files = S3Bucket(conf=conf).all(unified_parquet_path)
        if files:
            if check_parquet_exist(files):
                data_fail[device_code].append(date)
        else:
            path_fail[device_code].append(date)
    if not path_fail[device_code]:
        path_fail.pop(device_code)
    if not data_fail[device_code]:
        data_fail.pop(device_code)
        
    print data_fail
    print path_fail


def test_android_ts_date_period_completeness_citus():
    date_list = get_date_list_from_granularity(start_date, end_date, 'daily')
    #print date_list
    path_fail, data_fail = dict(), dict()
    path_fail[device_code], data_fail[device_code] = list(), list()
    
    sql = "select distinct date from aso.aso_sv_kd_fact_v1 where device_code='android-all'"
    db_result = get_aso_citus_connection(urn, sql)

    acutal_db_result=[]
    for item in db_result:
        acutal_db_result.append(str(item[0]))
        
        
    print list(set(date_list).difference(set(acutal_db_result)))


def test_kd_do_not_have_zero():
    print 'test no Zero value in keyword diffculity'
    sql = "select * from aso_sv_kd_fact_v1 where device_code = 'android-all' and difficulty = 0"
    db_result = get_aso_citus_connection(urn, sql)
    print db_result

# test_android_sv_kd_keyword_count()
# test_android_sv_kd_keyword_value()
# test_android_ts_date_period_completeness()
test_kd_do_not_have_zero()

# %%
import unittest
from random import choice, randint

from aaintdatapipeline.application.app_qa.common.utils import get_month_start_end_date
from aaintdatapipeline.application.app_qa.data_validation_v1.constants import IOS_PHONE, IOS_TABLET, \
    ANDROID_ALL, ASO_TS_RAW_DATA_HEAD
from aaintdatapipeline.application.app_qa.data_validation_v1.pysparktest import PySparkTest
from aaintdatapipeline.application.app_qa.data_validation_v1.utils import (
    get_random_date, get_aso_ts_raw_df, get_aso_svi_raw_df, get_aso_kd_raw_df,
    check_parquet_exist, get_date_list_from_granularity, get_aso_ts_unified_data_path)
from aaintdatapipeline.core.fs.device import S3Bucket
from aaintdatapipeline.core.conf import Conf
from aaintdatapipeline.application.app_qa.data_validation_v1.utils import (
    get_aso_citus_connection, datetime_to_string)

from aaintdatapipeline.application.app_qa.data_validation_v1.constants import \
    urn
from aaintdatapipeline.application.app_qa.common.utils import get_date_list

from aaintdatapipeline.application.app_qa.common.utils import get_random_day_in_last_month, datetime_to_string, \
    get_random_day_in_last_week, get_week_start_end_date, send_data_source_date_email, get_month_start_end_date, \
    string_to_datetime

from dateutil.relativedelta import relativedelta
from datetime import date, timedelta
from datetime import timedelta, date, datetime

mkt_new_bucket = "b2c-prod-int-data-pipeline-unified-paid-aso"
ts_unified_path = \
    "s3://{}/unified/app-tech.market.aso-keyword-trafficshare.v1/fact/granularity=daily/date={}/device_code={}/"
svi_kd_unified_path = "s3://{}/unified/app-tech.market.aso-keyword-difficulty-search-volume.v1/fact/" \
                      "granularity=monthly/date={}/device_code={}/"


date = "2019-07-03"
platform = "1"
device_code="ios-tablet"

aso_sv_kd_raw_bucket = "prod.appannie.mktint.data"
aso_sv_raw_bucket_path = "s3://{}/oss/SEARCH_VOLUME/routine/granularity=daily/date={}/platform={}/"
aso_kd_raw_bucket_path = "s3://{}/oss/KEYWORD_DIFFICULTY/routine/granularity=daily/date={}/platform={}"


aso_sv_kd_unified_bucket = "b2c-prod-data-pipeline-unified-aso"
aso_sv_kd_unified_bucket_path = "s3://{}/unified/app-tech.aso.keyword-difficulty-search-volume.v1/fact/granularity=daily/date={}/device_code={}/"




def get_aso_sv_raw_df_root(path, aso_sv_raw_bucket, date, platform):
    return path.format(aso_sv_raw_bucket, date, platform)

def get_aso_kd_raw_df_root(path, aso_kd_raw_bucket, date, platform):
    return path.format(aso_kd_raw_bucket, date, platform)

def get_aso_sv_kd_unified_df_root(path, aso_sv_kd_unified_bucket,  date, device_code):
    return path.format(aso_sv_kd_unified_bucket, date,  device_code)


aso_sv_raw_parquet_path = get_aso_sv_raw_df_root(aso_sv_raw_bucket_path, aso_sv_kd_raw_bucket,
                                                           date,
                                                           platform)
aso_kd_raw_parquet_path = get_aso_kd_raw_df_root(aso_kd_raw_bucket_path, aso_sv_kd_raw_bucket,
                                                           date,
                                                           platform)

aso_sv_kd_unified_parquet_path = get_aso_sv_kd_unified_df_root(aso_sv_kd_unified_bucket_path,
                                                                   aso_sv_kd_unified_bucket,
                                                                   date,
                                                                   device_code
                                                                   )
def test_android_sv_kd_keyword_count():
    print 'test android all sv keyword count with different country'
    country_iterate="US"
    print country_iterate
    expected_sv_count = spark.read.parquet(aso_sv_raw_parquet_path.split("platform")[0]).filter(
        "platform=2 and device_id=1 and country_code='{}'".format(
            country_iterate)) #.count()
    expected_kd_count = spark.read.parquet(aso_kd_raw_parquet_path.split("platform")[0]).filter(
        "platform=2 and device_id=1 and country_code='{}'".format(
            country_iterate)) #.count()
    
    result=expected_sv_count.join(expected_kd_count, expected_sv_count.keyword_id==expected_kd_count.keyword_id, 'outer').select(expected_kd_count.keyword_id).collect()
    print len(result)
    unified_count = spark.read.parquet(aso_sv_kd_unified_parquet_path.split("device_code")[0]).filter(
        "country_code='{}'and device_code='ios-phone'".format(
            country_iterate)).select(
        "keyword_id").distinct().count()
        
    print unified_count
    
    
def test_android_sv_kd_keyword_count_citus():
    country_code_android_list=['US']
    print 'test android all sv-kd keyword count with different country'
    for country_iterate in country_code_android_list:
        print country_iterate
        expected_sv_count = spark.read.parquet(aso_sv_raw_parquet_path.split("platform")[0]).filter(
            "platform=1 and device_id=0 and country_code='{}'".format(
                country_iterate))
        expected_kd_count = spark.read.parquet(aso_kd_raw_parquet_path.split("platform")[0]).filter(
            "platform=1 and device_id=0 and country_code='{}'".format(
                country_iterate))
        print expected_kd_count

        result = expected_sv_count.join(expected_kd_count,
                                        expected_sv_count.keyword_id == expected_kd_count.keyword_id,
                                        'outer').select(expected_kd_count.keyword_id).collect()
        print len(result)
        sql = "select count(distinct keyword_id) from aso.aso_sv_kd_fact_v1 where device_code='{}' and country_code='{}' and date='{}'".format('android-all',country_iterate,date)
        db_result = get_aso_citus_connection(urn, sql)

        # unified_count = .spark.read.parquet(.aso_sv_kd_unified_parquet_path.split("device_code")[0]).filter(
        #     "country_code='{}' and device_code='android-all'".format(
        #         country_iterate)).select(
        #     "keyword_id").distinct().count()
        print db_result
    
    # selassertNotEqual(expected_sv_count or expected_kd_count, 0)
    # self.assertEqual(max(expected_sv_count, expected_kd_count), unified_count,
    #                  msg='{}~{}'.format(max(expected_sv_count, expected_kd_count), unified_count))

print "########################"

keyword_id=1387
def test_android_sv_kd_keyword_value():
    print 'test android all sv-kd keyword count with different country'
    country_code = 'US'
    expected_sv_count = spark.read.parquet(aso_sv_raw_parquet_path.split("platform")[0]).filter(
        "platform=1 and device_id=0 and country_code='{}' and keyword_id={}".format(
            country_code,keyword_id))
    expected_kd_count = spark.read.parquet(aso_kd_raw_parquet_path.split("platform")[0]).filter(
        "platform=1 and device_id=0 and country_code='{}' and keyword_id={}".format(
        country_code, keyword_id))

    result = expected_sv_count.join(expected_kd_count,
                                    expected_sv_count.keyword_id == expected_kd_count.keyword_id,
                                    'outer').collect()[:]

    unified_result = spark.read.parquet(aso_sv_kd_unified_parquet_path.split("device_code")[0]).filter(
        "country_code='{}' and device_code='android-all' and keyword_id={}".format(
            country_code, keyword_id)).collect()[:]
            
    print result
    print unified_result
    print result[0]["search_volume"]
    print unified_result[0]["search_volume"]
    print result[0]["difficulty"]
    print unified_result[0]["difficulty"]

mkt_new_bucket = "b2c-prod-data-pipeline-unified-aso"
conf = Conf(
    bucket_name=mkt_new_bucket
)

start_date = '2016-10-11'
end_date = '2019-06-30'

def test_android_ts_date_period_completeness():
    date_list = get_date_list_from_granularity(start_date, end_date, 'daily')
    print date_list
    path_fail, data_fail = dict(), dict()
    path_fail[device_code], data_fail[device_code] = list(), list()
    for date in date_list:
        unified_parquet_path = "unified/app-tech.aso.keyword-difficulty-search-volume.v1/fact/granularity=daily/date={}".format(date) #get_aso_ts_unified_data_path(date, device_code)
        files = S3Bucket(conf=conf).all(unified_parquet_path)
        if files:
            if check_parquet_exist(files):
                data_fail[device_code].append(date)
        else:
            path_fail[device_code].append(date)
    if not path_fail[device_code]:
        path_fail.pop(device_code)
    if not data_fail[device_code]:
        data_fail.pop(device_code)
        
    print data_fail
    print path_fail

country_code_android_list=['US']

def test_android_sv_kd_ckl_list_check(self):
        print 'test android sv ckl list'
        for country_iterate in country_code_android_list:
            print country_iterate
            ckl_check_list=["s3://prod.appannie.aso/ckl/INCREMENTAL/2019-09-08/android/android_AE.tsv","s3://prod.appannie.aso/ckl/INCREMENTAL/2019-09-07/android/android_AE.tsv","s3://prod.appannie.aso/ckl/INCREMENTAL/2019-09-03/android/android_AE.tsv"]
            expected_ckl_list=spark.read.csv(ckl_check_list,sep="\t").select("_c2").distinct().count()

            unified_count = spark.read.parquet(aso_sv_kd_unified_parquet_path.split("device_code")[0]).filter(
                "country_code='{}' and device_code='android-all'".format(
                    country_iterate)).select(
                "keyword_id").distinct().count()
            print expected_ckl_list
            assertEqual(expected_ckl_list, unified_count,
                             msg='{}~{}'.format(expected_ckl_list, unified_count))

def get_ckl_list(date,country):
    path="s3://prod.appannie.aso/ckl/{type}/{date}/android/android_{country}.tsv"
    ckl_path_list=[]
    ckl_date_list, need_last_month_data, last_day_of_month= get_date_list_for_ckl(date)
    if need_last_month_data:
        ckl_path_list.append(path.format(type='MONTH',date=last_day_of_month,country=country))
        for i in ckl_date_list:
            ckl_path_list.append(path.format(type='INCREMENTAL',date=i,country=country))
    else:
        ckl_path_list.append(path.format(type='MONTH',date=last_day_of_month,country=country))
        for i in ckl_date_list:
            ckl_path_list.append(path.format(type='INCREMENTAL',date=i,country=country))

    return ckl_path_list
    
def get_date_list_for_ckl(test_date):
    date_list=[]
    need_last_month=False
    month_end_date=''
    if string_to_datetime(test_date).day > 11:
        last_month= string_to_datetime(test_date)+relativedelta(months=-1)
        temp,month_end_date = get_month_start_end_date(datetime_to_string(last_month))
        month_start_date,temp = get_month_start_end_date(test_date)
        date_list.append(get_date_list(month_start_date, test_date))
    else:
        last_month= string_to_datetime(test_date)+relativedelta(months=-1)
        previously_two_month= string_to_datetime(test_date)+relativedelta(months=-2)
        month_start_date,temp = get_month_start_end_date(datetime_to_string(last_month))
        temp,month_end_date = get_month_start_end_date(datetime_to_string(previously_two_month))
        date_list.append(get_date_list(month_start_date, test_date))
        need_last_month=True
    print date_list[0]
    return date_list[0],need_last_month,month_end_date

# test_android_sv_kd_keyword_count()
# test_android_sv_kd_keyword_value()
# test_android_ts_date_period_completeness()
get_ckl_list('2019-03-15','US')

# %%
# %%sh
# # aws s3 ls s3://prod.appannie.mktint.data/oss/SEARCH_VOLUME/routine/granularity=daily/date=2019-07-01/platform=1/
# # aws s3 ls s3://prod.appannie.mktint.data/oss/KEYWORD_DIFFICULTY/routine/granularity=daily/date=2019-07-01/platform=1/
#
#
# # aws s3 ls s3://b2c-prod-data-pipeline-unified-aso/unified/app-tech.aso.keyword-difficulty-search-volume.v1/fact/granularity=daily/
#
# # aws s3 ls s3://prod.appannie.aso/ckl/INCREMENTAL/2019-09-07/android/android_AE.tsv
#
# # %%sh
# # PGPASSWORD='rn*Wh%osCl2C' psql -h internal-aa-citus-mkt-elb-1511434527.us-east-1.elb.amazonaws.com  -U citus_mkt_qa -d aa_mkt_db -p 7432 << EOF
# # set search_path=aso;
# # select * from aso_sv_kd_fact_v1 where device_code='android-all' and difficulty=0
#
# # EOF

# %%
# %%sh
# aws s3 ls s3://prod.appannie.mktint.data/oss/TRAFFIC_SHARE/routine/granularity=daily/date=2019-04-24/platform=1/

# %%
from pyspark.sql.functions import round

# raw data:app_type=SINGLE_APP/
# aws s3 ls s3://prod.appannie.mktint.data/oss/SEARCH_ADS_KEYWORD_SOV/routine/granularity=daily/date=2019-07-26/

# aws s3 ls s3://b2c-prod-data-pipeline-unified-aso/unified/app-tech.aso.sov-search-ads-keyword-fact.v1/metric/granularity=daily/date=2019-07-25/


# aws s3 ls s3://prod.appannie.mktint.data/oss/SEARCH_ADS_KEYWORD_SOV/routine/granularity=daily/date=2019-08-08/platform=1/app_type=SINGLE_APP/
 
# aws s3 ls s3://prod.appannie.aso.paid.product/oss/DAY/2018-09-27/TS/2/

# spark.read.csv("s3://prod.appannie.aso.paid.product/oss/DAY/2018-10-27/TS/2/",sep="\t").filter("_c2='UA' and  _c1=1 and _c0=2 and _c3=1058 ").show(20, False)


# spark.read.parquet("s3://b2c-prod-int-data-pipeline-unified-paid-aso/unified/app-tech.market.aso-keyword-trafficshare.v1/fact/granularity=daily/date=2017-01-01/device_code=android-all/").filter("keyword_id=2428227 and country_code='JP'").show(20,False)

# aws s3 ls s3://b2b-prod-int-data-pipeline-metastore/meta/staging-events/app-tech.aso.sov-search-ads-keyword-fact.v1/2019/08/21/08/

# spark.read.csv("s3://prod.appannie.aso.paid.product/oss/DAY/2018-10-27/TS/2/",sep="\t").filter("_c2='UA' and  _c1=1 and _c0=2").select("_c3" , round('_c6',6).alias('r')).filter("r!=0").select("_c3").distinct().count()
# spark.read.parquet("s3://b2c-prod-int-data-pipeline-unified-paid-aso/unified/app-tech.market.aso-keyword-trafficshare.v1/fact/granularity=daily/date=2018-10-27/device_code=ios-phone/").filter("country_code='UA'").select("keyword_id").distinct().count()
# print 'hello'
# # spark.read.csv("s3://prod.appannie.aso.paid.product/oss/DAY/2019-01-08/TS/1/",sep="\t").filter("_c1 = 0 and _c2='SA'").select("_c3").distinct().count()
# print 'world'
spark.read.parquet("s3://b2c-prod-data-pipeline-unified-aso/unified/app-tech.aso.keyword-trafficshare.v1/fact/granularity=daily/").filter("country_code='SA' and date='2019-01-08' and device_code='android-all'").select("keyword_id").distinct().count()

# %%
# %%sh
# PGPASSWORD='rn*Wh%osCl2C' psql -h internal-aa-citus-mkt-elb-1511434527.us-east-1.elb.amazonaws.com  -U citus_mkt_qa -d aa_mkt_db -p 7432 << EOF
# set search_path=aso;
# select * from aso.aso_sv_kd_fact_v1 where date='2019-08-02' limit 3
# EOF

# %%
import unittest
from random import choice, randint
from aaintdatapipeline.application.app_qa.common.utils import get_date_list

from aaintdatapipeline.application.app_qa.common.utils import get_month_start_end_date
from aaintdatapipeline.application.app_qa.data_validation_v1.constants import IOS_PHONE, IOS_TABLET, \
    ANDROID_ALL, ASO_TS_RAW_DATA_HEAD
from aaintdatapipeline.application.app_qa.data_validation_v1.constants import \
    urn
from aaintdatapipeline.application.app_qa.data_validation_v1.pysparktest import PySparkTest
from aaintdatapipeline.application.app_qa.data_validation_v1.utils import (
    get_random_date, get_aso_ts_raw_df, get_aso_svi_raw_df, get_aso_kd_raw_df,
    check_parquet_exist, get_date_list_from_granularity, get_aso_ts_unified_data_path, get_aso_est_unified_data_path,
    get_aso_citus_connection,datetime_to_string)
from aaintdatapipeline.application.app_qa.data_validation_v1.constants import \
APP_STORE_RANK_TABLE_NAME, urn, COUNTRY_CODE_CHECK_LIST, ios_devices
import unittest
from random import choice, randint

from aaintdatapipeline.application.app_qa.common.utils import get_month_start_end_date
from aaintdatapipeline.application.app_qa.data_validation_v1.constants import IOS_PHONE, IOS_TABLET, \
    ANDROID_ALL, ASO_TS_RAW_DATA_HEAD
from aaintdatapipeline.application.app_qa.data_validation_v1.pysparktest import PySparkTest
from aaintdatapipeline.application.app_qa.data_validation_v1.utils import (
    get_random_date, get_aso_ts_raw_df, get_aso_svi_raw_df, get_aso_kd_raw_df,
    check_parquet_exist, get_date_list_from_granularity, get_aso_ts_unified_data_path, get_aso_est_unified_data_path)
from aaintdatapipeline.core.conf import Conf
from aaintdatapipeline.core.fs.device import S3Bucket

from aaintdatapipeline.core.conf import Conf
from aaintdatapipeline.core.fs.device import S3Bucket
mkt_new_bucket = "b2c-prod-int-data-pipeline-unified-paid-aso"
ts_unified_path = \
    "s3://{}/unified/app-tech.market.aso-keyword-trafficshare.v1/fact/granularity=daily/date={}/device_code={}/"
svi_kd_unified_path = "s3://{}/unified/app-tech.market.aso-keyword-difficulty-search-volume.v1/fact/" \
                      "granularity=monthly/date={}/device_code={}/"
conf = Conf(
    bucket_name=mkt_new_bucket
)

traffic_share_table="aso.aso_keyword_trafficshare_fact_v1"
start_date = '2017-01-01'
end_date = '2019-08-01'
date = get_random_date(start_date, end_date)
random_monthly_date = get_random_date(start_date, end_date)
_, monthly_date = get_month_start_end_date(random_monthly_date)
country_code = 'IN'
raw_ts_data_path = get_aso_ts_raw_df(ASO_TS_RAW_DATA_HEAD, date, 1)

def test_android_ts_metric_est():
    expected_prodID_ts = spark.read.csv(raw_ts_data_path, sep="\t").filter(
        "_c1 = 0 and _c2 = '{}' and _c3 = {}".format(
            country_code, keyword_id)).select('_c4', '_c6').collect()
    sql = "select app_id_list,traffic_share_list from {} where country_code='{}' and keyword_id={} and date='{}' and device_code='{}'".format(
        traffic_share_table, country_code, keyword_id, date, ANDROID_ALL)
    db_result = get_aso_citus_connection(urn, sql)
    print 'test_android_ts_metric_est'

    db_count = db_result[0][0] or db_result[0][1] if len(db_result) else 0
    #assertNotEqual(len(db_count), 0)
    #assertEqual(len(db_result[0][0]),len(db_result[0][1]))
    print db_count
    print "expected_prodID_ts"
    print expected_prodID_ts
    print "db_result"
    print db_result
    for data in range(0, len(expected_prodID_ts)):
        product_id_index = list(db_result[0][0]).index(long(expected_prodID_ts[data][0]))
        print round(float(expected_prodID_ts[data][1]),6)
        print db_result[0][1][product_id_index]

#test_android_ts_metric_est()

def test_ios_date_period_completeness():
    expected_date_list = get_date_list(start_date, end_date)
    date_fail = dict()
    actual_date_list = []
    country_code_list="'US', 'FR', 'DE', 'GB', 'AU', 'BE', 'FI', 'GR', 'JP', 'IT'"
    for device_code in ios_devices:
        date_fail[device_code] = list()
        sql = "select distinct(date) from {} where granularity = 'daily' and device_code = '{}' " \
              "and country_code in ({}) and date between '{}' and '{}'".format(traffic_share_table, device_code,
                                                                              country_code_list, start_date,
                                                                              end_date)

        date_list = get_aso_citus_connection(urn, sql)
        for item in date_list:
            actual_date_list.append(datetime_to_string(item[0]))
        print 'actual_date_list'
        print actual_date_list
        print 'expected_date_list'
        print expected_date_list
        for date in expected_date_list:
            if str(date) not in actual_date_list:
                date_fail[device_code].append(date)
        if not date_fail[device_code]:
            date_fail.pop(device_code)
    print date_fail
    # self.assertFalse(date_fail, msg='{}'.format(date_fail))

def test_android_ts_keyword_count():
    print "country_code: "
    country_code = "US"
    print date
    expected_count = spark.read.csv(raw_ts_data_path, sep="\t").filter("_c1 = 0 and _c2 = '{}'".format(
        country_code)).select("_c3", round('_c6', 6).alias('r')).filter("r!=0").select(
        "_c3").distinct().count()
    sql = "select count(distinct keyword_id) from {} where country_code='{}' and date='{}' and device_code='{}' and app_id_list!='{{}}' ".format(
        traffic_share_table, country_code, date, ANDROID_ALL)

    print "test_android_ts_keyword_count_sql"
    print sql
    db_result = get_aso_citus_connection(urn, sql)
    print "test_android_ts_keyword_count_db_result"
    print db_result

    db_count = int(db_result[0][0] if db_result else 0)
    print db_count
    # self.assertEqual(expected_count, db_count,
    #                  msg="raw count = {}; db count = {}.".format(
    #                      expected_count, db_count))


def test_android_ts_keyword_app_id_count():
        keyword_id = spark.read.csv(raw_ts_data_path, sep="\t").filter("_c1 = 0 and _c2 = '{}'".format(
            country_code)).select('_c3').limit(1).collect()[0][0]
        expected_count = spark.read.csv(raw_ts_data_path, sep="\t").filter(
            "_c1 = 0 and _c2 = '{}' and _c3 = {}".format(
                country_code, keyword_id)).select("_c4", round('_c6', 6).alias('r')).filter("r!=0").select(
            "_c4").distinct().count()
        sql = "select app_id_list from {} where country_code='{}' and keyword_id={} and date='{}';".format(
            traffic_share_table, country_code, keyword_id, date)

        print "test_android_ts_keyword_app_id_count_sql"
        print sql
        db_result = get_aso_citus_connection(urn, sql)
        print 'test_android_ts_keyword_app_id_count_db_result'
        print  db_result

        db_count = db_result[0][0] if len(db_result) else 0
        
        print expected_count
        print len(db_count)
        # assertEqual(expected_count, len(db_count),
        #                  msg="raw count = {}; db count = {}.".format(
        #                      expected_count, len(db_count)))
                             
                             

country_code='CO'
test_times = 1
device_code = ANDROID_ALL
start_date = '2019-01-01'
end_date = '2019-08-10'

def test_android_ts_date_period_completeness():
        date_list = get_date_list_from_granularity(start_date, end_date, 'daily')
        path_fail, data_fail = dict(), dict()
        path_fail[device_code], data_fail[device_code] = list(), list()
        for date in date_list:
            unified_parquet_path = get_aso_ts_unified_data_path(date, device_code)
            files = S3Bucket(conf=conf).all(unified_parquet_path)
            if files:
                if check_parquet_exist(files):
                    data_fail[device_code].append(date)
            else:
                path_fail[device_code].append(date)
        if not path_fail[device_code]:
            path_fail.pop(device_code)
        if not data_fail[device_code]:
            data_fail.pop(device_code)

mkt_new_bucket = "b2c-prod-data-pipeline-unified-aso"
keyword_id=5141842
date='2019-01-01'
raw_ts_data_path="s3://prod.appannie.mktint.data/oss/TRAFFIC_SHARE/routine/granularity=daily/date={}/platform={}/".format(date,1)
ts_unified_path ="s3://{}/unified/app-tech.aso.keyword-trafficshare.v1/fact/granularity=daily/date={}/device_code={}/"
# spark.sql.decimalOperations.allowPrecisionLoss=False

print ts_unified_path
def test_android_ts_metric_est():
        print ts_unified_path.format(
            mkt_new_bucket, date, device_code
        )
        expected_ts = spark.read.parquet(raw_ts_data_path).filter(
        "country_code='{}' and keyword_id={}".format(
        country_code, keyword_id)).select('app_id' ,'traffic_score','traffic_share').collect()
        print 'expected ts'
        print expected_ts
        
        unified_ts =spark.read.parquet(ts_unified_path.format(
            mkt_new_bucket, date, device_code
        )).filter("country_code = '{}' and keyword_id = '{}'".format(
            country_code, keyword_id)).select('app_id_list', 'traffic_score_list', 'traffic_share_list').collect()
            
        print 'unified ts: '
        print unified_ts
        
        for i in range(0,len(unified_ts[0][0])):
            print 'expected ts in array'
            print expected_ts[i][0]
            ts_index =  unified_ts[0][0].index(expected_ts[i][0])
            print unified_ts[0][0][ts_index]
            print unified_ts[0][1][ts_index]
            print unified_ts[0][2][ts_index]
            print expected_ts[i][1]
            print expected_ts[i][2]

            # print 'check with result'
            # print unified_ts[0][0][i]
            # for
            # print expected_ts[i][1]
            # print unified_ts[0][2][i]
            # print expected_ts[i][2]

        # raw_index = randint(0, len(unified_ts[0][0]) - 1)
        # app_id = unified_ts[0][0][raw_index]
        # traffic_score = unified_ts[i][1][raw_index]
        # traffic_share = unified_ts[0][2][raw_index]

        # print 'andorid ts metric'
        # print raw_index
        # print app_id
        # print traffic_score
        # print traffic_share

        # print 'expected ts'
        # print expected_ts

        # expect_score = float(expected_ts[0][0]) - float(traffic_score)
        # expect_share = float(expected_ts[0][1]) - float(traffic_share)
        
        # print expect_score
        # print expect_share
test_android_ts_metric_est()
        # assertEqual(abs(expect_score), 0.0, msg='{}~{}'.format(expect_score, traffic_score))
        # assertEqual(abs(expect_share), 0.0, msg='{}~{}'.format(expect_share, traffic_share))
# s3://b2c-prod-data-pipeline-unified-aso/unified/app-tech.aso.keyword-trafficshare.v1/fact/granularity=daily/
# s3://b2c-prod-data-pipeline-unified-aso/unified/app-tech.market.aso-keyword-trafficshare.v1/fact/granularity=daily/date=2019-01-01/device_code=android-all/

1127.45214844
1127.4521484375
3.8361611986272135e-08
3.83616119863e-08

# %%
import psycopg2
import datetime

citus_dsn_ = (
    "dbname='{db}' user='{user}' password='{password}' "
    "host='{host}' port='{port}'".format(
        db="aa_mkt_db",
        user="citus_mkt_qa",
        host="internal-aa-citus-mkt-elb-1511434527.us-east-1.elb.amazonaws.com",
        password="rn*Wh%osCl2C",
        port=7432
    )
)
sql = "select * from aso.aso_keyword_trafficshare_fact_v1 limit 1;"
# sql = "select count(distinct keyword_id) from aso.aso_keyword_trafficshare_fact_v1 where country_code='JP' and date='2017-01-01' and device_code='android-all' "

def query(dsn, sql):
    with psycopg2.connect(dsn) as conn:
        conn.autocommit = True
        with conn.cursor() as cur:
            cur.execute(sql)
            result = cur.fetchall()
            conn.commit()
    return result
    
test_result = query(citus_dsn_, sql)

print test_result
# jdbcDF2 = spark.read.jdbc("jdbc:citus:dbserver", "aso.aso_keyword_trafficshare_fact_v1",

# jdbcDF3 = spark.read \
#     .format("jdbc") \
#     .option("url", "jdbc:postgresql:dbserver://internal-aa-citus-mkt-elb-1511434527.us-east-1.elb.amazonaws.com") \
#     .option("dbtable", "aa_mkt_db.aso.aso_keyword_trafficshare_fact_v1") \
#     .option("user", "citus_mkt_qa") \
#     .option("password", "rn*Wh%osCl2C") \
#     .option("port", "7432") \
#     .load()


# spark.createDataFrame(test_result).show(20,False)




#405162L

# %%
import pyspark.sql.functions as f
# aso-kpi-sov_search_ads_keyword_fact_v1_daily_ca_2019-07
# aso-kpi-sov_search_ads_keyword_fact_v1_daily_gb_2019-07
# f.array_contains("")
# spark.read.parquet("s3://aardvark-prod-dca-data/oss/SEARCH_ADS_KEYWORD_SOV/version=0815_test/range_type=DAY/date=2019-07-19/platform=0/app_type=UNIFIED_APP").show()


# raw data

# spark.read.parquet("s3://prod.appannie.mktint.data/oss/SEARCH_ADS_KEYWORD_SOV/routine/granularity=daily/date=2019-07-03/").where("app_type='SINGLE_APP' and platform=1 and device_id=1 and country_code='US'").show()

# spark.read.parquet("s3://prod.appannie.mktint.data/oss/SEARCH_ADS_KEYWORD_SOV/routine/granularity=daily/date=2019-07-03/").filter("sov_search_ads_keyword is null").show()
# spark.read.parquet("s3://prod.appannie.mktint.data/oss/SEARCH_ADS_KEYWORD_SOV/routine/granularity=daily/date=2019-07-03/").filter("keyword_id is null").show()
# spark.read.parquet("s3://prod.appannie.mktint.data/oss/SEARCH_ADS_KEYWORD_SOV/routine/granularity=daily/date=2019-07-03/").filter("product_id is not null").count()

# spark.read.parquet("s3://prod.appannie.mktint.data/oss/SEARCH_ADS_KEYWORD_SOV/routine/granularity=daily/date=2019-07-03/").where("app_type='SINGLE_APP' and platform=2 and device_id=2 and country_code='GB'").select("keyword_id").distinct().count()
# spark.read.parquet("s3://prod.appannie.mktint.data/oss/SEARCH_ADS_KEYWORD_SOV/routine/granularity=daily/date=2019-07-03/").filter("app_type='SINGLE_APP' and platform=1 and device_id=0 and country_code='US'").select(
#             'keyword_id').distinct().count()

# 's3://b2c-prod-data-pipeline-unified-aso/unified/app-tech.aso.sov-search-ads-keyword-fact.v1/metric/granularity=daily/date=2019-01-01/country_code=country_code/'

# unified data

# spark.read.parquet("s3://b2c-prod-data-pipeline-unified-aso/unified/app-tech.aso.sov-search-ads-keyword-fact.v1/metric/granularity=daily/date=2019-07-03/").where("app_type='SINGLE_APP' and device_code='android-all' and app_type='SINGLE_APP' and country_code='US'").show(20,False)

# spark.read.parquet("s3://b2c-prod-data-pipeline-unified-aso/unified/app-tech.aso.sov-search-ads-keyword-fact.v1/metric/granularity=daily/date=2019-07-03/").where(" country_code='GB' and app_type='SINGLE_APP' and device_code='ios-tablet'").select("keyword_id").distinct().count()

# spark.read.parquet("s3://b2c-prod-data-pipeline-unified-aso/unified/app-tech.aso.sov-search-ads-keyword-fact.v1/metric/granularity=daily/date=2019-07-03/").where("keyword_id=1944365 and app_type='SINGLE_APP' and device_code='ios-tablet' ").show(20,False)

# spark.read.parquet("s3://b2c-prod-data-pipeline-unified-aso/unified/app-tech.aso.sov-search-ads-keyword-fact.v1/metric/granularity=daily/date=2019-07-03/").where("keyword_id=1944365 and app_type='SINGLE_APP' and device_code='ios-tablet' and country_code='GB'").show(20,False)
# .select('app_id_list','sov_list','protect_status_list').show(10,False)
# .filter(f.array_contains("app_id_list",1336918844))

# spark.read.parquet("s3://b2c-prod-data-pipeline-unified-aso/unified/app-tech.aso.sov-search-ads-keyword-fact.v1/metric/granularity=daily/date=2019-07-03/").where("country_code='GB' and app_type='SINGLE_APP' and device_code='ios-all'").show()

# spark.read.parquet("s3://b2c-prod-data-pipeline-unified-aso/unified/app-tech.aso.sov-search-ads-keyword-fact.v1/metric/granularity=daily/date=2019-07-03/").where("country_code='US' and app_type='SINGLE_APP' and device_code='ios-tablet' and keyword_id=1274").show(20, False)


# spark.read.parquet("s3://b2c-prod-data-pipeline-unified-aso/unified/app-tech.aso.sov-search-ads-keyword-fact.v1/metric/granularity=daily/date=2019-07-03/").where("keyword_id=1944365 and app_type='SINGLE_APP' and device_code='ios-tablet' and country_code='GB' ").show(20,False)


# spark.read.parquet("s3://b2c-prod-data-pipeline-unified-aso/unified/app-tech.aso.sov-search-ads-keyword-fact.v1/metric/granularity=daily/date=2019-07-02/").where("app_type='SINGLE_APP' and device_code='ios-tablet' and country_code='US' and keyword_id=1387").show(20,False)
spark.read.parquet("s3://prod.appannie.mktint.data/oss/SEARCH_ADS_KEYWORD_SOV/routine/granularity=daily/date=2019-11-06/platform=2/app_type=SINGLE_APP/").where("country_code='US'").show()

# spark.read.parquet("s3://b2c-prod-data-pipeline-unified-aso/unified/app-tech.aso.sov-search-ads-keyword-fact.v1/metric/granularity=daily/date=2019-07-09/").where("keyword_id=1944365 and app_type='SINGLE_APP' and device_code='ios-tablet' and country_code='AU' ").show(20,False)

# %%
# %%sh
# aws s3 ls s3://prod.appannie.mktint.data/oss/SEARCH_ADS_KEYWORD_SOV/routine/granularity=daily/date=2019-11-06/platform=2/app_type=SINGLE_APP/

# %%
from datetime import datetime
from elasticsearch import Elasticsearch
import json
from aaintdatapipeline.application.app_qa.data_validation_v1.pysparktest import PySparkTest
import unittest
import random
from aaintdatapipeline.application.app_qa.data_validation_v1.utils import (get_aso_keyword_sov_raw_df_root,
                                                                           get_aso_keyword_sov_unified_df_root,
                                                                            )
from aaintdatapipeline.core.loader import es
from aaintdatapipeline.core.urn import Urn
from pyspark.sql.types import *
# es = Elasticsearch(["http://internal-aa-prod-int-elasticsearch-v5-1589259492.us-east-1.elb.amazonaws.com"],http_auth=("app_bdp_usage_qa","euIGw5c6cP3D"),port=19200)
# query={
#   "query": {
#     "bool": {
#       "must": [
#         {
#           "match": {
#             "device_code": "android-all"
#           }
#         },
#         {
#           "range": {
#             "date": {
#               "gte": "2019-07-01",
#               "lte": "2019-07-01"
#             }
#           }
#         }
#       ]
#     }
#   },
#   "stored_fields": [
#     "keyword_id"
#   ],
#   "sort": [
#     {
#       "keyword_id": "desc"
#     }
#   ]
# }

# res = es.search(index="aso-kpi-sov_search_ads_keyword_fact_v1_daily_jp*",body=query)

# json_result = json.dumps(res, indent=4)

# print str(res["hits"]["total"])

def get_count_by_date(device_code,keyword_id,start_date,end_date):
        get_count_json_query = {
            "query": {
                "bool": {
                    "must": [
                        {
                            "match": {
                                "device_code": "{}".format(device_code)
                            }
                        },
                        {
                            "match": {
                                "keyword_id": keyword_id
                            }
                        },
                        {
                            "range": {
                                "date": {
                                    "gte": "{}".format(start_date),
                                    "lte": "{}".format(end_date)
                                }
                            }
                        }
                    ]
                }
            },
            "stored_fields": [
                "date"
            ],
            "sort": [
                {
                    "date": "desc"
                }
            ]
        }
        return get_count_json_query

def get_count_by_date( device_code, keyword_id, test_date):
    get_single_result_query = {
        "query": {
            "bool": {
                "must": [
                    {
                        "match": {
                            "device_code": "{}".format(device_code)
                        }
                    },
                    {
                        "match": {
                            "keyword_id": keyword_id
                        }
                    }, {
                        "match": {
                            "date": "{}".format(test_date)
                        }
                    }
                ]
            }
        }
    }
    return get_single_result_query


def get_count_by_date( device_code, keyword_id, test_date):
    get_single_result_query = {
        "query": {
            "bool": {
                "must": [
                    {
                        "match": {
                            "device_code": "{}".format(device_code)
                        }
                    },
                    {
                        "match": {
                            "keyword_id": keyword_id
                        }
                    }, {
                        "match": {
                            "date": "{}".format(test_date)
                        }
                    }
                ]
            }
        }
    }
    return get_single_result_query

def get_keyword_count(device_code,test_date):
    get_keyword_count_query = {
        "query": {
            "bool": {
                "must": [
                    {
                        "match": {
                            "device_code": "{}".format(device_code)
                        }
                    },
                    {
                        "range": {
                            "date": {
                                "gte": "{}".format(test_date),
                                "lte": "{}".format(test_date)
                            }
                        }
                    }
                ]
            }
        },
        "stored_fields": [
            "keyword_id"
        ],
        "sort": [
            {
                "keyword_id": "desc"
            }
        ]
    }
    return get_keyword_count_query


def get_es_search_data( query, country_code):
    res = es.search(index="aso-kpi-sov_search_ads_keyword_fact_v1_daily_{}*".format(country_code.lower()), body=query)
    return res


def setUp(self):
    super(TestSOVSearchAdsKeywordsES, self).setUp()


def prepare_data(self):
    es_connection = Elasticsearch(["http://internal-aa-prod-int-elasticsearch-v5-1589259492.us-east-1.elb.amazonaws.com"],http_auth=("app_bdp_usage_qa","euIGw5c6cP3D"),port=19200)
    return es_connection



aso_sov_raw_bucket = "prod.appannie.mktint.data"
aso_sov_raw_bucket_path = "s3://{}/oss/SEARCH_ADS_KEYWORD_SOV/routine/granularity={}/date={}/platform={}/app_type={}/"

range_type = "routine"
daily = "2019-07-15"
weekly = "2019-08-24"
monthly = "2019-07-31"
platform = 2
app_type = "SINGLE_APP"
granularity = "daily"


app_type = "SINGLE_APP"
granularity_daily = "daily"
granularity_weekly = "weekly"
granularity_monthly = "monthly"


country_code_list = ["US", "GB", "JP", "KR", "DE", "CA",  "MX", "AU", "IN", "ID", "FR", "IT", "ES", "TH", "TW",
      "HK", "SE", "DK", "NO", "FI", "NZ"]

country_code_ios_list = ["US", "GB", "JP", "KR", "DE", "CA", "MX", "AU", "IN", "ID", "FR", "IT", "ES", "TH", "TW",
      "HK", "SE", "DK", "NO", "FI", "NZ"]

country_code_android_list = ["US", "GB", "JP", "KR", "DE", "CA", "BR", "MX", "RU", "AU", "IN", "ID", "FR", "IT", "ES", "TH", "TW",
      "HK", "TR", "SE", "DK", "NO", "FI", "NZ"]

country_code = random.sample(country_code_list, 1)[0]
print "use country code : "
print country_code


aso_sov_raw_parquet_path = get_aso_keyword_sov_raw_df_root(aso_sov_raw_bucket_path, aso_sov_raw_bucket,
                                                           granularity, daily,
                                                           platform, app_type)


aso_sov_raw_weekly_parquet_path = get_aso_keyword_sov_raw_df_root(aso_sov_raw_bucket_path, aso_sov_raw_bucket,
                                                           granularity_weekly, weekly,
                                                           platform, app_type)


aso_sov_raw_monthly_parquet_path = get_aso_keyword_sov_raw_df_root(aso_sov_raw_bucket_path, aso_sov_raw_bucket,
                                                           granularity_monthly, monthly,
                                                           platform, app_type)


urn = Urn(
    namespace='app-qa.db-check.v1',
    owner='app_qa'
)



### different country
def test_android_all_daily_single_sov_keyword_count_with_different_country():
    print 'test android all daily single sov test keyword count with different country'
    for country_iterate in country_code_android_list:
        print country_iterate
        expected_count = spark.read.parquet(aso_sov_raw_parquet_path.split("platform")[0]).filter(
            "app_type='SINGLE_APP' and platform=1 and device_id=0 and country_code='{}'".format(
                country_iterate)).select("keyword_id").distinct().count()
        db_count = get_es_search_data(get_keyword_count("android-all" , daily),country_iterate)
        
        print db_count["hits"]["total"]
        print expected_count
        # assertNotEqual(expected_count, 0)
        # assertEqual(expected_count, db_count, msg='{}~{}'.format(expected_count, db_count))
        

def get_es_search_data_performance(query):
    common_config = {
        "database": "aso_sov"
    }
    con_es= es.connection(urn, common_config)
    res = con_es.search(index="aso-kpi-sov_search_ads_keyword_fact_v1_daily_us*", body=query)
    return res

query_30_keyword_breakdown={"query":{"bool":{"must":[{"match":{"device_code":"ios-phone"}},{"match":{"date":"2019-07-01"}},{"terms":{"keyword_id":[477,501,632,633,682,1010,1084,1128,1142,1167,1191,1222,1350,1355,1361,1388,1481,1544,1549,1570,1601,1612,1812,1948,1958,2376,2606,2610]}},{"terms":{"app_id_list":["545519333"]}}]}}}


query_300_keyword_breakdown={"query":{"bool":{"must":[{"match":{"device_code":"ios-phone"}},{"match":{"date":"2019-07-01"}},{"terms":{"keyword_id":[31,59,204,263,297,410,477,501,632,633,682,1010,1084,1128,1142,1167,1191,1222,1350,1355,1361,1388,1481,1544,1549,1570,1601,1612,1812,1948,1958,2376,2606,2610,2772,2817,3196,3528,3587,3866,3975,4314,4441,4633,5259,8416,8467,8660,10338,10495,10674,10684,10697,11920,12510,12663,14239,14635,15406,15408,15626,15634,15737,16123,16279,16624,16687,16847,18266,18274,18324,18331,18385,18428,18615,18666,20050,20320,20340,20431,20700,21396,21437,21821,22273,22608,22934,23953,25051,25505,25772,25817,26903,27659,27790,28856,29027,29614,30283,30718,31110,32359,33368,33465,34720,35312,36710,38379,38517,40837,47663,54528,57448,57711,60872,67167,87806,87820,87999,88892,89526,92286,106576,111930,113027,116490,118834,121281,122147,125477,134412,135793,137813,146329,148157,149551,158067,165600,167002,167714,175551,194493,194869,200787,203542,203817,223918,225351,226614,227198,228182,231592,232962,237621,243560,250942,251882,268404,276353,276356,278267,280780,285266,303511,312437,316384,333984,335153,342458,356009,357887,374452,374720,377737,379262,385085,389552,392475,393582,396059,396105,417512,420925,425302,426976,441391,441430,441433,449700,459155,461716,474167,483993,489253,495649,502538,503685,504361,512023,512897,518253,519613,520568,532562,541018,541467,547292,547466,551951,553994,554080,555372,559661,559914,562100,563140,565654,571522,577878,581520,582030,582092,586083,592973,595582,595919,601895,602688,604282,604472,623496,627817,628803,634790,637598,653066,655832,665013,665955,670804,672606,674159,687093,693815,696505,703788,708967,710400,712058,717682,723637,725576,729019,735797,738623,739641,741880,742044,746768,750943,763470,772689,774317,780177,781124,782473,788305,806815,816642,827353,830803,831556,837866,843602,844615,849008,849089,849718,856052,865947,868467,869647,877524,882574,886023,888862,891156,895846,902247,904779,904901,906486,907377,912424,916122,924592,940354,958963,960932,960962]}},{"terms":{"app_id_list":["545519333"]}}]}}}



query_800_keyword_breakdown={"query":{"bool":{"must":[{"match":{"device_code":"ios-phone"}},{"match":{"date":"2019-07-01"}},{"terms":{"keyword_id":[31,59,204,263,297,410,477,501,632,633,682,1010,1084,1128,1142,1167,1191,1222,1350,1355,1361,1388,1481,1544,1549,1570,1601,1612,1812,1948,1958,2376,2606,2610,2772,2817,3196,3528,3587,3866,3975,4314,4441,4633,5259,8416,8467,8660,10338,10495,10674,10684,10697,11920,12510,12663,14239,14635,15406,15408,15626,15634,15737,16123,16279,16624,16687,16847,18266,18274,18324,18331,18385,18428,18615,18666,20050,20320,20340,20431,20700,21396,21437,21821,22273,22608,22934,23953,25051,25505,25772,25817,26903,27659,27790,28856,29027,29614,30283,30718,31110,32359,33368,33465,34720,35312,36710,38379,38517,40837,47663,54528,57448,57711,60872,67167,87806,87820,87999,88892,89526,92286,106576,111930,113027,116490,118834,121281,122147,125477,134412,135793,137813,146329,148157,149551,158067,165600,167002,167714,175551,194493,194869,200787,203542,203817,223918,225351,226614,227198,228182,231592,232962,237621,243560,250942,251882,268404,276353,276356,278267,280780,285266,303511,312437,316384,333984,335153,342458,356009,357887,374452,374720,377737,379262,385085,389552,392475,393582,396059,396105,417512,420925,425302,426976,441391,441430,441433,449700,459155,461716,474167,483993,489253,495649,502538,503685,504361,512023,512897,518253,519613,520568,532562,541018,541467,547292,547466,551951,553994,554080,555372,559661,559914,562100,563140,565654,571522,577878,581520,582030,582092,586083,592973,595582,595919,601895,602688,604282,604472,623496,627817,628803,634790,637598,653066,655832,665013,665955,670804,672606,674159,687093,693815,696505,703788,708967,710400,712058,717682,723637,725576,729019,735797,738623,739641,741880,742044,746768,750943,763470,772689,774317,780177,781124,782473,788305,806815,816642,827353,830803,831556,837866,843602,844615,849008,849089,849718,856052,865947,868467,869647,877524,882574,886023,888862,891156,895846,902247,904779,904901,906486,907377,912424,916122,924592,940354,958963,960932,960962,968905,974868,978947,988999,1005983,1014862,1029902,1037006,1049956,1075745,1083160,1088502,1098480,1108263,1117487,1122926,1123566,1146687,1146942,1147367,1149879,1151361,1163560,1164660,1173500,1176472,1191912,1198880,1202153,1207045,1213549,1221765,1245463,1281228,1296951,1297998,1299907,1321741,1323638,1340629,1340740,1344293,1347520,1354280,1356954,1364499,1368590,1373000,1375968,1379722,1384181,1389299,1395717,1418099,1427767,1429544,1431385,1434673,1440285,1448360,1450429,1459508,1462379,1469286,1469946,1471296,1477849,1480538,1480683,1486793,1488583,1488908,1489137,1492703,1503039,1507005,1507231,1509095,1509882,1510266,1518523,1522861,1524696,1527478,1532685,1533311,1544789,1546370,1551708,1553089,1561446,1563473,1564582,1570259,1571997,1576130,1576586,1576957,1577332,1577999,1579851,1585627,1585668,1586697,1587099,1588778,1590702,1590704,1592077,1592973,1594106,1598180,1598851,1600069,1600097,1601980,1609523,1609945,1611934,1612048,1619282,1621869,1629379,1632192,1634436,1636044,1637014,1640811,1643304,1648367,1649452,1656359,1664972,1676983,1678203,1680474,1685766,1704823,1708912,1714739,1726953,1735429,1736622,1737496,1738233,1741131,1750487,1753137,1753900,1759682,1760895,1761311,1767787,1775024,1777237,1780016,1782876,1794676,1795790,1805257,1807071,1807650,1813857,1815457,1815995,1823478,1828874,1830717,1837824,1844743,1855139,1861509,1865781,1866900,1872872,1880237,1882827,1887715,1899107,1899324,1900332,1902468,1902632,1909718,1914122,1914977,1921470,1955144,1955360,1962218,1968892,1979502,1997280,2001773,2002021,2005779,2022290,2023589,2029553,2030544,2039962,2058482,2064771,2100606,2102583,2106319,2106693,2114781,2119700,2127263,2129009,2129999,2137072,2143194,2146168,2154554,2162016,2166466,2170543,2172255,2193844,2198745,2202784,2205448,2205745,2207477,2223132,2225800,2228372,2228674,2230689,2231397,2231745,2233734,2239695,2240499,2242743,2246368,2248569,2255522,2266107,2267755,2281373,2294622,2303154,2304072,2316435,2317681,2325500,2325713,2327838,2337628,2339620,2346721,2352219,2355116,2357859,2359644,2361412,2372590,2372969,2374320,2377313,2377908,2378081,2379348,2381593,2384462,2388219,2389636,2393572,2394798,2396255,2398737,2402605,2407962,2413138,2414472,2417817,2419104,2419207,2420178,2429603,2435442,2531405,2553513,2560037,2595759,2602320,2620788,2625236,2675516,2689408,2707549,2744795,2763331,2768673,2826826,2827393,2900108,2904434,2957645,2982334,2985627,2990336,2993809,2995176,3010056,3010495,3020403,3026250,3027460,3041832,3048133,3072802,3121312,3144880,3207233,3221122,3231452,3234291,3252154,3270003,3284999,3306911,3310634,3373693,3376272,3412263,3424144,3475717,3488487,3523287,3556156,3561409,3565081,3571330,3645026,3651859,3675427,3686545,3690708,3696940,3713363,3717950,3741783,3742172,3790264,3822562,3827618,3839173,3862858,3869725,3874935,3901639,3901776,3918731,3955038,3973655,3974583,3975871,3977962,3981570,4009526,4020753,4024682,4029249,4029812,4040737,4067101,4107209,4109393,4117148,4133380,4173539,4193888,4252037,4254604,4315750,4323889,4362269,4364325,4394807,4443947,4452259,4470410,4473385,4480580,4510622,4526692,4537249,4554904,4561347,4577439,4595774,4656770,4672220,4689776,4697859,4736620,4767940,4797270,4806027,4845293,4849198,4876731,4879129,4879593,4901729,4915330,4989896,4989925,4990416,4990511,4990531,4990723,4990744,4990800,4990903,4991132,4991328,4991339,4991340,4991341,4991454,4991644,4991737,4991878,4992337,4992368,4992536,4992737,4992738,4993113,4993931,4993933,4993977,4993978,4994491,4994500,4994528,4994651,4994852,4995388,4995484,4995605,4995755,4995868,4995949,4996110,4996477,4996726,4997581,4997609,4997656,4998034,4998549,4998552,4998580,4998646,4999519,4999597,4999598,4999600,4999689,4999710,4999751,4999802,4999803,4999908,4999943,5000065,5000121,5000214,5000437,5000684,5001274,5001510,5001770,5001845,5001987,5002228,5002405,5002514,5002515,5002840,5002847,5002936,5003102,5003468,5003481,5003618,5003934,5004430,5004431,5004593,5004687,5004745,5005508,5005558]}},{"terms":{"app_id_list":["545519333"]}}]}}}


query_10_product_breakdown={"query":{"bool":{"must":[{"match":{"device_code":"ios-phone"}},{"match":{"date":"2019-07-01"}},{"terms":{"keyword_id":[960932]}},{"terms":{"app_id_list":[1396178579,1460390567,486781045,1055315077,545519333,1452065363,1208421834,302584613,1179872144,1251322970]}}]}}}

query_30_product_breakdown={"query":{"bool":{"must":[{"match":{"device_code":"ios-phone"}},{"match":{"date":"2019-07-01"}},{"terms":{"keyword_id":[263]}},{"terms":{"app_id_list":[1396178579,1460390567,486781045,1055315077,545519333,1452065363,1208421834,302584613,1179872144,1251322970,415850124,621574163,1470364946,1121463708,1326618359,991809759,1297066486,1276437113,1044683357,1469175283,1465864100,535811906,768469908,694431263,1232461700,1152477906,498127541,1200529449,962194608,569077959
]}}]}}}


query_30_date_product_breakdown={"query":{"bool":{"must":[{"match":{"device_code":"ios-phone"}},{"range":{"date":{"gte":"2019-07-01","lte":"2019-08-01"}}},{"terms":{"keyword_id":[18428]}},{"terms":{"app_id_list":[1396178579,1460390567,486781045,1055315077,545519333,1452065363,1208421834,302584613,1179872144,1251322970,415850124,621574163,1470364946,1121463708,1326618359,991809759,1297066486,1276437113]}}]}}}


query_78_date_product_breakdown={"query":{"bool":{"must":[{"match":{"device_code":"ios-phone"}},{"range":{"date":{"gte":"2019-07-01","lte":"2019-09-09"}}},{"terms":{"keyword_id":[18428]}},{"terms":{"app_id_list":[1396178579,1460390567,486781045,1055315077,545519333,1452065363,1208421834,302584613,1179872144,1251322970,415850124,621574163,1470364946,1121463708,1326618359,991809759,1297066486,1276437113]}}]}}}



# performance test
def calculate_time():
    # sql_list=[query_30_keyword_breakdown, query_300_keyword_breakdown,query_800_keyword_breakdown,query_10_product_breakdown,query_30_product_breakdown,query_30_date_product_breakdown,query_78_date_product_breakdown]
    sql_list=[query_30_keyword_breakdown]

    for sql in sql_list:
        print "### ### ### ### ### ###"
        result={}
        response_time=[]
        for x in range(2):
            db_count = get_es_search_data_performance(sql)
            result[x]=db_count["took"],db_count["hits"]["total"]
            response_time.append(db_count["took"])
        print response_time
        df=spark.createDataFrame(response_time,IntegerType())
        # percentile(elapsed, 0.95)
        df.selectExpr('avg(value)', "min(value)","max(value)","percentile(value, 0.95)").show()
        # df.selectExpr('min(value)').show()
        # df.selectExpr('max(value)').show()
        # df.selectExpr('percentile(value, 0.95)').show()

        # print result
        # print "avrg"
        # print sum(response_time)/len(response_time)
        # print "min"
        # print min(response_time)
        # print "max"
        # print max(response_time)
        
# result_df.createOrReplaceTempView("table1")
# df2 = spark.sql("SELECT name, count(name) / (max(start) - min(start)) * 60 as rpm, avg(length) as result_count, count(elapsed) as count, avg(elapsed) as avg, max(elapsed) as max, min(elapsed) as min, percentile(elapsed, 0.95) as 95p from table1 group by name")`
# test_android_all_daily_single_sov_keyword_count_with_different_country()
calculate_time()

# test_android_all_daily_single_sov_keyword_count_with_different_country()

# %%
# %%sh
#
#
# # day=04
# # curl -u app_bdp_usage_qa:euIGw5c6cP3D -XGet http://internal-aa-prod-int-elasticsearch-v5-1589259492.us-east-1.elb.amazonaws.com:19200/aso-kpi-sov_search_ads_keyword_fact_v1_daily_nz*/_search?pretty -d '
# # {
# # "query":
# #     {
# #         "bool":
# #             {
# #                 "must":
# #                     [
# #                         {"match":
# #                             {
# #                                 "device_code": "ios-phone"
# #                             }
# #                         },
# #                         {"match":
# #                             {
# #                                 "date": "2019-07-14"
# #                             }
# #                         },
# #                         {"match":
# #                             {
# #                                 "keyword_id": 1944365
# #                             }
# #                         }
# #                     ]
# #             }
# #     }
# # }
# # '
#
# # done
# # curl -u app_bdp_usage_qa:euIGw5c6cP3D -XGet http://internal-aa-prod-int-elasticsearch-v5-1589259492.us-east-1.elb.amazonaws.com:19200/aso-kpi-sov_search_ads_keyword_fact_v1*/_search?size=50 -d '{
#
#
#
#
#
#
#
#
# # ES_UDS_GENERAL_ACCESS_ID = 'app_bdp_usage_qa'
# # ES_UDS_GENERAL_SECRET_KEY = 'euIGw5c6cP3D'

# %%
import datetime
from collections import defaultdict
from elasticsearch import Elasticsearch

from aaintdatapipeline.application.app_qa.common.utils import get_random_day_in_last_month, datetime_to_string, \
    get_random_day_in_last_week, get_week_start_end_date, send_data_source_date_email, get_month_start_end_date, \
    string_to_datetime

from aaintdatapipeline.core.loader import es
from aaintdatapipeline.core.urn import Urn
from aaintdatapipeline.core.utils.spark import canned_spark, stop
from dateutil.relativedelta import relativedelta

# country_code_list=["us","gb","jp","fr","au"]
# device_code_list=["ios-phone","android-all","ios-tablet"]
# today = datetime.date.today()
# date = today #- datetime.timedelta(days=1)

urn = Urn(
    namespace='app-qa.db-check.v1',
    owner='app_qa'
)


def check_aso_sov_data():
    params={"project_name":"All_Products"}
    country_code_list = ["us", "gb", "jp", "fr", "au"]
    device_code_list = ["ios-phone", "android-all", "ios-tablet"]
    today = datetime.date.today() - datetime.timedelta(days=5)
    date = today - datetime.timedelta(days=2)
    failed_ids = defaultdict(list)
    project_name = params['project_name']
    if project_name == 'All_Products':
        # check daily
        for device_code in device_code_list:
            for country_code in country_code_list:
                query_body = {
                    "query": {"bool": {"must": [{"match": {"device_code": device_code}}, {"match": {"date": date}}]}},
                    "sort": [{"date": {"order": "desc", "mode": "max"}}]}
                res = check_aso_sov_db(country_code, query_body)
                print "{} - {} - {}".format(date,country_code,res["hits"]["total"])
                if not res["hits"]["total"]:
                    failed_ids["daily {} {}".format(date, device_code)].append(country_code)
                    
        # check weekly and monthly            
        sov_dict_list = get_granularity_date(today)
        print sov_dict_list
        if sov_dict_list:
            for granularity, granularity_date in sov_dict_list.iteritems():
                print granularity
                print granularity_date
                for device_code in device_code_list:
                    for country_code in country_code_list:
                        query_body = {
                            "query": {"bool": {
                                "must": [{"match": {"device_code": device_code}}, {"match": {"date": granularity_date}}]}},
                            "sort": [{"date": {"order": "desc", "mode": "max"}}]}
                        res = check_aso_sov_db(country_code, query_body, granularity=granularity)
                        print res
                        if not res["hits"]["total"]:
                            failed_ids["{} {} {} - ".format(granularity,granularity_date, device_code)].append(country_code)
        return failed_ids


def check_aso_sov_db(country_code, query_body,granularity="daily"):
    common_config = {
        "database": "aso_sov"
    }
    es_conn = es.connection(urn, common_config)
    res = es_conn.search(index="aso-kpi-sov_search_ads_keyword_fact_v1_{}_{}_*".format(granularity,country_code.lower()),
                         body=query_body)
    return res

def get_granularity_date(today):
    print today
    granularity_dic= {}
    if today.isoweekday() == 5:
        week_date = today - datetime.timedelta(days=6)
        granularity_dic["weekly"]=week_date
    if today.day == 6:
        month_date = datetime.date(today.year, today.month, 1) - relativedelta(days=1)
        granularity_dic["monthly"]=month_date
    print granularity_dic
    return granularity_dic

check_aso_sov_data()

# %%
from datetime import datetime
from elasticsearch import Elasticsearch
import json
from aaintdatapipeline.application.app_qa.data_validation_v1.pysparktest import PySparkTest
import unittest
import random
from aaintdatapipeline.application.app_qa.data_validation_v1.utils import (get_aso_keyword_sov_raw_df_root,
                                                                           get_aso_keyword_sov_unified_df_root,
                                                                            )
from aaintdatapipeline.core.loader import es
from aaintdatapipeline.core.urn import Urn
from pyspark.sql.types import *

def get_es_search_data( query, country_code):
    res = es.search(index="aso-kpi-sov_search_ads_keyword_fact_v1_daily_{}*".format(country_code.lower()), body=query)
    return res


def setUp(self):
    super(TestSOVSearchAdsKeywordsES, self).setUp()


def prepare_data(self):
    es_connection = Elasticsearch(["http://internal-aa-prod-int-elasticsearch-v5-1589259492.us-east-1.elb.amazonaws.com"],http_auth=("app_bdp_usage_qa","euIGw5c6cP3D"),port=19200)
    return es_connection
urn = Urn(
    namespace='app-qa.db-check.v1',
    owner='app_qa'
)

def get_es_search_data_performance(query):
    common_config = {
        "database": "aso_sov"
    }
    con_es= es.connection(urn, common_config)
    res = con_es.search(index="aso-kpi-sov_search_ads_keyword_fact_v1_daily_us*", body=query)
    return res

def calculate_time():
    # query_30_keyword_breakdown={"query":{"bool":{"must":[{"match":{"device_code":"ios-phone"}}]}},"aggs":{"aggregate_keyword":{"terms":{"field":"date","order":{"_term":"desc"},"size":2000}}},"size":0}
            # {"query":{"bool":{"must":[{"match":{"device_code":"android-all"}},{"range":{"sov_list":{"gt":1}}}]}}}
    # query_30_keyword_breakdown={"query":{"bool":{"must":[{"match":{"device_code":"android-all"}},{"range":{"sov_list":{"gt":1}}}]}}}
    query_30_keyword_breakdown={"query":{"bool":{"must":[{"match":{"device_code":"android-all"}},{"match":{"keyword_id":"2058582"}},{"match":{"date":"2019-07-02"}}]}}}
    sql_list=[query_30_keyword_breakdown]

    for sql in sql_list:
        print "### ### ### ### ### ###"
        result={}
        data_list=[]
        db_count = get_es_search_data_performance(sql)
        print db_count["hits"]["hits"][0]["_source"]["app_id_list"]
calculate_time()

# %%
from datetime import datetime
import datetime
from elasticsearch import Elasticsearch
import json
from aaintdatapipeline.application.app_qa.data_validation_v1.pysparktest import PySparkTest
import unittest
import random
from aaintdatapipeline.application.app_qa.data_validation_v1.utils import (get_aso_keyword_sov_raw_df_root,
                                                                           get_aso_keyword_sov_unified_df_root,
                                                                            )
from aaintdatapipeline.core.loader import es
from aaintdatapipeline.core.urn import Urn
from pyspark.sql.types import *

def get_es_search_data( query, country_code):
    res = es.search(index="aso-kpi-sov_search_ads_keyword_fact_v1_daily_{}*".format(country_code.lower()), body=query)
    return res


def setUp(self):
    super(TestSOVSearchAdsKeywordsES, self).setUp()


def prepare_data(self):
    es_connection = Elasticsearch(["http://internal-aa-prod-int-elasticsearch-v5-1589259492.us-east-1.elb.amazonaws.com"],http_auth=("app_bdp_usage_qa","euIGw5c6cP3D"),port=19200)
    return es_connection
urn = Urn(
    namespace='app-qa.db-check.v1',
    owner='app_qa'
)

def get_es_search_data_performance(query):
    common_config = {
        "database": "aso_sov"
    }
    con_es= es.connection(urn, common_config)
    res = con_es.search(index="aso-kpi-sov_search_ads_keyword_fact_v1_daily_us*", body=query)
    return res

def calculate_time():
    today = datetime.datetime.today()
    date_delta = z.input("previously_days")
    date_start = today + datetime.timedelta(0-int(date_delta)-1)
    print date_start.date()
    print today.date()

    # print "%table {}\t{}\t{}\t ".format( "db_date", "device_code_db" , "all_count_db")
    query={"query":{"bool":{"must":[{"range":{"date":{"gte":date_start.date(),"lte":today.date()}}}]}},"aggs":{"aggregate_keyword":{"terms":{"field":"date","order":{"_term":"desc"},"size":2000},"aggs":{"device":{"terms":{"field":"device_code","order":{"_term":"desc"},"size":2000}}}}},"size":0}
    result={}
    data_list=[]
    db_count = get_es_search_data_performance(query)
    range_length = len(db_count["aggregations"]["aggregate_keyword"]["buckets"])
    for i in range(0,range_length):
        db_date=db_count["aggregations"]["aggregate_keyword"]["buckets"][i]["key_as_string"]
        for x in range (0,3):
            device_code_db = db_count["aggregations"]["aggregate_keyword"]["buckets"][i]["device"]["buckets"][x]["key"]
            all_count_db = db_count["aggregations"]["aggregate_keyword"]["buckets"][i]["device"]["buckets"][x]["doc_count"]
            # print "{}\t{}\t{}\t".format(db_date, device_code_db, all_count_db)


calculate_time()

# %%
from datetime import datetime
import datetime
from elasticsearch import Elasticsearch
import json
from aaintdatapipeline.application.app_qa.data_validation_v1.pysparktest import PySparkTest
import unittest
import random
from aaintdatapipeline.application.app_qa.data_validation_v1.utils import (get_aso_keyword_sov_raw_df_root,
                                                                           get_aso_keyword_sov_unified_df_root,
                                                                            )
from aaintdatapipeline.core.loader import es
from aaintdatapipeline.core.urn import Urn
from pyspark.sql.types import *

def get_es_search_data( query, country_code):
    res = es.search(index="aso-kpi-sov_search_ads_keyword_fact_v1_daily_{}*".format(country_code.lower()), body=query)
    return res


def setUp(self):
    super(TestSOVSearchAdsKeywordsES, self).setUp()


def prepare_data(self):
    es_connection = Elasticsearch(["http://internal-aa-prod-int-elasticsearch-v5-1589259492.us-east-1.elb.amazonaws.com"],http_auth=("app_bdp_usage_qa","euIGw5c6cP3D"),port=19200)
    return es_connection
urn = Urn(
    namespace='app-qa.db-check.v1',
    owner='app_qa'
)

def get_es_search_data_performance(query):
    common_config = {
        "database": "aso_sov"
    }
    con_es= es.connection(urn, common_config)
    res = con_es.search(index="aso-kpi-sov_search_ads_keyword_fact_v1_daily_us*", body=query)
    return res

def calculate_time():
    today = datetime.datetime.today()
    date_delta = z.input("previously_days")
    date_start = today + datetime.timedelta(0-int(date_delta)-1)
    print date_start.date()
    print today.date()

    print "%table {}\t{}\t{}\t ".format( "db_date", "device_code_db" , "all_count_db")
    query={"query":{"bool":{"must":[{"range":{"date":{"gte":date_start.date(),"lte":today.date()}}}]}},"aggs":{"aggregate_keyword":{"terms":{"field":"date","order":{"_term":"desc"},"size":2000},"aggs":{"device":{"terms":{"field":"device_code","order":{"_term":"desc"},"size":2000}}}}},"size":0}
    result={}
    data_list=[]
    db_count = get_es_search_data_performance(query)
    range_length = len(db_count["aggregations"]["aggregate_keyword"]["buckets"])
    for i in range(0,range_length):
        db_date=db_count["aggregations"]["aggregate_keyword"]["buckets"][i]["key_as_string"]
        for x in range (0,3):
            device_code_db = db_count["aggregations"]["aggregate_keyword"]["buckets"][i]["device"]["buckets"][x]["key"]
            all_count_db = db_count["aggregations"]["aggregate_keyword"]["buckets"][i]["device"]["buckets"][x]["doc_count"]
            print "{}\t{}\t{}\t".format(db_date, device_code_db, all_count_db)


calculate_time()

# %%
# %%sh
# # aws s3 ls s3://prod.appannie.mktint.data/oss/SEARCH_VOLUME/routine/granularity=daily/date=2017-07-06/platform=1/
# # aws s3 ls s3://prod.appannie.mktint.data/oss/KEYWORD_DIFFICULTY/routine/granularity=daily/date=2017-07-06/platform=1/
# # aws s3 ls s3://b2c-prod-data-pipeline-unified-aso/unified/app-tech.aso.keyword-difficulty-search-volume.v1/fact/granularity=daily/date=2017-07-06/device_code=android-all/
#
# # aws s3 ls s3://prod.appannie.mktint.data/
# # aws s3 ls s3://prod_appannie_android/country-ranks/
#
# # aws s3 ls s3://b2c-prod-data-pipeline-unified-aso/unified/
# # aws s3 ls s3://prod.appannie.mktint.data/oss/SEARCH_ADS_KEYWORD_SOV/routine/granularity=daily/date=2019-10-12/platform=1/app_type=SINGLE_APP/
# aws s3 ls s3://prod.appannie.mktint.data/mkt_ad_app_impression/granularity=WEEK/

# %%
spark.read.parquet("s3://prod.appannie.mktint.data/mkt_ad_app_impression/granularity=WEEK/date=2019-11-09/").show()

# %%
# %%sh
# PGPASSWORD='rn*Wh%osCl2C' psql -h internal-aa-citus-mkt-elb-1511434527.us-east-1.elb.amazonaws.com  -U citus_mkt_qa -d aa_mkt_db -p 7432 << EOF
# \dn
# set search_path=market;
# select * from market_pub_app_impression_fact_v1 where device_code='android-tablet' limit 3;
#
# EOF

# %%
raw_result = spark.read.parquet("s3://b2c-prod-advanced-review/oss/ADVRVW_TOPIC_EFFECTIVE_PREDICTIONS/").filter("country='US' and language='en'").distinct().count()
print raw_result
