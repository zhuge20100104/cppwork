# %%
COUNTRY_MAPPING = {
    'gp': {1: 'AU', 2: 'CA', 3: 'CN', 4: 'DE', 5: 'ES', 6: 'FR', 7: 'GB',
        8: 'IT', 9: 'JP', 10: 'US', 11: 'BE', 12: 'CH', 13: 'CL', 14: 'ZA',
        15: 'VN', 16: 'HK', 17: 'AR', 18: 'BR', 19: 'IN', 20: 'FI', 21: 'ID',
        22: 'RU', 23: 'NL', 24: 'MY', 25: 'TR', 26: 'MX', 27: 'KR', 28: 'PL',
        29: 'TH', 30: 'TW', 31: 'PH', 32: 'SG', 33: 'EG', 34: 'SE', 35: 'AT',
        36: 'CZ', 37: 'HU', 38: 'DK', 39: 'IE', 40: 'IL', 41: 'NZ', 42: 'NO',
        43: 'PT', 44: 'RO', 45: 'SK', 46: 'GR', 47: 'BG', 48: 'UA', 49: 'AE',
        50: 'KW', 51: 'SA', 52: 'CO', 53: 'KZ', 54: 'PK', 56: 'PE', 61: 'AZ',
        62: 'EC', 64: 'CR', 65: 'LB', 73: 'QA', 74: 'NG', 78: 'LT', 80: 'HR',
        86: 'LV', 95: 'KE', 1000: 'WW'},
    'ios': {143441: 'US', 143442: 'FR', 143443: 'DE', 143444: 'GB', 143445: 'AT',
        143446: 'BE', 143447: 'FI', 143448: 'GR', 143449: 'IE', 143450: 'IT',
        143451: 'LU', 143452: 'NL', 143453: 'PT', 143454: 'ES', 143455: 'CA',
        143456: 'SE', 143457: 'NO', 143458: 'DK', 143459: 'CH', 143460: 'AU',
        143461: 'NZ', 143462: 'JP', 143463: 'HK', 143464: 'SG', 143465: 'CN',
        143466: 'KR', 143467: 'IN', 143468: 'MX', 143469: 'RU', 143470: 'TW',
        143471: 'VN', 143472: 'ZA', 143473: 'MY', 143474: 'PH', 143475: 'TH',
        143476: 'ID', 143477: 'PK', 143478: 'PL', 143479: 'SA', 143480: 'TR',
        143481: 'AE', 143482: 'HU', 143483: 'CL', 143484: 'NP', 143485: 'PA',
        143486: 'LK', 143487: 'RO', 143489: 'CZ', 143491: 'IL', 143492: 'UA',
        143493: 'KW', 143494: 'HR', 143495: 'CR', 143496: 'SK', 143497: 'LB',
        143498: 'QA', 143499: 'SI', 143501: 'CO', 143502: 'VE', 143503: 'BR',
        143504: 'GT', 143505: 'AR', 143506: 'SV', 143507: 'PE', 143508: 'DO',
        143509: 'EC', 143510: 'HN', 143511: 'JM', 143512: 'NI', 143513: 'PY',
        143514: 'UY', 143515: 'MO', 143516: 'EG', 143517: 'KZ', 143518: 'EE',
        143519: 'LV', 143520: 'LT', 143521: 'MT', 143523: 'MD', 143524: 'AM',
        143525: 'BW', 143526: 'BG', 143528: 'JO', 143529: 'KE', 143530: 'MK',
        143531: 'MG', 143532: 'ML', 143533: 'MU', 143534: 'NE', 143535: 'SN',
        143536: 'TN', 143537: 'UG', 143538: 'AI', 143539: 'BS', 143540: 'AG',
        143541: 'BB', 143542: 'BM', 143543: 'VG', 143544: 'KY', 143545: 'DM',
        143546: 'GD', 143547: 'MS', 143548: 'KN', 143549: 'LC', 143550: 'VC',
        143551: 'TT', 143552: 'TC', 143553: 'GY', 143554: 'SR', 143555: 'BZ',
        143556: 'BO', 143557: 'CY', 143558: 'IS', 143559: 'BH', 143560: 'BN',
        143561: 'NG', 143562: 'OM', 143563: 'DZ', 143564: 'AO', 143565: 'BY',
        143566: 'UZ', 143568: 'AZ', 143571: 'YE', 143572: 'TZ', 143573: 'GH',
        143575: 'AL', 143576: 'BJ', 143577: 'BT', 143578: 'BF', 143579: 'KH',
        143580: 'CV', 143581: 'TD', 143582: 'CG', 143583: 'FJ', 143584: 'GM',
        143585: 'GW', 143586: 'KG', 143587: 'LA', 143588: 'LR', 143589: 'MW',
        143590: 'MR', 143591: 'FM', 143592: 'MN', 143593: 'MZ', 143594: 'NA',
        143595: 'PW', 143597: 'PG', 143598: 'ST', 143599: 'SC', 143600: 'SL',
        143601: 'SB', 143602: 'SZ', 143603: 'TJ', 143604: 'TM', 143605: 'ZW',
        0: 'WW'},
}

CATEGORY_MAPPING = {
    "mac-os-mac": {
        39: 200000,
        12001: 200001,
        12002: 200002,
        12003: 200003,
        12004: 200004,
        12005: 200005,
        12006: 200006,
        12007: 200007,
        12008: 200008,
        12010: 200009,
        12011: 200010,
        12012: 200011,
        12013: 200012,
        12014: 200013,
        12015: 200014,
        12016: 200015,
        12017: 200016,
        12018: 200017,
        12019: 200018,
        12020: 200019,
        12021: 200020,
        12022: 200021,
        12201: 200022,
        12202: 200023,
        12203: 200024,
        12204: 200025,
        12205: 200026,
        12206: 200027,
        12207: 200028,
        12208: 200029,
        12209: 200030,
        12210: 200031,
        12211: 200032,
        12212: 200033,
        12213: 200034,
        12214: 200035,
        12215: 200036,
        12216: 200037,
        12217: 200038,
        12218: 200039,
        12219: 200040,
    }
}

class AppStoreRankRawData():
    bucket_name = ""
    bucket_path = ""
    data_split_str = ""
    rank_split_str = ""
    accept_feeds = []

    def get_raw_data_by_date(self, date, filter_country=None, filter_category=None):
        """
        :return: raw_data_frame
        :rtype: list_of_dic
        raw_data:
        _________________________________________________________________________________
        |    date    |   country_id   |  category_id  |   feed_id   |   rank (app_id)   |
        |------------|----------------|---------------|-------------|-------------------|
        | 2019-04-27 | 143441(bigint) |   6016 (int)  |   0 (int)   | 376510438(bigint) |
        ---------------------------------------------------------------------------------
        unified_data:
        _____________________________________________________________________________________
        |  country_code  |   category_id   |       app_id       | feed_name (free_download) |
        |----------------|-----------------|--------------------|---------------------------|
        |      'US'      | 100026 (bigint) | 376510438 (bigint) |    25 (int) (app_rank)    |
        -------------------------------------------------------------------------------------
        """
        path = "{_bucket_path}/{_date}/23/".format(_date=date, _bucket_path=self.bucket_path)
        bucket = rank_bucket(self.bucket_name)
        raw_df = []
        count = 0
        category=[]
        country=[]
        country_dict = {}
        category_dict = {}
        date_dict = {}
        for key in bucket.list(path):
            if 'md5' in key or 'SUCCESS' in key:
                continue
            raw_data = zlib.decompress(bucket.get(key))
            for _data in raw_data.splitlines():
                data = _data.split(self.data_split_str)
                # remove tv data
                if int(data[3]) not in self.accept_feeds:
                    continue
                rank_list = [rank for rank in data[4].split(self.rank_split_str) if rank.strip() != '']
                # tbd
                rank_list = list(dict.fromkeys(rank_list))
                if len(data) == 5:
                    data_dic = {
                        'date': data[0],
                        'country': data[1],
                        'category': data[2],
                        'feed': data[3],
                        'rank': rank_list
                    }
                    count += len(data_dic['rank'])
                    
                    
                    country_code = COUNTRY_MAPPING["ios"][int(data_dic['country'])]
                    category_id = CATEGORY_MAPPING['mac-os-mac'][int(data_dic['category'])]
                    date = data_dic["date"]
                    if country_code not in country_dict:
                        country_dict[country_code] = {}
                    if category_id not in country_dict[country_code]:
                        country_dict[country_code][category_id] = 0
                    if date not in date_dict:
                        date_dict[date] = 0
                    date_dict[date]+=len(data_dic['rank'])
                    country_dict[country_code][category_id] += len(data_dic['rank'])
                    if filter_country == country_code and filter_category == category_id:
                        print data_dic
                    

                    # country.append(data_dic['country'])
                    # category.append(data_dic['category'])
                    # country_code = COUNTRY_MAPPING['ios'][int(data_dic['country'])]
                    # # if country_code not in country_dict:
                    # #     country_dict[country_code] = 0
                    # # country_dict[country_code] += len(data_dic['rank'])
                    # if country_code=="MS":
                    #     print data_dic
                    #     if data_dic["category"] not in category_dict:
                    #         category_dict[data_dic["category"]] = 0
                    #     category_dict[data_dic["category"]] += len(data_dic["rank"])
                    # print count
                    # raw_df.append(data_dic)
                else:
                    print("Error: The length of raw data is wrong, length is {}.".format(len(data)))
        # return country_dict
        return date_dict
        return count
        # print len(set(country))
        # print len(set(category))
        # print country_dict
        # print category_dict
        # return raw_df


class IosPhoneRaw(AppStoreRankRawData):
    bucket_name = "prod_appannie_ios"
    bucket_path = "country-ranks"
    data_split_str = "\t"
    rank_split_str = " "
    accept_feeds = [0, 1, 2]


class IosTabletRaw(AppStoreRankRawData):
    bucket_name = "prod_appannie_ios"
    bucket_path = "country-ranks"
    data_split_str = "\t"
    rank_split_str = " "
    accept_feeds = [101, 100, 102]


class MacTabletRaw(AppStoreRankRawData):
    bucket_name = "prod_appannie_ios"
    bucket_path = "mac/country-ranks"
    data_split_str = "\t"
    rank_split_str = " "
    accept_feeds = [200, 201, 202]


def rank_bucket(bucket_str):
    """
    Get Bucket Object from bucket string
    :param bucket_str: string like: s3://xxx.xxx
    :type bucket_str: str
    :return: bucket_object
    :rtype: bucket_object
    """
    conf = Conf(
        bucket_name=bucket_str,
        bucket_class=S3Bucket
    )
    return specified_bucket(conf)

# %%
from pyspark.sql import functions as F


APP_STORE_RANK_METRICS = ["free_download", "new_paid_download", "revenue", "paid_download", "new_free_download"]


# df_unified = df.filter("country_code='MS'").groupBy("category_id").agg(F.count("free_download").alias("free_download_count"),F.count("paid_download").alias("paid_download_count"), F.count("revenue").alias("revenue_count")).collect()

# # for item in df_unified:
#     # print "{},{}".format(item.category_id, sum([item.free_download_count, item.paid_download_count, item.revenue_count]))

# raw_result = {200000: 257, 200001: 33, 200002: 13, 200003: 13, 200004: 10, 200005: 9, 200006: 56, 200007: 3, 200008: 7, 200009: 3, 200010: 23, 200011: 4, 200012: 16, 200013: 78, 200014: 7, 200015: 16, 200016: 3, 200017: 4, 200018: 59, 200019: 27, 200020: 3, 200021: 17, 200022: 20, 200023: 19, 200024: 9, 200025: 7, 200026: 8, 200027: 3, 200028: 3, 200029: 3, 200030: 6, 200031: 3, 200032: 3, 200033: 12, 200034: 3, 200035: 6, 200036: 10, 200037: 4, 200038: 7, 200039: 4, 200040: 5}

# for item in df_unified:
#     category_id = int(item.category_id)
#     print "{} {} {}".format(category_id, raw_result[category_id], sum([item.free_download_count, item.paid_download_count, item.revenue_count]) )
    


# continue
def get_unified_count_by_date(date_str):
    device_code = "mac-os-mac"
    df = spark.read.parquet("s3://b2c-prod-data-pipeline-unified-store-free/unified/app-tech.store.app-rank.v1/fact/date={}/device_code={}/".format(date_str, device_code))
    count = 0
    for metric in APP_STORE_RANK_METRICS:
        # df.show(1)
        count += df.filter("{} is not null".format(metric)).count()
    return count

# %%
def get_date_list(begin_date, end_date, freq):
    date_list = [x.strftime('%Y-%m-%d') for x in list(pd.date_range(start=begin_date, end=end_date, freq=freq))]
    return date_list

begin_date = datetime.datetime.strptime("2012-12-27", '%Y-%m-%d')
end_date = datetime.datetime.strptime("2019-11-26", '%Y-%m-%d')
date_list = get_date_list(begin_date, end_date, "D")

print "%table date\tr_count\tu_count\tdiff"

for date_str in date_list:
    try:
        u_count = get_unified_count_by_date(date_str)
        r_count = MacTabletRaw().get_raw_data_by_date(date_str)
        print "{}\t{}\t{}\t{}".format(date_str, r_count, u_count, r_count-u_count)
    except Exception as e:
        print "{}\t{}\t{}\t{}".format(date_str, 0, 0, -100)

# %%
print "%table date\tr_count\tu_count\tdiff"

date_list = ["2014-09-14", "2014-09-15", "2014-09-16", "2014-09-17", "2014-09-18", "2014-09-19", "2014-09-20", "2014-09-21", "2014-09-22", "2014-09-23", "2014-10-03", "2014-10-04", "2014-10-16", "2014-10-17", "2014-11-04", "2014-11-05", "2014-11-19", "2014-11-20", "2014-11-21", "2019-07-29", "2019-08-24", "2019-09-30", "2019-10-01"]

for date_str in date_list:
    try:
        u_count = get_unified_count_by_date(date_str)
        r_count = MacTabletRaw().get_raw_data_by_date(date_str)
        print "{}\t{}\t{}\t{}".format(date_str, r_count, u_count, r_count-u_count)
    except Exception as e:
        print "{}\t{}\t{}\t{}".format(date_str, 0, 0, -10)
        print e.msg

# %%
device_code = "mac-os-mac"

for date_str in date_list:
    df = spark.read.parquet("s3://b2c-prod-data-pipeline-unified-store-free/unified/app-tech.store.app-rank.v1/fact/date={}/device_code={}/".format(date_str, "mac-os-mac"))
    df_unified = df.groupBy(["country_code","category_id"]).agg(F.count("free_download").alias("free_download_count"),F.count("paid_download").alias("paid_download_count"), F.count("revenue").alias("revenue_count")).collect()
    raw_result = MacTabletRaw().get_raw_data_by_date(date_str)
    unified_result = {}
    for data in df_unified:
        unified_count = sum([data.free_download_count, data.paid_download_count, data.revenue_count])
        diff_count = raw_result[data.country_code][data.category_id]-unified_count
        if diff_count !=0:
            print "{} {} {} {}".format(date_str, data.country_code,data.category_id, diff_count)

# %%
df = spark.read.parquet("s3://b2c-prod-data-pipeline-unified-store-free/unified/app-tech.store.app-rank.v1/fact/date={}/device_code={}/".format("2014-09-14", "mac-os-mac"))
df_unified = df.filter("country_code='AR' and category_id=200032").groupBy(["country_code","category_id"]).agg(F.count("free_download").alias("free_download_count"),F.count("paid_download").alias("paid_download_count"), F.count("revenue").alias("revenue_count")).collect()
df.filter("country_code='AR' and category_id=200032").orderBy("free_download").show(100)
for data in  df_unified:
    print data.free_download_count
    print data.paid_download_count
    print data.revenue_count

MacTabletRaw().get_raw_data_by_date("2014-09-14", filter_country="AR", filter_category=200032)

# %%
# %%sh
#
# aws s3 ls s3://b2c-prod-data-pipeline-unified-store-free/unified/app-tech.store.app-rank.v1/fact/date=2014-09-14/device_code=mac-os-mac/

# %%
import datetime
from aaintdatapipeline.core.conf import Conf
from aaintdatapipeline.core.fs.device import S3Bucket, specified_bucket
import zlib
import pandas as pd
import numpy as np

columns = ['date','country_code', 'category_id', 'metrics', 'rank_list']
country_code_mapping = {143441: 'US', 143442: 'FR', 143443: 'DE', 143444: 'GB', 143445: 'AT',
            143446: 'BE', 143447: 'FI', 143448: 'GR', 143449: 'IE', 143450: 'IT',
            143451: 'LU', 143452: 'NL', 143453: 'PT', 143454: 'ES', 143455: 'CA',
            143456: 'SE', 143457: 'NO', 143458: 'DK', 143459: 'CH', 143460: 'AU',
            143461: 'NZ', 143462: 'JP', 143463: 'HK', 143464: 'SG', 143465: 'CN',
            143466: 'KR', 143467: 'IN', 143468: 'MX', 143469: 'RU', 143470: 'TW',
            143471: 'VN', 143472: 'ZA', 143473: 'MY', 143474: 'PH', 143475: 'TH',
            143476: 'ID', 143477: 'PK', 143478: 'PL', 143479: 'SA', 143480: 'TR',
            143481: 'AE', 143482: 'HU', 143483: 'CL', 143484: 'NP', 143485: 'PA',
            143486: 'LK', 143487: 'RO', 143489: 'CZ', 143491: 'IL', 143492: 'UA',
            143493: 'KW', 143494: 'HR', 143495: 'CR', 143496: 'SK', 143497: 'LB',
            143498: 'QA', 143499: 'SI', 143501: 'CO', 143502: 'VE', 143503: 'BR',
            143504: 'GT', 143505: 'AR', 143506: 'SV', 143507: 'PE', 143508: 'DO',
            143509: 'EC', 143510: 'HN', 143511: 'JM', 143512: 'NI', 143513: 'PY',
            143514: 'UY', 143515: 'MO', 143516: 'EG', 143517: 'KZ', 143518: 'EE',
            143519: 'LV', 143520: 'LT', 143521: 'MT', 143523: 'MD', 143524: 'AM',
            143525: 'BW', 143526: 'BG', 143528: 'JO', 143529: 'KE', 143530: 'MK',
            143531: 'MG', 143532: 'ML', 143533: 'MU', 143534: 'NE', 143535: 'SN',
            143536: 'TN', 143537: 'UG', 143538: 'AI', 143539: 'BS', 143540: 'AG',
            143541: 'BB', 143542: 'BM', 143543: 'VG', 143544: 'KY', 143545: 'DM',
            143546: 'GD', 143547: 'MS', 143548: 'KN', 143549: 'LC', 143550: 'VC',
            143551: 'TT', 143552: 'TC', 143553: 'GY', 143554: 'SR', 143555: 'BZ',
            143556: 'BO', 143557: 'CY', 143558: 'IS', 143559: 'BH', 143560: 'BN',
            143561: 'NG', 143562: 'OM', 143563: 'DZ', 143564: 'AO', 143565: 'BY',
            143566: 'UZ', 143568: 'AZ', 143571: 'YE', 143572: 'TZ', 143573: 'GH',
            143575: 'AL', 143576: 'BJ', 143577: 'BT', 143578: 'BF', 143579: 'KH',
            143580: 'CV', 143581: 'TD', 143582: 'CG', 143583: 'FJ', 143584: 'GM',
            143585: 'GW', 143586: 'KG', 143587: 'LA', 143588: 'LR', 143589: 'MW',
            143590: 'MR', 143591: 'FM', 143592: 'MN', 143593: 'MZ', 143594: 'NA',
            143595: 'PW', 143597: 'PG', 143598: 'ST', 143599: 'SC', 143600: 'SL',
            143601: 'SB', 143602: 'SZ', 143603: 'TJ', 143604: 'TM', 143605: 'ZW',
            0: 'WW'}

category_id_mapping = {
        39: 200000,
        12001: 200001,
        12002: 200002,
        12003: 200003,
        12004: 200004,
        12005: 200005,
        12006: 200006,
        12007: 200007,
        12008: 200008,
        12010: 200009,
        12011: 200010,
        12012: 200011,
        12013: 200012,
        12014: 200013,
        12015: 200014,
        12016: 200015,
        12017: 200016,
        12018: 200017,
        12019: 200018,
        12020: 200019,
        12021: 200020,
        12022: 200021,
        12201: 200022,
        12202: 200023,
        12203: 200024,
        12204: 200025,
        12205: 200026,
        12206: 200027,
        12207: 200028,
        12208: 200029,
        12209: 200030,
        12210: 200031,
        12211: 200032,
        12212: 200033,
        12213: 200034,
        12214: 200035,
        12215: 200036,
        12216: 200037,
        12217: 200038,
        12218: 200039,
        12219: 200040,
    }

metrics_mapping = {
    200: 'free_download',
    201: 'paid_download',
    202: 'revenue'
}

path = "country-ranks/2016-10-31/23/"
bucket = rank_bucket("prod_appannie_android")
# prod_appannie_ios/mac/country-ranks/2014-09-15/23/
_raw_data_list = []
for key in bucket.list(path):
    _raw_data = zlib.decompress(bucket.get(key))
    for _line in _raw_data.splitlines():
        line_data = _line.split(",")
        _raw_data_list.append(line_data)
    
df = pd.DataFrame(_raw_data_list, columns=columns)
# df['rank_list'] = df['rank_list'].str.split()
# df["country_code"] = pd.to_numeric(df["country_code"])
# df["category_id"] = pd.to_numeric(df["category_id"])
# df["metrics"] = pd.to_numeric(df["metrics"])


df = df.replace({"country_code": country_code_mapping, "category_id": category_id_mapping, "metrics": metrics_mapping })

print set(df["date"].tolist())

# %%
from aaintdatapipeline.core.conf import Conf

df = spark.read.csv('s3://prod_appannie_ios/mac/country-ranks/2014-11-05/23/143441', sep='\t', header='false')
_raw_data = zlib.decompress(bucket.get(key))

# %%
# %%sh
#
# aws s3 ls s3://prod_appannie_ios/mac/country-ranks/2014-09-15/23/

# %%
# %%sh
#
# aws s3 ls s3://prod_appannie_ios/mac/country-ranks/2014-09-12/23/

# %%
import datetime
from aaintdatapipeline.core.conf import Conf
from aaintdatapipeline.core.fs.device import S3Bucket, specified_bucket
import zlib
import pandas as pd
import numpy as np

columns = ['date','country_code', 'category_id', 'metrics', 'rank_list']
country_code_mapping = {143441: 'US', 143442: 'FR', 143443: 'DE', 143444: 'GB', 143445: 'AT',
            143446: 'BE', 143447: 'FI', 143448: 'GR', 143449: 'IE', 143450: 'IT',
            143451: 'LU', 143452: 'NL', 143453: 'PT', 143454: 'ES', 143455: 'CA',
            143456: 'SE', 143457: 'NO', 143458: 'DK', 143459: 'CH', 143460: 'AU',
            143461: 'NZ', 143462: 'JP', 143463: 'HK', 143464: 'SG', 143465: 'CN',
            143466: 'KR', 143467: 'IN', 143468: 'MX', 143469: 'RU', 143470: 'TW',
            143471: 'VN', 143472: 'ZA', 143473: 'MY', 143474: 'PH', 143475: 'TH',
            143476: 'ID', 143477: 'PK', 143478: 'PL', 143479: 'SA', 143480: 'TR',
            143481: 'AE', 143482: 'HU', 143483: 'CL', 143484: 'NP', 143485: 'PA',
            143486: 'LK', 143487: 'RO', 143489: 'CZ', 143491: 'IL', 143492: 'UA',
            143493: 'KW', 143494: 'HR', 143495: 'CR', 143496: 'SK', 143497: 'LB',
            143498: 'QA', 143499: 'SI', 143501: 'CO', 143502: 'VE', 143503: 'BR',
            143504: 'GT', 143505: 'AR', 143506: 'SV', 143507: 'PE', 143508: 'DO',
            143509: 'EC', 143510: 'HN', 143511: 'JM', 143512: 'NI', 143513: 'PY',
            143514: 'UY', 143515: 'MO', 143516: 'EG', 143517: 'KZ', 143518: 'EE',
            143519: 'LV', 143520: 'LT', 143521: 'MT', 143523: 'MD', 143524: 'AM',
            143525: 'BW', 143526: 'BG', 143528: 'JO', 143529: 'KE', 143530: 'MK',
            143531: 'MG', 143532: 'ML', 143533: 'MU', 143534: 'NE', 143535: 'SN',
            143536: 'TN', 143537: 'UG', 143538: 'AI', 143539: 'BS', 143540: 'AG',
            143541: 'BB', 143542: 'BM', 143543: 'VG', 143544: 'KY', 143545: 'DM',
            143546: 'GD', 143547: 'MS', 143548: 'KN', 143549: 'LC', 143550: 'VC',
            143551: 'TT', 143552: 'TC', 143553: 'GY', 143554: 'SR', 143555: 'BZ',
            143556: 'BO', 143557: 'CY', 143558: 'IS', 143559: 'BH', 143560: 'BN',
            143561: 'NG', 143562: 'OM', 143563: 'DZ', 143564: 'AO', 143565: 'BY',
            143566: 'UZ', 143568: 'AZ', 143571: 'YE', 143572: 'TZ', 143573: 'GH',
            143575: 'AL', 143576: 'BJ', 143577: 'BT', 143578: 'BF', 143579: 'KH',
            143580: 'CV', 143581: 'TD', 143582: 'CG', 143583: 'FJ', 143584: 'GM',
            143585: 'GW', 143586: 'KG', 143587: 'LA', 143588: 'LR', 143589: 'MW',
            143590: 'MR', 143591: 'FM', 143592: 'MN', 143593: 'MZ', 143594: 'NA',
            143595: 'PW', 143597: 'PG', 143598: 'ST', 143599: 'SC', 143600: 'SL',
            143601: 'SB', 143602: 'SZ', 143603: 'TJ', 143604: 'TM', 143605: 'ZW',
            0: 'WW'}

category_id_mapping = {
        39: 200000,
        12001: 200001,
        12002: 200002,
        12003: 200003,
        12004: 200004,
        12005: 200005,
        12006: 200006,
        12007: 200007,
        12008: 200008,
        12010: 200009,
        12011: 200010,
        12012: 200011,
        12013: 200012,
        12014: 200013,
        12015: 200014,
        12016: 200015,
        12017: 200016,
        12018: 200017,
        12019: 200018,
        12020: 200019,
        12021: 200020,
        12022: 200021,
        12201: 200022,
        12202: 200023,
        12203: 200024,
        12204: 200025,
        12205: 200026,
        12206: 200027,
        12207: 200028,
        12208: 200029,
        12209: 200030,
        12210: 200031,
        12211: 200032,
        12212: 200033,
        12213: 200034,
        12214: 200035,
        12215: 200036,
        12216: 200037,
        12217: 200038,
        12218: 200039,
        12219: 200040,
    }

metrics_mapping = {
    200: 'free_download',
    201: 'paid_download',
    202: 'revenue'
}

path = "mac/country-ranks/2014-09-15/23/"
bucket = rank_bucket("prod_appannie_ios")

_raw_data_list = []
for key in bucket.list(path):
    _raw_data = zlib.decompress(bucket.get(key))
    for _line in _raw_data.splitlines():
        line_data = _line.split("\t")
        if line_data[0] == "2014-09-14":
            print key
            break
        _raw_data_list.append(_line.split("\t"))
    
df = pd.DataFrame(_raw_data_list, columns=columns)
df['rank_list'] = df['rank_list'].str.split()
df["country_code"] = pd.to_numeric(df["country_code"])
df["category_id"] = pd.to_numeric(df["category_id"])
df["metrics"] = pd.to_numeric(df["metrics"])


df = df.replace({"country_code": country_code_mapping, "category_id": category_id_mapping, "metrics": metrics_mapping })

print set(df["date"].tolist())
