# %%
# %%sh
# curl -u app_bdp_usage_qa:'euIGw5c6cP3D' -XGet http://internal-aa-prod-int-elasticsearch-v5-1589259492.us-east-1.elb.amazonaws.com:19200/int-ss-rating-apple-store-*/_search?pretty -d '
# {
#   "query": {
#     "bool": {
#       "filter": [
#         {
#           "terms": {
#             "product_id": [
#               284882215
#             ]
#           }
#         },
#
#         {
#           "terms": {
#             "country_code": [
#               "US"
#             ]
#           }
#         },
#         {
#           "range": {
#             "date": {
#               "lte": "2019-09-01"
#             }
#           }
#         }
#       ]
#     }
#   }
# }
# '

# %%
# %%sh
