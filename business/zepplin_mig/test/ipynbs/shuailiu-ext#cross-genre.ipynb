# %%
# %%sh
# aws s3 ls s3://aardvark-prod-pdx-to-int-usage-cohorts/retention/retention_batch_D7_routine/v3.0.0/MONTH/2020-08-31/RRD0/US/

# %%
spark.read.parquet("s3://aardvark-prod-dca-data/oss/GAME_CROSS_GENRE_KPI_PARQUET/version=1.0.6/range_type=MONTH/date=2020-07-31/platform=1/").show(10)

# %%
df = spark.read.csv("s3://aardvark-prod-pdx-to-int-usage-cohorts/retention/retention_batch_D7_routine/v3.0.0/MONTH/2020-08-31/RRD0/US/")
df.count()
