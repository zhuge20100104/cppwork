# %%
# %%sh
# PGPASSWORD='wZw8cfBuuklIskVG' psql -h 10.2.6.141 -U citus_bdp_prod_app_int_qa -d aa_store_db -p 5432 << EOF
# set search_path=dna;
# -- select distinct(app_id) from dna_app_tag_dim_v3 where tag_id=7875700000002 and app_id in (1163925890, 575658129, 949701151, 727420266, 1106014973, 932500451, 981305941, 570306657, 444844790, 1039141908, 1073698593, 737006024, 623592465, 1030902626,1005765746, 937976391, 20600008711561, 20600011045171);
# -- select * from dna_app_tag_dim_v3 where tag_id=7875700000002;
# select count(1) from dna_app_tag_dim_v3 where tag_type_code not in ('custom');
# EOF

# %%
# %sh
PGPASSWORD='wZw8cfBuuklIskVG' psql -h 10.2.6.141 -U citus_bdp_prod_app_int_qa -d aa_store_db -p 5432 << EOF
set search_path=stpre;
-- count(distinct(unified_app_id))
select distinct(tag_table.app_id) from dna_app_unified_dim_v3 right join 
(select app_id from dna_app_tag_dim_v2 where tag_id=1 ) tag_table on dna_app_unified_dim_v3.app_id=tag_table.app_id  where  dna_app_unified_dim_v3.unified_app_id is null limit 1000;
EOF

# %%
# %%sh
# PGPASSWORD='wZw8cfBuuklIskVG' psql -h 10.2.6.141 -U citus_bdp_prod_app_int_qa -d aa_store_db -p 5432 << EOF
# set search_path=store;
# -- count(distinct(unified_app_id))
# select app_id, sum(est_free_app_download), sum(est_paid_app_download)  from store_est_fact_v2 where date between '2020-09-12' and '2020-12-10'
# and device_code in ('ios-phone', 'ios-tablet', 'android-all')
# and country_code in ('BE', 'JP')
# and granularity = 'daily'
# and app_id in (553834731,20600000578686)
# -- and (est_paid_app_download is not null or est_free_app_download is not null)
# group by  app_id
#
#
# EOF

# %%
# %%sh
