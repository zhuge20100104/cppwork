# %%
# %%sh
# aws s3 ls s3://b2c-prod-data-pipeline-qa/aa.mobile.web.domain/2020-04-01/

# %%
spark.read.parquet("s3://b2c-prod-data-pipeline-qa/aa.mobile.web.domain/2020-03-25/").show()

# %%
print "test"
