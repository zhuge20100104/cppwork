# %%
# %%sh
# PGPASSWORD='wZw8cfBuuklIskVG' psql -h 10.2.10.254  -U citus_bdp_prod_app_int_qa -d aa_store_db -p 5432 << EOF
# set search_path=ugcpii;
# \d
# select * from ugcpii_custom_cate_dimension_v1   limit 3 ;

# %%
# %%sh
#
# PGPASSWORD='2mHdFW6%#REu' psql -h internal-aa-prod-plproxy-internal-4-329644124.us-east-1.elb.amazonaws.com -p 7432 -U app_bdp_usage_qa -d dailyest << EOF
# select  pub_id, category_id, date, app_id from plproxy.execute_select_nestloop(\$proxy\$
# select pub_id, category_id, date, app_id
#     from pp.pub_app_daily_associate_0
#     where date='2020-05-19'
#      limit 5 \$proxy\$) tbl
#       (pub_id BIGINT, category_id INTEGER, date DATE, app_id BIGINT)  limit 5 ;
#
# EOF

# %%
# %%sh
#
# PGPASSWORD='2mHdFW6%#REu' psql -h internal-aa-prod-plproxy-internal-4-329644124.us-east-1.elb.amazonaws.com -p 7432 -U app_bdp_usage_qa -d dailyest << EOF
# select  app_id,feed_id,store_id,estimate,category_id ,device_id, rank, date from plproxy.execute_select_nestloop(\$proxy\$
# select  distinct app_id,feed_id,store_id,estimate,category_id ,device_id, rank, date
#     from aa.app_store_daily_estimate_0
#     where
#       app_id = 20600003289877  and date between '2020-01-01' and '2020-01-01' and store_id=10 order by category_id asc, date desc limit 500 \$proxy\$) tbl
#       (app_id BIGINT,feed_id SMALLINT,store_id INT, estimate INT, category_id INT, device_id SMALLINT, rank INT, date Date ) order by category_id  asc, date desc limit 500 ;
#
# EOF

# %%
# %%sh
# # feed id
# # ‘iphone’: (1, (0, 1, 2)),
# #  ‘ipad’: (1, (100, 101, 102)),
# #  ‘gp’: (0, (0, 1, 2))
#
#
# # PGPASSWORD='2mHdFW6%#REu' psql -h internal-aa-prod-plproxy-internal-4-329644124.us-east-1.elb.amazonaws.com -p 7432 -U app_bdp_usage_qa -d dailyest << EOF
# # select distinct app_id,feed_id,store_id,estimate from plproxy.execute_select_nestloop(\$proxy\$
# #     select distinct app_id,feed_id,store_id,estimate
# #     from aa.app_store_daily_estimate_1
# #     where
# #       date = '2020-03-28'  and store_id='0'  limit 5
# # \$proxy\$) tbl (app_id BIGINT,feed_id SMALLINT,store_id INT, estimate INT)  limit 5 ;
#
# # EOF
#
#
#
#
#
#
#
#
# # PGPASSWORD='2mHdFW6%#REu' psql -h internal-aa-prod-plproxy-internal-4-329644124.us-east-1.elb.amazonaws.com -p 7432 -U app_bdp_usage_qa -d dailyest << EOF
# # select app_id, sum_est from plproxy.execute_select_nestloop(\$proxy\$
# #     select app_id, sum(estimate) as sum_est from aa.app_store_daily_estimate_1
# #     where  date in ( '2020-01-01' , '2020-01-02' )  and store_id=143441 and feed_id = 0  and category_id = 6014 group by app_id order by sum_est desc
# # \$proxy\$) tbl (app_id BIGINT,sum_est BIGINT)  order by sum_est desc limit 4000 ;
#
# # EOF
#
#
# # PGPASSWORD='2mHdFW6%#REu' psql -h internal-aa-prod-plproxy-internal-4-329644124.us-east-1.elb.amazonaws.com -p 7432 -U app_bdp_usage_qa -d dailyest << EOF
# # select  app_id,feed_id,store_id,estimate,category_id ,device_id from plproxy.execute_select_nestloop(\$proxy\$
# # select  distinct app_id,feed_id,store_id,estimate,category_id ,device_id
# #     from aa.app_store_daily_estimate_1
# #     where
# #       date = '2020-02-02' and store_id='143547' and feed_id = 0 and isunique='t' and device_id=1 order by estimate  asc limit 5 \$proxy\$) tbl
# #       (app_id BIGINT,feed_id SMALLINT,store_id INT, estimate INT, category_id INT, device_id SMALLINT ) order by estimate  asc limit 5 ;
#
# # EOF
#
#
#
# PGPASSWORD='2mHdFW6%#REu' psql -h internal-aa-prod-plproxy-internal-4-329644124.us-east-1.elb.amazonaws.com -p 7432 -U app_bdp_usage_qa -d dailyest << EOF
# select sum(cnt) from plproxy.execute_select_nestloop(\$proxy\$
#     select sum(estimate) as cnt
#     from ( select distinct app_id,feed_id,store_id,estimate,category_id,device_id from aa.app_store_daily_estimate_1
#     where date = '2019-12-05'  and  feed_id in (0) and isunique='t') as prod
# \$proxy\$) tbl (cnt bigint);
#
# select sum(cnt) from plproxy.execute_select_nestloop(\$proxy\$
#     select sum(estimate) as cnt
#     from ( select distinct app_id,feed_id,store_id,estimate,category_id,device_id from aa.app_store_daily_estimate_1
#     where date = '2019-12-05'  and  feed_id in (1) and isunique='t' ) as prod
# \$proxy\$) tbl (cnt bigint);
#
#
# select sum(cnt) from plproxy.execute_select_nestloop(\$proxy\$
#     select sum(estimate) as cnt
#     from ( select distinct app_id,feed_id,store_id,estimate,category_id,device_id from aa.app_store_daily_estimate_1
#     where date = '2019-12-05'  and  feed_id in (2) and isunique='t') as prod
# \$proxy\$) tbl (cnt bigint);
#
#
# select sum(cnt) from plproxy.execute_select_nestloop(\$proxy\$
#     select sum(estimate) as cnt
#     from ( select app_id,feed_id,store_id,estimate,category_id,device_id,rank from aa.app_store_daily_estimate_1
#     where date = '2019-12-05'  and  feed_id in (101) and isunique='t') as prod
# \$proxy\$) tbl (cnt bigint);
#
# select sum(cnt) from plproxy.execute_select_nestloop(\$proxy\$
#     select sum(estimate) as cnt
#     from ( select app_id,feed_id,store_id,estimate,category_id,device_id,rank from aa.app_store_daily_estimate_1
#     where date = '2019-12-05'  and  feed_id in (100) and isunique='t') as prod
# \$proxy\$) tbl (cnt bigint);
#
#
# select sum(cnt) from plproxy.execute_select_nestloop(\$proxy\$
#     select sum(estimate) as cnt
#     from ( select app_id,feed_id,store_id,estimate,category_id,device_id,rank from aa.app_store_daily_estimate_1
#     where date = '2019-12-05'  and  feed_id in (102)  and isunique='t') as prod
# \$proxy\$) tbl (cnt bigint);
#
#
#
#
# select sum(cnt) from plproxy.execute_select_nestloop(\$proxy\$
#     select sum(estimate) as cnt
#     from ( select app_id,feed_id,store_id,estimate,category_id,device_id,rank from aa.app_store_daily_estimate_0
#     where date = '2019-12-05'  and  feed_id in (0) and isunique='t') as prod
# \$proxy\$) tbl (cnt bigint);
#
# select sum(cnt) from plproxy.execute_select_nestloop(\$proxy\$
#     select sum(estimate) as cnt
#     from ( select app_id,feed_id,store_id,estimate,category_id,device_id,rank from aa.app_store_daily_estimate_0
#     where date = '2019-12-05'  and  feed_id in (1) and isunique='t') as prod
# \$proxy\$) tbl (cnt bigint);
#
#
# select sum(cnt) from plproxy.execute_select_nestloop(\$proxy\$
#     select sum(estimate) as cnt
#     from ( select app_id,feed_id,store_id,estimate,category_id,device_id,rank from aa.app_store_daily_estimate_0
#     where date = '2019-12-05'  and  feed_id in (2) and isunique='t') as prod
# \$proxy\$) tbl (cnt bigint);
#
#
# EOF

# %%
# %%sh
# PGPASSWORD='wZw8cfBuuklIskVG' psql -h 10.2.6.141  -U citus_bdp_prod_app_int_qa -d aa_store_db -p 5432 << EOF
# set search_path=store;
# select sum(est_free_app_download), sum(est_paid_app_download), sum(est_revenue),  sum(est_organic_download),  sum(est_paid_download) from store.store_est_fact_v1 where date='2019-12-05' and device_code='ios-phone' and granularity='daily' limit 3 ;
# select sum(est_free_app_download), sum(est_paid_app_download), sum(est_revenue),  sum(est_organic_download), sum(est_paid_download) from store.store_est_fact_v1 where date='2019-12-05' and device_code='ios-tablet' and granularity='daily' limit 3 ;
# select sum(est_free_app_download), sum(est_paid_app_download), sum(est_revenue),  sum(est_organic_download), sum(est_paid_download) from store.store_est_fact_v1 where date='2019-12-05' and device_code='android-all' and granularity='daily' limit 3 ;

# %%
# %%sh
#
# PGPASSWORD='2mHdFW6%#REu' psql -h internal-aa-prod-plproxy-internal-4-329644124.us-east-1.elb.amazonaws.com -p 7432 -U app_bdp_usage_qa -d dailyest << EOF
# select sum(cnt) from plproxy.execute_select_nestloop(\$proxy\$
#     select sum(estimate) as cnt
#     from ( select distinct app_id,feed_id,store_id,estimate,category_id,device_id, date from aa.app_store_daily_estimate_1
#     where date between '2019-12-01' and '2019-12-31'  and  feed_id in (0,1,2) and app_id=1062996947 and store_id=0) as prod
# \$proxy\$) tbl (cnt bigint);
#
# EOF

# %%
# %%sh
# PGPASSWORD='wZw8cfBuuklIskVG' psql -h 10.2.10.254  -U citus_bdp_prod_app_int_qa -d aa_store_db -p 5432 << EOF
# set search_path=store;
#
#
# -- select * from store.store_est_fact_v6 where est_free_app_download is null and est_paid_app_download is null  and granularity='daily' and date in ('2020-04-17','2020-04-18') ;
#
# -- select distinct country_code from store.store_est_category_fact_v6 where date='2018-02-02' and device_code='android-all' and granularity='daily'  ;
#
# --select sum(est_free_app_download), sum(est_paid_app_download), sum(est_revenue),  sum(est_organic_download), sum(est_paid_download) from store.store_est_category_fact_v6 where date='2018-04-01' and device_code='ios-phone' and granularity='daily'   limit 3 ;
# --select sum(est_free_app_download), sum(est_paid_app_download), sum(est_revenue),  sum(est_organic_download), sum(est_paid_download) from store.store_est_category_fact_v6 where date='2018-04-01' and device_code='ios-tablet' and granularity='daily'   limit 3 ;
# --select sum(est_free_app_download), sum(est_paid_app_download), sum(est_revenue), sum(est_organic_download), sum(est_paid_download) from store.store_est_category_fact_v6 where date='2018-04-01' and device_code='android-all' and granularity='daily'   limit 3 ;
#
# --select ( sum(est_free_app_download) + sum(est_paid_app_download) ) as total,   sum(est_organic_download), sum(est_paid_download) from store.store_est_fact_v6 where date='2018-04-01' and device_code='ios-phone' and granularity='daily'   limit 3 ;
#
#
# --select sum(est_free_app_download), sum(est_paid_app_download), sum(est_revenue), sum(est_organic_download), sum(est_paid_download) from store.store_est_category_fact_v6 where date='2020-04-01' and device_code='ios-phone' and granularity='daily' limit 3;;
# --select sum(est_free_app_download), sum(est_paid_app_download), sum(est_revenue), sum(est_organic_download), sum(est_paid_download) from store.store_est_category_fact_v6 where date='2020-04-01' and device_code='ios-tablet' and granularity='daily' limit 3; ;
# --select sum(est_free_app_download), sum(est_paid_app_download), sum(est_revenue), sum(est_organic_download), sum(est_paid_download) from store.store_est_category_fact_v6 where date='2020-04-01' and device_code='android-all' and granularity='daily' limit 3;
#
#
# -- select * from store.store_est_fact_v6 where est_free_app_download = 2 and est_revenue >5000 and country_code='WW' and date='2020-04-01' and app_id = 1282971607 limit 3;
# -- select * from store.store_est_category_fact_v6 where app_id = 1282971607 and date='2020-04-01' and country_code='WW' limit 3;
#
#
#
#
# -- select * from store.store_est_fact_v6 where est_free_app_download is null and est_paid_app_download is null limit 3;
# -- select * from store.store_est_category_fact_v6 where est_free_app_download is null and est_paid_app_download is null limit 3;
#
# -- select * from store.store_est_fact_v6 where est_free_app_download is null and est_paid_app_download is not null limit 3;
# -- select * from store.store_est_category_fact_v6 where est_free_app_download is null and est_paid_app_download  is not null limit 3;
#
# -- select * from store.store_est_fact_v6 where est_free_app_download is not null and est_paid_app_download is null limit 3;
# -- select * from store.store_est_category_fact_v6 where est_free_app_download is not null and est_paid_app_download is null limit 3;
#
#
# --select * from store.store_est_fact_v6 where est_free_app_download is not null and est_paid_app_download is not null limit 3;
# --select * from store.store_est_category_fact_v6 where est_free_app_download is not null and est_paid_app_download is not null limit 3;
#
#
# --select * from store.store_est_category_fact_v6
# --right join est_free_app_download
# --where est_free_app_download is null
# --and est_paid_app_download is not null
# --and granularity='daily' and date in ('2020-04-16','2020-04-18','2020-04-19') limit 3;
#
# -- select * from store_est_category_fact_v6 where  app_id='1062996947' and country_code='WW' and date='2019-12-01'  limit 5;
#
# SELECT sum(est_free_app_download) as est_free_app_download_monthly , sum(est_revenue) as est_revenue_monthly
# FROM(
#     SELECT a.app_id, a.country_code, a.device_code, a.date, a.est_free_app_download, a.est_paid_app_download, a.est_revenue, b.category_id
#     FROM store.store_est_fact_v6 as a
# JOIN store.store_est_category_fact_v6 as b
# ON a.app_id = b.app_id
# AND a.country_code = b.country_code
# AND a.date = b.date
# AND a.device_code = b.device_code
# WHERE a.date between '2019-12-01' and '2019-12-31'
# AND a.country_code='WW'
# AND a.device_code='ios-tablet'
# AND a.app_id=570366534
# ) as prod
# EOF

# %%
# %%sh
# PGPASSWORD='wZw8cfBuuklIskVG' psql -h 10.2.10.254  -U citus_bdp_prod_app_int_qa -d aa_store_db -p 5432 << EOF
# set search_path=store;
#
# select * from store_est_category_fact_v6 where  app_id='570366534' and country_code='WW' and date='2019-12-01'  limit 5;
#
# EOF

# %%
# %%sh
# %%sh
# PGPASSWORD='wZw8cfBuuklIskVG' psql -h 10.2.10.254  -U citus_bdp_prod_app_int_qa -d aa_store_db -p 5432 << EOF
# set search_path=store;
# select sum(est_revenue) from store_est_fact_v6 where date in ( '2019-12-01','2019-12-02','2019-12-03','2019-12-04','2019-12-05') and  est_revenue is not null  and est_free_app_download is null and est_paid_app_download is null limit 3;
# select sum(est_revenue) from store_est_fact_v6 where date in ( '2019-12-01','2019-12-02','2019-12-03','2019-12-04','2019-12-05') ;
#
# EOF
#
# # '2019-12-01','2019-12-02','2019-12-03','2019-12-04',

# %%
# %python
80955473.00/1763602476.00

# %%
# %%sh
#
#
# select * from store.store_est_fact_v6 where est_free_app_download is null and est_paid_app_download is null limit 3;
# select * from store.store_est_category_fact_v6 where est_free_app_download is null and est_paid_app_download is null limit 3;
#
# select * from store.store_est_fact_v6 where est_free_app_download is null and est_paid_app_download is not null limit 3;
# select * from store.store_est_category_fact_v6 where est_free_app_download is null and est_paid_app_download  is not null limit 3;
#
# select * from store.store_est_fact_v6 where est_free_app_download is not null and est_paid_app_download is null limit 3;
# select * from store.store_est_category_fact_v6 where est_free_app_download is not null and est_paid_app_download is null limit 3;
#
#
#
#
# PGPASSWORD='wZw8cfBuuklIskVG' psql -h 10.2.10.254  -U citus_bdp_prod_app_int_qa -d aa_store_db -p 5432 << EOF
# set search_path=store;
#
# select * from store.store_est_fact_v6 where est_free_app_download is  null and est_paid_app_download is null limit 3;
# select * from store.store_est_category_fact_v6 where est_free_app_download is  null and est_paid_app_download is null limit 3;
#
#
# select * from store.store_est_fact_v6 where est_free_app_download is  null and est_paid_app_download is not null limit 3;
# select * from store.store_est_category_fact_v6 where est_free_app_download is not null and est_paid_app_download is null limit 3;
#
# select * from store.store_est_fact_v6 where est_free_app_download =0  and est_paid_app_download is null limit 3;
# select * from store.store_est_category_fact_v6 where est_free_app_download is null and est_paid_app_download =0 limit 3;
#
# select * from store.store_est_fact_v6 where est_free_app_download =0  and est_paid_app_download=0 limit 3;
#
#
# select * from store.store_est_fact_v6 where est_free_app_download =1 and est_revenue >5000 and date='2020-03-15' limit 3;
# select * from store.store_est_category_fact_v6 where app_id = 20600007503687 and date='2020-03-15' and country_code='WW' limit 3
# select * from store.store_est_fact_v1 where est_free_app_download =1 and est_revenue >5000  limit 3;
#
# EOF

# %%
# %%sh
# PGPASSWORD='2mHdFW6%#REu' psql -h internal-aa-prod-plproxy-internal-4-329644124.us-east-1.elb.amazonaws.com -p 7432 -U app_bdp_usage_qa -d dailyest << EOF
# select app_id, store_id, device_id, est_organic_download_share from plproxy.execute_select_nestloop(\$proxy\$
# select distinct app_id,store_id, device_id, est_organic_download_share
#     from da.app_da_daily_estimate_2001 where date = '2020-08-01'
#      limit 5 \$proxy\$) tbl
#       (app_id BIGINT, store_id INT, device_id SMALLINT, est_organic_download_share FLOAT )  ;
#
# EOF

# %%
# %%sh
# PGPASSWORD='wZw8cfBuuklIskVG' psql -h 10.2.10.254  -U citus_bdp_prod_app_int_qa -d aa_store_db -p 5432 << EOF
# set search_path=store;
# explain (analyze true, buffers true)
# select store_est_fact_v6.*, store_est_category_fact_v6.*
# from store.store_est_category_fact_v6
# left join store.store_est_fact_v6
# on store_est_fact_v6.device_code = store_est_category_fact_v6.device_code
# and store_est_fact_v6.app_id = store_est_category_fact_v6.app_id
# and store_est_fact_v6.date = store_est_category_fact_v6.date
# and store_est_fact_v6.country_code = store_est_category_fact_v6.country_code
# where store_est_fact_v6.date='2018-04-01'
# limit 3
# EOF
#
# # select sum(est_free_app_download), sum(est_paid_app_download), sum(est_revenue),  sum(est_organic_download), sum(est_paid_download) from store.store_est_category_fact_v6 where date='2018-04-01' and device_code='ios-phone' and granularity='daily'   limit 3 ;

# %%
# %%sh
# PGPASSWORD='dNzWtSV3pKTx' psql -h 10.2.10.132 -p 5432 -U citus_bdp_usage_qa -d aa_citus_db << EOF
# SET search_path=advancedreview;
# --\d advancedreview_term_fact_v3
# select * from advancedreview_term_fact_v3 where country_code='US' limit 1;
# select * from advancedreview_topic_fact_v3 limit 1;
#
# EOF
#
# # explain (analyze true, buffers true)
# # select * from (
# # select advancedreview_topic_fact_v3.product_id, advancedreview_topic_fact_v3.topic_ids , advancedreview_term_fact_v3.terms
# # from advancedreview.advancedreview_topic_fact_v3
# # inner join advancedreview.advancedreview_term_fact_v3
# # on advancedreview_topic_fact_v3.product_id = advancedreview_term_fact_v3.product_id
# # where advancedreview_topic_fact_v3.date='2020-04-12' and advancedreview_topic_fact_v3.country_code='US'
# # limit 3
# # ) as test
# #  join advancedreview_topic_fact_v3
# # on advancedreview_topic_fact_v3.product_id = test.product_id

# %%
# %%sh
# PGPASSWORD='wZw8cfBuuklIskVG' psql -h 10.2.10.254  -U citus_bdp_prod_app_int_qa -d aa_store_db -p 5432 << EOF
# set search_path=store;
# select * from store.store_est_category_fact_v6
# left join store.store_est_fact_v6
# on store_est_fact_v6.device_code = store_est_category_fact_v6.device_code
# and store_est_fact_v6.app_id = store_est_category_fact_v6.app_id
# and store_est_fact_v6.date = store_est_category_fact_v6.date
# and store_est_fact_v6.country_code = store_est_category_fact_v6.country_code
# where store_est_fact_v6.date='2018-04-01'
# limit 3
# EOF

# %%
# %%sh
# PGPASSWORD='wZw8cfBuuklIskVG' psql -h 10.2.10.254  -U citus_bdp_prod_app_int_qa -d aa_store_db -p 5432 << EOF
# set search_path=ugcpii;
# select * from ugcpii_custom_cate_dimension_v1 limit 1
#
# EOF

# %%
# %%sh
