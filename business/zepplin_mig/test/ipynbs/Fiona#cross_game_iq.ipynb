# %%
# %%sh
# PGPASSWORD='wZw8cfBuuklIskVG' psql -h 10.2.6.141  -U citus_bdp_prod_app_int_qa -d aa_store_db -p 5432 << EOF
# set search_path=store;
#
# select *
# from store_est_publisher_fact_v2 where  date between '2020-01-01' and '2020-12-31'  and (company_id=1000200000003459 or parent_company_id=1000200000003459)
# limit 1
#
# EOF
#
# select count(1), sum(est_free_app_download), sum(est_revenue)
# from store_est_t_w_fact_v2 where  date between '2020-01-01' and '2020-12-31' and country_code = 'WW'  and (company_id=1000200000003459 or parent_company_id=1000200000003459)
#
# select app_id, count(1) from store_est_fact_v2 where  date between '2020-01-01' and '2020-12-31' and country_code = 'WW'  and app_id in ()
# group by app_id
#
#
#
#
# # select
# #     count(1)
# # from store_est_publisher_t_w_fact_v2
# # where
# #      date between '2020-01-01' and '2020-12-31'
#
# #      and country_code= 'WW'
# #   --  and category_id  in (100000,400000)
# #      and (company_id=1000200000003459 or parent_company_id=1000200000003459)
# #   --  order by date
# # --select * from store_est_fact_v2 where  date between '2020-01-01' and '2020-12-31' and country_code = 'WW'  limit 1
#
# # select
# #     category_id, count(1), sum(est_revenue)
# # from store_est_publisher_fact_v2
# # where
# #     date between '2020-01-01' and '2020-12-31'
#     # and country_code= 'WW'
#     # and category_id  in (100000,400000)
#     # and (company_id=1000200000003459 or parent_company_id=1000200000003459)
# #     group by category_id
# #     order by category_id
# # ;
#
# 45203160

# %%
spark.read.format("delta").load("s3://b2c-prod-data-pipeline-unified-dna/unified/dna.mapping-log.v1/dimension").where("update_date in ('2020-12-09', '2020-12-01') and company_id=1000200000229763 ").show()

# %%
# %%sh
# PGPASSWORD='wZw8cfBuuklIskVG' psql -h 10.2.6.141  -U citus_bdp_prod_app_int_qa -d aa_store_db -p 5432 << EOF
# set search_path=store;
# select
#     category_id, sum(est_revenue)
# from store_est_publisher_fact_v2
# where
#     date between '2020-01-01' and '2020-12-31'
#     and country_code= 'WW'
#     and category_id  in (100000,400000)
#     and (company_id=1000200000035578 or parent_company_id=1000200000035578)
# group by category_id
# order by category_id
# ;
#
#
# select
#     category_id, sum(est_revenue)
# from store_est_publisher_t_y_fact_v2
# where
#     date between '2020-01-01' and '2020-12-31'
#     and country_code= 'WW'
#     and category_id  in (100006, 100007, 400006, 400007, 100008, 400024)
#     and (company_id=1000200000035578 or parent_company_id=1000200000035578)
# group by category_id
# order by category_id
# limit 20;
#
# --select * from store_est_fact_v2 where  date between '2020-01-01' and '2020-12-31' and country_code = 'WW'  limit 1
#
# EOF
# # select app_id, count(1) from store_est_fact_v2 where  date between '2020-01-01' and '2020-12-31' and country_code = 'WW'  and app_id in ()
# # group by app_id
#
#
# 45203160

# %%
spark.sql("select mod(833424538, 1000)").show()


spark.read.format("delta").load("s3://b2c-prod-data-pipeline-unified-store-paid/unified/store.app-est-dna-log-pubrange.v1/fact/").where("granularity='daily' and month='2020-08' and pub_range=538 and device_code='ios-phone' and app_id =318906310 and country_code='JP' and date='2020-08-29' ").show()

# %%
# %%sh
#
# # aws s3 ls s3://b2c-prod-data-pipeline-unified-usage/unified/usage.genre-cross.v1/fact/granularity=monthly/
# # aws s3 ls s3://aardvark-prod-pdx-mdm-to-int/genre_report/version=1.0.0/range_type=MONTH/date=
#
# # aws s3 ls s3://b2c-prod-data-pipeline-unified-usage/unified/usage.genre-cross.v1/fact/granularity=monthly/date=2020-05-31/
# # aws s3 ls s3://aardvark-prod-dca-data/oss/GAME_CROSS_GENRE_KPI_PARQUET/version=1.0.6.post1/range_type=MONTH/date
# # aws s3 cp s3://b2c-prod-data-pipeline-unified-usage/unified/usage.genre-cross.v1/fact/_delta_log/00000000000000000013.json - | head
#
# # aws s3 ls s3://b2c-prod-data-pipeline-raw-usage/raw/usage.genre-cross.v1/insert/_default_partition=2020-07/
# # aws s3 ls s3://b2c-prod-data-pipeline-unified-usage/unified/usage.genre-cross.v1/fact/granularity=monthly/date=2020-06-30/
#
# # aws s3 ls s3://b2c-prod-data-pipeline-unified-usage/unified/usage.genre-cross.v1/fact/granularity=monthly/
#
# # aws s3 ls s3://aardvark-prod-pdx-mdm-to-int/genre_report/version=1.0.0/range_type=MONTH/
#
# # aws s3 ls s3://b2c-prod-data-pipeline-unified-usage/unified/usage.genre-cross.v1/fact/granularity=monthly/date=2019-01-31/ --recursive
# aws s3 ls s3://aardvark-prod-dca-data/oss/GAME_CROSS_GENRE_KPI_PARQUET/version=1.0.6.post1/range_type=MONTH/date=2019-04-30/platform=3/

# %%
# print spark.read.parquet("s3://aardvark-prod-pdx-mdm-to-int/genre_report/version=1.0.0/range_type=MONTH/").filter(" device_type='1' and platform='2'").count()
# print spark.read.parquet("s3://b2c-prod-data-pipeline-unified-usage/unified/usage.genre-cross.v1/fact/granularity=monthly/").filter("_identifier like '12020032004%' and device_code='ios-phone'").count()
# print spark.read.format("delta").option("versionAsOf", 11).load("s3://b2c-prod-data-pipeline-unified-usage/unified/usage.genre-cross.v1/fact/granularity=monthly/").filter("_identifier like '12020032004%' and device_code='ios-phone'").count()

# spark.read.parquet("s3://aardvark-prod-dca-data/oss/GAME_CROSS_GENRE_KPI_PARQUET/version=1.0.4/range_type=MONTH/date=2020-07-31").where("metric_name='XUP'").count()


# spark.read.parquet("s3://aardvark-prod-dca-data/oss/GAME_CROSS_GENRE_KPI_PARQUET/version=1.0.6.post1/range_type=MONTH/date=2019-07-31").printSchema()
# spark.read.format("delta").load("s3://b2c-prod-data-pipeline-unified-usage/unified/usage.genre-cross-test.v1/fact").printSchema()



# spark.sql("select cast(sum(value) as decimal(38,24)) , metric_name from raw where selected_genre_id=101005 and related_genre_id=201006 group by metric_name   ").show(20,False)
# spark.sql("select cast ( sum(est_cross_genre_affinity) as decimal(38,24)), cast( sum(est_cross_genre_usage_penetration) as decimal(38,24)) from unified where    genre_id=101005  and cross_genre_id=201006").show(20,False)



# spark.sql("select value, country, metric_name from raw where selected_genre_id=101005 and related_genre_id=201006 and metric_name='XGA' order by country desc  ").createOrReplaceTempView("raw_xup_country")
# spark.sql("select est_cross_genre_affinity, country_code from unified where genre_id=101005  and cross_genre_id=201006 order by country_code desc ").createOrReplaceTempView("unifed_country")
# join_collect = spark.sql(" select * from raw_xup_country a join unifed_country b on a.country = b.country_code   order by a.country desc  ").collect()
# # print join_collect
# # print ([r['value'] for r in join_collect])
# # print ([r['est_cross_genre_affinity'] for r in join_collect])
# spark.sql("select sum(value)  , metric_name from raw  where   selected_genre_id=101005 and related_genre_id=201006 group by metric_name ").show(20,False)
# spark.sql("select sum(est_cross_genre_affinity), sum(est_cross_genre_usage_penetration) from unified where    genre_id=101005  and cross_genre_id=201006").show(20,False)

# %%
# https://tai6.appannie.com/intelligence/shared-users?chart_shared_users_chart=(aggr:!f,percent:!f,stack:!f,type:line)&shared_users_chart$chart_compare_facets=!(est_cross_genre_usage_penetration__avg)&genre_id=205004&country_code=FR&date=!(%272020-01-01%27,%272020-06-30%27)&granularity=monthly

spark.read.parquet("s3://aardvark-prod-dca-data/oss/GAME_CROSS_GENRE_KPI_PARQUET/version=1.0.6.post1/range_type=MONTH/").createOrReplaceTempView("raw")
spark.read.format("delta").load("s3://b2c-prod-data-pipeline-unified-usage/unified/usage.genre-cross.v1/fact").createOrReplaceTempView("unified")

spark.sql("select * from raw where date='2020-01-31' and country='US' and selected_genre_id=101 and related_genre_id=206").show()
spark.sql("select * from unified where date='2020-01-31' and country_code='US' and genre_id=101 and cross_genre_id=206").show()

# spark.sql("select * from raw where selected_genre_id = 205004  and country='FR' and date='2020-06-30' and platform !=3 ").printSchema()
# spark.sql("select * from unified where genre_id=205004 and country_code='FR' and  date='2020-06-30' and device_code != ''   ").printSchema()

# %%
# spark.sql("select sum(cast(value as decimal(38,30))) , metric_name from raw  group by metric_name   ").show(20,False)
# spark.sql("select sum(cast (est_cross_genre_affinity as decimal(38,24))) , sum(cast( est_cross_genre_usage_penetration as decimal(38,30))) from unified ").show(20,False)
spark.sql("select count(1), metric_name from raw where date<'2020-08-31' group by metric_name").show()
spark.sql("select count(1)  from unified where est_cross_genre_usage_penetration is not null ").show()
spark.sql("select count(1)  from unified where est_cross_genre_affinity is not null ").show()


# spark.sql("select * from unified where est_cross_genre_affinity =0 ").show()

# %%
# %%sh
# # SELECT *  FROM   advancedreview_topic_fact_v1 where date='2019-07-08' and country_code='AU' limit 4;
#
# PGPASSWORD='dNzWtSV3pKTx' psql -h 10.2.10.132 -p 5432 -U citus_bdp_usage_qa -d aa_citus_db << EOF
# SET search_path=usage;
# BEGIN;
# --\d usage.usage_genre_cross_fact_v2
# -- EXPLAIN ANALYZE SELECT * FROM  usage_genre_cross_fact_v1 where granularity='monthly' and device_code='ios-phone'  and country_code='RU'  and date='2019-08-31' and genre_id='204' ;
# -- SELECT * FROM  usage_genre_cross_fact_v1 where granularity='monthly' and device_code='ios-phone'  limit 3;
# -- SELECT max(est_cross_genre_affinity) , min(est_cross_genre_affinity) FROM  usage_genre_cross_fact_v1 where granularity='monthly'   ;
# -- SELECT * FROM  usage_genre_cross_fact_v1 where granularity='monthly' and cast(_identifier as varchar)  like '12020032004%' order by  date desc limit 3;
#
#
# -- SELECT country_code, device_code , count(*) FROM  usage_genre_cross_fact_v1 where granularity='monthly' and date='2020-04-30' group by country_code, device_code  ;
# -- SELECT country_code, device_code , count(*) FROM  usage_genre_cross_fact_v1 where granularity='monthly' and date='2020-03-31' group by country_code, device_code  ;
# -- SELECT country_code, device_code , count(*) FROM  usage_genre_cross_fact_v1 where granularity='monthly' and date='2020-01-31' group by country_code, device_code  ;
# --SELECT * FROM  usage_genre_cross_fact_v1 where granularity='monthly' and  est_cross_genre_usage_penetration>1 limit 3;
#
#
# -- SELECT * FROM  usage_genre_cross_fact_v1 where granularity='monthly'  and date = '2020-05-31' and (est_cross_genre_affinity is NULL or est_cross_genre_usage_penetration is NULL) limit 3
# -- SELECT distinct date FROM  usage_genre_cross_fact_v1 where granularity='monthly'  and ( est_cross_genre_usage_penetration <= 0 or est_cross_genre_usage_penetration > 1  ) limit 3
# --SELECT count(1) FROM  usage_genre_cross_fact_v2 where granularity='monthly' and est_cross_genre_affinity is not null ;
# --SELECT count(1) FROM  usage_genre_cross_fact_v2 where granularity='monthly' and est_cross_genre_usage_penetration is not null ;
#
# --SELECT sum(est_cross_genre_affinity) , sum(est_cross_genre_usage_penetration) FROM  usage_genre_cross_fact_v2 where granularity='monthly' ;
# -- select date, count(country_code), device_code from ( select distinct date, country_code, device_code from usage_genre_cross_fact_v2 where granularity='monthly') as prod group by device_code, date order by date, device_code  ;
#
# -- select * from pg_indexes where tablename like 'usage_genre_cross_fact_v' limit 1;
#
# select * from usage_genre_cross_fact_v2 where granularity='monthly' and date='2021-01-31' where =301 limit 20 ;
#
# EOF
# # SELECT *
# # FROM
# #     pg_indexes
# # WHERE
# #     schemaname = 'usage' AND tablename LIKE 'usage_genre_cross_fact_v1%'
# # LIMIT 1
# # ;

# %%
spark.sql("select sum(value)  , metric_name from raw  where   selected_genre_id=101005 and related_genre_id=201006 group by metric_name ").show(20,False)
spark.sql("select sum(est_cross_genre_affinity), sum(est_cross_genre_usage_penetration) from unified where    genre_id=101005  and cross_genre_id=201006").show(20,False)

# %%
import pyspark.sql.functions as F 
# spark.sql("select est_cross_genre_affinity,est_cross_genre_usage_penetration from unified where genre_id=101005  and cross_genre_id=201006 order by country_code desc ").show(20,False)
# spark.sql("select sum(value)  , metric_name from raw  where   selected_genre_id=101005 and related_genre_id=201006 group by metric_name ").show(20,False)
# spark.sql("select sum(est_cross_genre_affinity), sum(est_cross_genre_usage_penetration) from unified where    genre_id=101005  and cross_genre_id=201006").show(20,False)


df1 = spark.read.parquet("s3://aardvark-prod-dca-data/oss/GAME_CROSS_GENRE_KPI_PARQUET/version=1.0.6.post1/range_type=MONTH/date=2019-07-31").cache()
df2 = spark.read.format("delta").load("s3://b2c-prod-data-pipeline-unified-usage/unified/usage.genre-cross-test.v1/fact").cache()
print df1.where("metric_name='XGA'").select("value").agg({"value":"sum"}).collect()
print df2.select("est_cross_genre_affinity").agg({"est_cross_genre_affinity":"sum"}).collect()
# df2.select("est_cross_genre_usage_penetration").agg({"est_cross_genre_usage_penetration":"sum"}).show()

# df1.select(F.agg(sum(value).alias("sum_value"))).show()
# df2.select(F.agg(sum(est_cross_genre_affinity).alias("sum_xga")), F.agg(sum(est_cross_genre_usage_penetration).alias("sum_xup"))).show()
# agg({"value":"sum"}).show()

# %%
df1 = spark.read.parquet("s3://aardvark-prod-pdx-mdm-to-int/genre_report/version=1.0.0/range_type=MONTH/").cache()
df1.show()
df1.filter("device_type=1 and platform=2").groupBy("metric_name").agg({"*":"count"}).show()

# %%
spark.read.parquet("s3://b2c-prod-data-pipeline-unified-usage/unified/usage.genre.cross.qa.v1/dimension/").show(20,False)

# %%
country_code_list=set()
df = spark.read.parquet("s3://b2c-prod-data-pipeline-unified-usage/unified/usage.genre-cross.v1/fact/granularity=monthly/date=2019-08-31/").groupBy("country_code").agg({"*":"count"}).cache()
result = df.collect()
for r in result:
    country_code_list.add(str(r["country_code"]))
expected_country_code={"TR", "RU", "FR", "KR", "TW", "CA", "DE", "JP", "IT", "US", "HK", "AU", "GB", "BR", "MX", "ES"}

print country_code_list==expected_country_code

# %%
print spark.read.parquet("s3://b2c-prod-data-pipeline-unified-usage/unified/usage.genre-cross.v1/fact/granularity=monthly/").filter("country_code = 'RU' and device_code='android-phone'").count()
print spark.read.parquet("s3://b2c-prod-data-pipeline-unified-usage/unified/usage.genre-cross.v1/fact/granularity=monthly/").filter("country_code = 'US' and device_code='android-phone'").count()
print spark.read.parquet("s3://b2c-prod-data-pipeline-unified-usage/unified/usage.genre-cross.v1/fact/granularity=monthly/").filter("country_code = 'US' and device_code='ios-phone'").count()

print spark.read.parquet("s3://b2c-prod-data-pipeline-unified-usage/unified/usage.genre-cross.v1/fact/granularity=monthly/").filter("est_cross_genre_usage_penetration is null").take(1)
print spark.read.parquet("s3://b2c-prod-data-pipeline-unified-usage/unified/usage.genre-cross.v1/fact/granularity=monthly/").filter("est_cross_genre_usage_penetration>1").take(1)
print spark.read.parquet("s3://b2c-prod-data-pipeline-unified-usage/unified/usage.genre-cross.v1/fact/granularity=monthly/").filter("est_cross_genre_usage_penetration=0").take(1)
print spark.read.parquet("s3://b2c-prod-data-pipeline-unified-usage/unified/usage.genre-cross.v1/fact/granularity=monthly/").filter("est_cross_genre_affinity>10").take(1)
print spark.read.parquet("s3://b2c-prod-data-pipeline-unified-usage/unified/usage.genre-cross.v1/fact/granularity=monthly/").filter("est_cross_genre_affinity is null").take(1)

# %%
# %%sh
# # aws s3 ls s3://b2c-prod-data-pipeline-unified-usage/unified/usage.genre-cross.v1/fact/granularity=monthly/date=
# aws s3 ls s3://b2c-prod-data-pipeline-raw-usage/raw/usage.genre-cross.v1/insert/_default_partition --recursive | sort -r

# %%
# %%sh
