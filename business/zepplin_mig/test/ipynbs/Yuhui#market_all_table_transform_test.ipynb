# %%
# %%sh
#
#
# aws s3 ls s3://b2c-prod-data-pipeline-unified-market/unified/

# %%
spark.read.parquet("s3://prod.appannie.mktint.data/market_fact/granularity=MONTH_TO_DATE/date=2019-06-01/").printSchema()
