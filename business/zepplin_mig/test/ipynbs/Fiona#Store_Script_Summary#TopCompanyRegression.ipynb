# %%
df = spark.read.parquet("s3://b2c-prod-data-pipeline-unified-dna/unified/dna.mapping-log.v1/dimension/update_date=2020-06-30/").cache()
df.createOrReplaceTempView("dna_info")
# spark.sql("select count (distinct publisher_id) from dna_info where company_id=1000200000000111 and end_date is null").show(500)
# spark.sql("select * from dna_info where company_id=1000200000000111 and end_date is null").show(500)
spark.sql("select * from dna_info where app_id=1097492828").show()

# %%
# %%sh
# PGPASSWORD='wZw8cfBuuklIskVG' psql -h 10.2.6.141  -U citus_bdp_prod_app_int_qa -d aa_store_db -p 5432 << EOF
# set search_path=store;
#
# --select sum(est_free_app_download) as sum_download , app_id from store_est_fact_v2 where country_code='US' and date between '2020-05-01' and '2020-05-09' and country_code='US' and company_id=1000200000000111 and
# -- device_code!='android-all' group by app_id, publisher_id, company_id, parent_company_id order by sum_download desc  limit 10;
#
# -- select date, sum(est_free_app_download) from store_est_fact_v2 where  date between '2018-06-14' and '2018-06-15'  and company_id = 1000200000000111 and country_code = 'US' and device_code='ios-phone' group by date limit 6;
#
#
#
#
# -- select * from store_est_fact_v2 where date between '2018-06-14' and '2018-06-14'  and company_id = 1000200000018181 and country_code = 'US' and device_code='ios-phone'  group by app_id order by sum_download desc limit 6;
#
# select app_id, sum(est_free_app_download) as sum_download from store_est_fact_v2 where date between '2018-06-14' and '2018-06-14'  and parent_company_id = 1000200000017478 and country_code = 'US' and device_code='ios-phone' and est_free_app_download is not null group by app_id order by sum_download desc limit 6;
#
# select app_id, sum(est_free_app_download) as sum_download from store_est_fact_v2 where date between '2018-06-15' and '2018-06-15'  and parent_company_id = 1000200000031106 and country_code = 'US' and device_code='ios-phone' and est_free_app_download is not null group by app_id order by sum_download desc limit 6;
#
#
# EOF

# %%
# %%sh
# PGPASSWORD='wZw8cfBuuklIskVG' psql -h 10.2.6.141  -U citus_bdp_prod_app_int_qa -d aa_store_db -p 5432 << EOF
# set search_path=store;
# select * from (
#     select app_id, sum(est_free_app_download) as sum_download from ( select * from store_est_fact_v2 where date between '2018-06-15' and '2018-06-15'  and country_code = 'US' and device_code='ios-phone' and company_id=1000200000031106 and parent_company_id=0 order by est_free_app_download desc ) as prod group by app_id
#     union
#     select app_id, sum(est_free_app_download) as sum_download from store_est_fact_v2 where date between '2018-06-15' and '2018-06-15'  and parent_company_id = 1000200000031106 and country_code = 'US' and device_code='ios-phone' and est_free_app_download is not null group by app_id
#     ) as test order by sum_download desc limit 10;
#
#
# EOF

# %%
# %%sh
# PGPASSWORD='wZw8cfBuuklIskVG' psql -h 10.2.6.141  -U citus_bdp_prod_app_int_qa -d aa_store_db -p 5432 << EOF
# set search_path=store;
#
# select * from store.store_est_fact_v2 where date between '2018-06-15' and '2018-06-15'  and country_code = 'JP' and device_code='ios-phone'  and ((company_id=1000200000000122 and parent_company_id =0 ) or parent_company_id=1000200000000122) and est_revenue is not null order by est_revenue desc limit 5;
#
# EOF

# %%
# %%sh
# PGPASSWORD='2mHdFW6%#REu' psql -h 10.2.25.198  -U app_bdp_usage_qa -d dna -p 6432 << EOF
# set search_path=public;
#
# -- universal_id : company id
# -- parent_id : parent id
# select * from dna_universal_company_parent  limit 1
# -- select * from ( select universal_id, count(universal_id) from dna_universal_company_parent where start_date is not null and end_date is not null group by universal_id ) as prod limit 5
#
# -- select * from dna_universal_company_parent where start_date < '2012-01-01' limit 10;
#
#
# -- universal_id : company id
# -- company id : publisher id
# -- select * from dna_universal_company_mapping where company_id=542280115   limit 2;
#
#
#
# EOF
#
# # select id , universal_id  ,  parent_id ,start_date , end_date, confirmed , disabled from dna_universal_company_parent where universal_id= 1000200000050365 and disabled = 'f' order by start_date asc limit 10;
# # select * from dna_universal_company_mapping where universal_id= 1000200000050365 limit 10;

# %%
# %%sh
# PGPASSWORD='wZw8cfBuuklIskVG' psql -h 10.2.6.141  -U citus_bdp_prod_app_int_qa -d aa_store_db -p 5432 << EOF
# set search_path=store;
#
# --select sum(est_free_app_download) as sum_download , app_id from store_est_fact_v2 where country_code='US' and date between '2020-05-01' and '2020-05-09' and country_code='US' and company_id=1000200000000111 and
# -- device_code!='android-all' group by app_id, publisher_id, company_id, parent_company_id order by sum_download desc  limit 10;
#
#
#
#
#
# -- select * from store_est_fact_v2 where date between '2018-06-14' and '2018-06-14'  and company_id = 1000200000018181 and country_code = 'US' and device_code='ios-phone'  group by app_id order by sum_download desc limit 6;
#
#
# -- select app_id, est_revenue from store_est_fact_v2 where  date between '2018-06-14' and '2018-06-14'  and company_id = 1000200000018181 and country_code = 'US' and device_code='ios-phone' and est_revenue is not null order -- by est_revenue desc limit 6;
#
# select * from store_est_fact_v2 where app_id =1017551780 and date between '2020-05-01' and '2020-05-01'  and country_code = 'US'  limit 5;
#
# EOF

# %%
PGPASSWORD='wZw8cfBuuklIskVG' psql -h 10.2.6.141  -U citus_bdp_prod_app_int_qa -d aa_store_db -p 5432 << EOF 
set search_path=store;
select * from store_est_fact_v2 where date between '2020-05-01' and '2020-05-01'  and country_code = 'US' and app_id= 1499849161 limit 5;
select app_id , sum(est_paid_app_download) as sum_paid from store_est_fact_v2 where date between '2020-05-01' and '2020-05-01'  and country_code = 'US' and  publisher_id =20200003238779 and est_paid_app_download is not null group by app_id order by sum_paid desc limit 5;


EOF

# %%
# %%sh
# PGPASSWORD='wZw8cfBuuklIskVG' psql -h 10.2.6.141  -U citus_bdp_prod_app_int_qa -d aa_store_db -p 5432 << EOF
# set search_path=store;
# select sum(est_paid_app_download) from store.store_est_fact_v2 where date between '2020-03-29' and '2020-04-04'   and country_code='US' and company_id = 1000200000005302 and app_id in (select distinct app_id from dna.dna_app_tag_dim_v2 where (tag_id=3 ) and ( tag_id !='500008') ) ;
# EOF

# %%
# %%sh
# PGPASSWORD='wZw8cfBuuklIskVG' psql -h 10.2.6.141  -U citus_bdp_prod_app_int_qa -d aa_store_db -p 5432 << EOF
# set search_path=dna;
# select * from dna.dna_app_tag_dim_v2 where (tag_id=3 ) and ( tag_id !='500008') limit 5;
#
# EOF

# %%
# %%sh
# PGPASSWORD='2mHdFW6%#REu' psql -h 10.2.25.198  -U app_bdp_usage_qa -d dna -p 6432 << EOF
# set search_path=public;
# select * from dna_genre_info where language_code = 'en' and name like '%Core%' limit 1;
# select * from dna_modifier_info where language_code = 'en' and name like '%2D%' limit 1;
#
# EOF

# %%
# %%sh
