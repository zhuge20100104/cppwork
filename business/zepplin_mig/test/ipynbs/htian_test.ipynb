# %%
# %%sh
# PGPASSWORD='wZw8cfBuuklIskVG' psql -h 10.2.6.141 -U citus_bdp_prod_app_int_qa -d aa_store_db -p 5432 << EOF
# set search_path=dna;
# select count(distinct(app_id)) from dna_app_tag_dim_v1 where tag_id = 155306600000000;
# EOF

# %%
# %%sh
# PGPASSWORD='wZw8cfBuuklIskVG' psql -h 10.2.6.141 -U citus_bdp_prod_app_int_qa -d aa_store_db -p 5432 << EOF
# set search_path=dna;
# select count(distinct(app_id)) from dna_app_tag_dim_v1 where tag_id = 1;
# EOF

# %%
# %%sh
# PGPASSWORD='wZw8cfBuuklIskVG' psql -h 10.2.6.141 -U citus_bdp_prod_app_int_qa -d aa_store_db -p 5432 << EOF
# set search_path=dna;
# select distinct(app_id) from dna_app_tag_dim_v1 where tag_id = 1
# except
# select distinct(app_id) from dna_app_tag_dim_v1 where tag_id = 155306600000000;
# EOF

# %%
# %%sh
# PGPASSWORD='wZw8cfBuuklIskVG' psql -h 10.2.6.141 -U citus_bdp_prod_app_int_qa -d aa_store_db -p 5432 << EOF
# set search_path=dna;
# select * from dna_app_tag_dim_v1 where app_id = 1485363251;
# EOF

# %%
# %sh
PGPASSWORD='wZw8cfBuuklIskVG' psql -h 10.2.6.141 -U citus_bdp_prod_app_int_qa -d aa_store_db -p 5432 << EOF
set search_path=dna;
select count(distinct(app_id)) from dna_app_tag_dim_v1 where tag_id = 3;
EOF

# %%
# %%sh
