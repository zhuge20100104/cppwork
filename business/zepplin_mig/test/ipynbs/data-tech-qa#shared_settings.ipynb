# %%
# !/usr/bin/env python
# coding=utf-8
# Copyright (c) 2017 App Annie Inc. All rights reserved.
"""
For production
"""

TEST = False
RUNNING_ENV = 'prod'

PG_METADB_HOSTS = [('b2b-prod-uds-storage-meta-db-new.crlexxwtzodp.us-east-1.rds.amazonaws.com', 5432)]
PG_METADB_ACCESS_ID = 'datapipeline_uds_writer'
PG_METADB_SECRET_KEY = '$mfbKd^&#D&6w6jX'
PG_METADB_NAME = 'metadb'
PG_METADB_CONNECTION_CAPACITY = 10
PG_METADB_SEMAPHORE_TIMEOUT = 7201
BACKGROUND_SERVICES_RETRY_COUNT = 5
KINESIS_METADATA_NAME = "B2C-PROD-DATA-PIPELINE-METADATA-KINESIS"
ES_METADATA_HOSTS = [('vpc-b2c-prod-dp-metadata-aes-2xenisytvftmqz5igpcwz6bkcu.us-east-1.es.amazonaws.com', 443)]
ES_METADATA_ACCESS_ID = 'AKIARIYIV4POVFTHLAFV'
ES_METADATA_SECRET_KEY = '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'
ES_METADATA_CONNECTION_CAPACITY = 10
ES_METADATA_SEMAPHORE_TIMEOUT = 7201
SLACK_USER_ID_MAPPING = {
    "XIEYUANPENG": "UJ86V0ABY",
    "GAORIHE": "UG4R6ABCY",
    "ANRUI": "U6YR3M0RF",
    "QA": "UL8AEA3KP",
    "GUANJIAN": "UHS7J9B6F",
    "XINGYUKUN": "U397U9LKW",
    "YIMING": "U6B8RJ404",
    "DEFAULT": "UJ86V0ABY",
    "YUYUANZHANG": "UJHHR5VMX"
}
ES_METADATA_INTERFACE = {
    "engine": "ES",
    "database": "metadata",
    "index_pattern": "datapipeline-job-monitoring-{type}",
    "index_settings": {
        "index.number_of_shards": ""
    },
    "doc_type": "_doc",
    "doc_id_fields": ["id"],
    "doc_fields_mapping": {}
}

SENTRY_RATING_DSN = "https://072c176e54884673b4aebffb0ff5c610:7415cdbdd8a048609b13facad83d6ae4@" \
                    "sentry.smart-sense.org/50"

PRODUCT_SERVICE_ENDPOINT = "http://prod-aa-product-service-internal.appannie.org/v1/query"
DIMENSION_SERVICE_ENDPOINT = "http://prod-aa-dimension-service-internal.appannie.org/v1/query"
MICRO_SERVICE_ACCESS_ID = "ms-fe"
MICRO_SERVICE_SECRET_KEY = "eV6zZJWXQrEs"
MICRO_SERVICE_RETRY_COUNT = 1
MICRO_SERVICE_RETRY_INTERVAL = 0

ES_APP_INT_ACCESS_ID = 'bdp_qa'
ES_APP_INT_SECRET_KEY = '577TwEzU3NK#'
ES_APP_INT_HOSTS = [('http://internal-aa-int-sdk-elasticsearch-621265199.us-east-1.elb.amazonaws.com', 19200)]

PG_DAILY_EST_CLUSTER = 'dailyest'
PG_DAILY_EST_HOSTS = [('internal-aa-prod-plproxy-internal-4-329644124.us-east-1.elb.amazonaws.com', 7432)]
PG_DAILY_EST_NAME = 'dailyest'
PG_DAILY_EST_ACCESS_ID = 'app_bdp_usage_qa'
PG_DAILY_EST_SECRET_KEY = '2mHdFW6%#REu'
PG_DAILY_EST_NODE_NUM = 8

PG_USAGE_CLUSTER = 'cohort'
PG_USAGE_HOSTS = [('internal-aa-prod-usage-plproxy-internal-1640809782.us-east-1.elb.amazonaws.com', 7432)]
PG_USAGE_NAME = 'cohort'
PG_USAGE_ACCESS_ID = 'app_bdp_usage_qa'
PG_USAGE_SECRET_KEY = '2mHdFW6%#REu'
PG_USAGE_NODE_NUM = 8

PG_DNA_HOSTS = [('10.2.26.136', 6432)]
PG_DNA_NAME = 'dna'
PG_DNA_ACCESS_ID = 'app_bdp_usage_qa'
PG_DNA_SECRET_KEY = '2mHdFW6%#REu'

PG_AA_HOSTS = [('10.2.26.136', 6432)]
PG_AA_NAME = 'aa'
PG_AA_ACCESS_ID = 'app_bdp_usage_qa'
PG_AA_SECRET_KEY = '2mHdFW6%#REu'

# Amazon App PG
PG_AA_AMAZON_HOSTS = [('pg-n-slave-4edc958bda550bbc.elb.us-east-1.amazonaws.com', 5433)]
PG_AA_AMAZON_NAME = 'aa_amazon'
PG_AA_AMAZON_ACCESS_ID = 'app_bdp_usage_qa'
PG_AA_AMAZON_SECRET_KEY = '2mHdFW6%#REu'

# App Store Rank Citus
CITUS_AA_CITUS_DB_HOSTS = [('10.2.10.132', 5432)]
CITUS_AA_CITUS_DB_ACCESS_ID = 'citus_bdp_usage_qa'
CITUS_AA_CITUS_DB_SECRET_KEY = 'dNzWtSV3pKTx'
CITUS_AA_CITUS_DB_NAME = 'aa_citus_db'
CITUS_AA_CITUS_DB_CONNECTION_CAPACITY = 2
CITUS_AA_CITUS_DB_SEMAPHORE_TIMEOUT = 7201

# ASO Citus
CITUS_ASO_STORE_HOSTS = [('internal-aa-citus-mkt-elb-1511434527.us-east-1.elb.amazonaws.com', 7432)]
CITUS_ASO_STORE_NAME = 'aa_mkt_db'
CITUS_ASO_STORE_ACCESS_ID = 'citus_mkt_qa'
CITUS_ASO_STORE_SECRET_KEY = 'rn*Wh%osCl2C'
CITUS_ASO_STORE_CONNECTION_CAPACITY = 10
CITUS_ASO_STORE_SEMAPHORE_TIMEOUT = 7201

# MKT Citus
CITUS_MKT_HOSTS = [('internal-aa-citus-mkt-elb-1511434527.us-east-1.elb.amazonaws.com', 7432)]
CITUS_MKT_NAME = 'aa_mkt_db'
CITUS_MKT_ACCESS_ID = 'citus_mkt_qa'
CITUS_MKT_SECRET_KEY = 'rn*Wh%osCl2C'
CITUS_MKT_CONNECTION_CAPACITY = 10
CITUS_MKT_SEMAPHORE_TIMEOUT = 7201

# UDS General
ES_UDS_GENERAL_HOSTS = [('http://internal-aa-int-uds-elasticsearch-124841367.us-east-1.elb.amazonaws.com', 19200)]
ES_UDS_GENERAL_ACCESS_ID = 'app_bdp_usage_qa'
ES_UDS_GENERAL_SECRET_KEY = 'euIGw5c6cP3D'
ES_UDS_GENERAL_CONNECTION_CAPACITY = 1
ES_UDS_GENERAL_SEMAPHORE_TIMEOUT = 36000

# ASO ES
ES_ASO_HOSTS = [('http://internal-aa-prod-int-elasticsearch-v5-1589259492.us-east-1.elb.amazonaws.com', 19200)]
ES_ASO_ACCESS_ID = 'app_bdp_usage_qa'
ES_ASO_SECRET_KEY = 'euIGw5c6cP3D'
ES_ASO_CONNECTION_CAPACITY = 1
ES_ASO_SEMAPHORE_TIMEOUT = 36000

# ASO SOV ES
ES_ASO_SOV_HOSTS = [('http://internal-aa-prod-int-elasticsearch-v5-1589259492.us-east-1.elb.amazonaws.com', 19200)]
ES_ASO_SOV_ACCESS_ID = 'app_bdp_usage_qa'
ES_ASO_SOV_SECRET_KEY = 'euIGw5c6cP3D'
ES_ASO_SOV_CONNECTION_CAPACITY = 2
ES_ASO_SOV_SEMAPHORE_TIMEOUT = 60


# ASO Citus
CITUS_ASO_CITUS_DB_HOSTS = [('internal-aa-citus-mkt-elb-1511434527.us-east-1.elb.amazonaws.com', 7432)]
CITUS_ASO_CITUS_DB_NAME = 'aa_mkt_db'
CITUS_ASO_CITUS_DB_ACCESS_ID = 'citus_mkt_qa'
CITUS_ASO_CITUS_DB_SECRET_KEY = 'rn*Wh%osCl2C'
CITUS_ASO_CITUS_DB_CONNECTION_CAPACITY = 10
CITUS_ASO_CITUS_DB_SEMAPHORE_TIMEOUT = 7201

# Advanced Review Citus
CITUS_ADVANCEDREVIEW_CITUS_DB_HOSTS = [('10.2.10.132', 5432)]
CITUS_ADVANCEDREVIEW_CITUS_DB_NAME = 'aa_citus_db'
CITUS_ADVANCEDREVIEW_CITUS_DB_CONNECTION_CAPACITY = 10
CITUS_ADVANCEDREVIEW_CITUS_DB_SEMAPHORE_TIMEOUT = 7201
CITUS_ADVANCEDREVIEW_CITUS_DB_ACCESS_ID = 'citus_bdp_usage_qa'
CITUS_ADVANCEDREVIEW_CITUS_DB_SECRET_KEY = 'dNzWtSV3pKTx'

# Advanced Review ES
ES_ADV_REVIEW_HOSTS = [('http://internal-internel-review-es-v7-1286999769.us-east-1.elb.amazonaws.com', 19200)]
ES_ADV_REVIEW_ACCESS_ID = 'bdp_qa'
ES_ADV_REVIEW_SECRET_KEY = '6trmJcZBJrKWdtN2'
ES_ADV_REVIEW_CONNECTION_CAPACITY = 15
ES_ADV_REVIEW_SEMAPHORE_TIMEOUT = 7200

# Rating ES
ES_RATING_OVER_TIME_HOSTS = [('http://aa-rating-es.appannie.org', 80)]
ES_RATING_OVER_TIME_ACCESS_ID = 'bdp_qa'
ES_RATING_OVER_TIME_SECRET_KEY = 'SQdyonvT1dJk68KA'
ES_RATING_OVER_TIME_CONNECTION_CAPACITY = 15
ES_RATING_OVER_TIME_SEMAPHORE_TIMEOUT = 7200

# not used
# ES_APP_SS_HOSTS = [('http://internal-aa-int-ss-review-elasticsearch-126620990.us-east-1.elb.amazonaws.com', 19200)]
# ES_APP_SS_ACCESS_ID = 'bdp_prod_app_ss'
# ES_APP_SS_SECRET_KEY = 'r0RiD5q6ykLl'

# Game IQ Cross Genre Citus
CITUS_GAME_IQ_CROSS_GENRE_CITUS_DB_HOSTS = [('10.2.10.132', 5432)]
CITUS_GAME_IQ_CROSS_GENRE_CITUS_DB_NAME = "aa_citus_db"
CITUS_GAME_IQ_CROSS_GENRE_CITUS_DB_ACCESS_ID = "citus_bdp_usage_qa"
CITUS_GAME_IQ_CROSS_GENRE_CITUS_DB_SECRET_KEY = "dNzWtSV3pKTx"
CITUS_GAME_IQ_CROSS_GENRE_CITUS_DB_CONNECTION_CAPACITY = 10
CITUS_GAME_IQ_CROSS_GENRE_CITUS_DB_SEMAPHORE_TIMEOUT = 7201

# Usage Citus
CITUS_USAGE_HOSTS = [('10.2.6.141', 5432)]
CITUS_USAGE_NAME = 'aa_store_db'
CITUS_USAGE_ACCESS_ID = 'citus_bdp_prod_app_int_qa'
CITUS_USAGE_SECRET_KEY = 'wZw8cfBuuklIskVG'


# Store/DNA Citus
CITUS_STORE_CITUS_DB_HOSTS = [('10.2.6.141', 5432)]
CITUS_STORE_CITUS_DB_NAME = "aa_store_db"
CITUS_STORE_CITUS_DB_ACCESS_ID = "citus_bdp_prod_app_int_qa"
CITUS_STORE_CITUS_DB_SECRET_KEY = "wZw8cfBuuklIskVG"
CITUS_STORE_CITUS_DB_CONNECTION_CAPACITY = 10
CITUS_STORE_CITUS_DB_SEMAPHORE_TIMEOUT = 7201


# metaDB Citus
CITUS_METADB_CITUS_DB_HOSTS = [('b2b-prod-uds-storage-meta-db-new.crlexxwtzodp.us-east-1.rds.amazonaws.com', 5432)]
CITUS_METADB_CITUS_DB_NAME = "metadb"
CITUS_METADB_CITUS_DB_ACCESS_ID = "app_meta_qa"
CITUS_METADB_CITUS_DB_SECRET_KEY = "IEdwiF2hmqzdKK43"
CITUS_METADB_CITUS_DB_CONNECTION_CAPACITY = 10
CITUS_METADB_CITUS_DB_SEMAPHORE_TIMEOUT = 5432


# ELB:pg-n-slave-4edc958bda550bbc.elb.us-east-1.amazonaws.com
# User:app_bdp_usage_qa
# Port:5433
# Database names:
# aa_android
# aa_amazon
# category_service

# ------------------------------------------
# db check - DEBUG ONLY - need to be removed
# ------------------------------------------
# DEFAULT_RECIPIENTS = "tom@appannie.com"
# PAGERDUTY_RECIPIENTS = "tom@appannie.com"

# %%
# %%sh
#
# PGPASSWORD='9KRMPySxvw9elJqk' psql -h udw-aurora-prod.cluster-ro-crlexxwtzodp.us-east-1.rds.amazonaws.com -U app_aurora_bdp_qa -d aa_intelligence_production -p 5432 << EOF
#
# \dv adl_usage_paid.fact_usage_basic_v1
#
# select * from adl_master.DIM_TAG_RELATION_MV_V2 limit 5;
#
#
# EOF

# %%
# %%sh
#
# cat ~/bdp/application/aaintdatapipeline/core/conf/settings_local.py
#
# # curl -s https://aa-data-model-service.stg-feature.appannie.org/status/
# # curl -s --connect-timeout 5 http://prod-aa-data-model-service-internal.appannie.org/status/

# %%
# %%sh
# curl -u bdp_qa:577TwEzU3NK# -XGet http://internal-aa-int-sdk-elasticsearch-621265199.us-east-1.elb.amazonaws.com:19200/_cat/indices/aso-kpi-ts-*
#
# # aso-kpi-sov_search_ads_keyword_fact_v1_daily_gb_2019-07*/_search?pretty -d '{
# #   "query": {
# #     "bool": { "must": [
#
# #       {
# #           "match": {
# #             "device_code": "ios-tablet"
# #           }
# #         },{
# #           "match": {
# #             "date": "2019-07-03"
# #           }
# #           },{
# #           "match": {
# #             "keyword_id": "1944365"
# #           }
# #           }
# #       ]
# #     }
# #     }
# #   }
# # '

# %%
# !/usr/bin/env python
# coding=utf-8
# Copyright (c) 2017 App Annie Inc. All rights reserved.
"""
For production
"""

TEST = False
RUNNING_ENV = 'prod'

PG_METADB_HOSTS = [('b2b-prod-uds-storage-meta-db-new.crlexxwtzodp.us-east-1.rds.amazonaws.com', 5432)]
PG_METADB_ACCESS_ID = 'datapipeline_uds_writer'
PG_METADB_SECRET_KEY = '$mfbKd^&#D&6w6jX'
PG_METADB_NAME = 'metadb'
PG_METADB_CONNECTION_CAPACITY = 10
PG_METADB_SEMAPHORE_TIMEOUT = 7201
BACKGROUND_SERVICES_RETRY_COUNT = 5
KINESIS_METADATA_NAME = "B2C-PROD-DATA-PIPELINE-METADATA-KINESIS"
ES_METADATA_HOSTS = [('vpc-b2c-prod-dp-metadata-aes-2xenisytvftmqz5igpcwz6bkcu.us-east-1.es.amazonaws.com', 443)]
ES_METADATA_ACCESS_ID = 'AKIARIYIV4POVFTHLAFV'
ES_METADATA_SECRET_KEY = '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'
ES_METADATA_CONNECTION_CAPACITY = 10
ES_METADATA_SEMAPHORE_TIMEOUT = 7201
SLACK_USER_ID_MAPPING = {
    "XIEYUANPENG": "UJ86V0ABY",
    "GAORIHE": "UG4R6ABCY",
    "ANRUI": "U6YR3M0RF",
    "QA": "UL8AEA3KP",
    "GUANJIAN": "UHS7J9B6F",
    "XINGYUKUN": "U397U9LKW",
    "YIMING": "U6B8RJ404",
    "DEFAULT": "UJ86V0ABY",
    "YUYUANZHANG": "UJHHR5VMX"
}
ES_METADATA_INTERFACE = {
    "engine": "ES",
    "database": "metadata",
    "index_pattern": "datapipeline-job-monitoring-{type}",
    "index_settings": {
        "index.number_of_shards": ""
    },
    "doc_type": "_doc",
    "doc_id_fields": ["id"],
    "doc_fields_mapping": {}
}

SENTRY_RATING_DSN = "https://072c176e54884673b4aebffb0ff5c610:7415cdbdd8a048609b13facad83d6ae4@" \
                    "sentry.smart-sense.org/50"

PRODUCT_SERVICE_ENDPOINT = "http://prod-aa-product-service-internal.appannie.org/v1/query"
DIMENSION_SERVICE_ENDPOINT = "http://prod-aa-dimension-service-internal.appannie.org/v1/query"
MICRO_SERVICE_ACCESS_ID = "ms-fe"
MICRO_SERVICE_SECRET_KEY = "eV6zZJWXQrEs"
MICRO_SERVICE_RETRY_COUNT = 1
MICRO_SERVICE_RETRY_INTERVAL = 0

ES_APP_INT_ACCESS_ID = 'bdp_qa'
ES_APP_INT_SECRET_KEY = '577TwEzU3NK#'
ES_APP_INT_HOSTS = [('http://internal-aa-int-sdk-elasticsearch-621265199.us-east-1.elb.amazonaws.com', 19200)]

PG_DAILY_EST_CLUSTER = 'dailyest'
PG_DAILY_EST_HOSTS = [('internal-aa-prod-plproxy-internal-4-329644124.us-east-1.elb.amazonaws.com', 7432)]
PG_DAILY_EST_NAME = 'dailyest'
PG_DAILY_EST_ACCESS_ID = 'app_bdp_usage_qa'
PG_DAILY_EST_SECRET_KEY = '2mHdFW6%#REu'
PG_DAILY_EST_NODE_NUM = 8

PG_USAGE_CLUSTER = 'cohort'
PG_USAGE_HOSTS = [('internal-aa-prod-usage-plproxy-internal-1640809782.us-east-1.elb.amazonaws.com', 7432)]
PG_USAGE_NAME = 'cohort'
PG_USAGE_ACCESS_ID = 'app_bdp_usage_qa'
PG_USAGE_SECRET_KEY = '2mHdFW6%#REu'
PG_USAGE_NODE_NUM = 8

PG_DNA_HOSTS = [('10.2.26.136', 6432)]
PG_DNA_NAME = 'dna'
PG_DNA_ACCESS_ID = 'app_bdp_usage_qa'
PG_DNA_SECRET_KEY = '2mHdFW6%#REu'

PG_AA_HOSTS = [('10.2.26.136', 6432)]
PG_AA_NAME = 'aa'
PG_AA_ACCESS_ID = 'app_bdp_usage_qa'
PG_AA_SECRET_KEY = '2mHdFW6%#REu'

# Amazon App PG
PG_AA_AMAZON_HOSTS = [('pg-n-slave-4edc958bda550bbc.elb.us-east-1.amazonaws.com', 5433)]
PG_AA_AMAZON_NAME = 'aa_amazon'
PG_AA_AMAZON_ACCESS_ID = 'app_bdp_usage_qa'
PG_AA_AMAZON_SECRET_KEY = '2mHdFW6%#REu'

# App Store Rank Citus
CITUS_AA_CITUS_DB_HOSTS = [('10.2.10.132', 5432)]
CITUS_AA_CITUS_DB_ACCESS_ID = 'citus_bdp_usage_qa'
CITUS_AA_CITUS_DB_SECRET_KEY = 'dNzWtSV3pKTx'
CITUS_AA_CITUS_DB_NAME = 'aa_citus_db'
CITUS_AA_CITUS_DB_CONNECTION_CAPACITY = 2
CITUS_AA_CITUS_DB_SEMAPHORE_TIMEOUT = 7201

# ASO Citus
CITUS_ASO_STORE_HOSTS = [('internal-aa-citus-mkt-elb-1511434527.us-east-1.elb.amazonaws.com', 7432)]
CITUS_ASO_STORE_NAME = 'aa_mkt_db'
CITUS_ASO_STORE_ACCESS_ID = 'citus_mkt_qa'
CITUS_ASO_STORE_SECRET_KEY = 'rn*Wh%osCl2C'
CITUS_ASO_STORE_CONNECTION_CAPACITY = 10
CITUS_ASO_STORE_SEMAPHORE_TIMEOUT = 7201

# MKT Citus
CITUS_MKT_HOSTS = [('internal-aa-citus-mkt-elb-1511434527.us-east-1.elb.amazonaws.com', 7432)]
CITUS_MKT_NAME = 'aa_mkt_db'
CITUS_MKT_ACCESS_ID = 'citus_mkt_qa'
CITUS_MKT_SECRET_KEY = 'rn*Wh%osCl2C'
CITUS_MKT_CONNECTION_CAPACITY = 10
CITUS_MKT_SEMAPHORE_TIMEOUT = 7201

# UDS General
ES_UDS_GENERAL_HOSTS = [('http://internal-aa-int-uds-elasticsearch-124841367.us-east-1.elb.amazonaws.com', 19200)]
ES_UDS_GENERAL_ACCESS_ID = 'app_bdp_usage_qa'
ES_UDS_GENERAL_SECRET_KEY = 'euIGw5c6cP3D'
ES_UDS_GENERAL_CONNECTION_CAPACITY = 1
ES_UDS_GENERAL_SEMAPHORE_TIMEOUT = 36000

# ASO ES
ES_ASO_HOSTS = [('http://internal-aa-prod-int-elasticsearch-v5-1589259492.us-east-1.elb.amazonaws.com', 19200)]
ES_ASO_ACCESS_ID = 'app_bdp_usage_qa'
ES_ASO_SECRET_KEY = 'euIGw5c6cP3D'
ES_ASO_CONNECTION_CAPACITY = 1
ES_ASO_SEMAPHORE_TIMEOUT = 36000

# ASO SOV ES
ES_ASO_SOV_HOSTS = [('http://internal-aa-prod-int-elasticsearch-v5-1589259492.us-east-1.elb.amazonaws.com', 19200)]
ES_ASO_SOV_ACCESS_ID = 'app_bdp_usage_qa'
ES_ASO_SOV_SECRET_KEY = 'euIGw5c6cP3D'
ES_ASO_SOV_CONNECTION_CAPACITY = 2
ES_ASO_SOV_SEMAPHORE_TIMEOUT = 60


# ASO Citus
CITUS_ASO_CITUS_DB_HOSTS = [('internal-aa-citus-mkt-elb-1511434527.us-east-1.elb.amazonaws.com', 7432)]
CITUS_ASO_CITUS_DB_NAME = 'aa_mkt_db'
CITUS_ASO_CITUS_DB_ACCESS_ID = 'citus_mkt_qa'
CITUS_ASO_CITUS_DB_SECRET_KEY = 'rn*Wh%osCl2C'
CITUS_ASO_CITUS_DB_CONNECTION_CAPACITY = 10
CITUS_ASO_CITUS_DB_SEMAPHORE_TIMEOUT = 7201

# Advanced Review Citus
CITUS_ADVANCEDREVIEW_CITUS_DB_HOSTS = [('10.2.10.132', 5432)]
CITUS_ADVANCEDREVIEW_CITUS_DB_NAME = 'aa_citus_db'
CITUS_ADVANCEDREVIEW_CITUS_DB_CONNECTION_CAPACITY = 10
CITUS_ADVANCEDREVIEW_CITUS_DB_SEMAPHORE_TIMEOUT = 7201
CITUS_ADVANCEDREVIEW_CITUS_DB_ACCESS_ID = 'citus_bdp_usage_qa'
CITUS_ADVANCEDREVIEW_CITUS_DB_SECRET_KEY = 'dNzWtSV3pKTx'

# Advanced Review ES
ES_ADV_REVIEW_HOSTS = [('http://internal-internel-review-es-v7-1286999769.us-east-1.elb.amazonaws.com', 19200)]
ES_ADV_REVIEW_ACCESS_ID = 'bdp_qa'
ES_ADV_REVIEW_SECRET_KEY = '6trmJcZBJrKWdtN2'
ES_ADV_REVIEW_CONNECTION_CAPACITY = 15
ES_ADV_REVIEW_SEMAPHORE_TIMEOUT = 7200

# not used
# ES_APP_SS_HOSTS = [('http://internal-aa-int-ss-review-elasticsearch-126620990.us-east-1.elb.amazonaws.com', 19200)]
# ES_APP_SS_ACCESS_ID = 'bdp_prod_app_ss'
# ES_APP_SS_SECRET_KEY = 'r0RiD5q6ykLl'

# Game IQ Cross Genre Citus
CITUS_GAME_IQ_CROSS_GENRE_CITUS_DB_HOSTS = [('10.2.10.132', 5432)]
CITUS_GAME_IQ_CROSS_GENRE_CITUS_DB_NAME = "aa_citus_db"
CITUS_GAME_IQ_CROSS_GENRE_CITUS_DB_ACCESS_ID = "citus_bdp_usage_qa"
CITUS_GAME_IQ_CROSS_GENRE_CITUS_DB_SECRET_KEY = "dNzWtSV3pKTx"
CITUS_GAME_IQ_CROSS_GENRE_CITUS_DB_CONNECTION_CAPACITY = 10
CITUS_GAME_IQ_CROSS_GENRE_CITUS_DB_SEMAPHORE_TIMEOUT = 7201

# Usage Citus
CITUS_USAGE_HOSTS = [('10.2.10.254', 5432)]
CITUS_USAGE_NAME = 'aa_store_db'
CITUS_USAGE_ACCESS_ID = 'citus_bdp_prod_app_int_qa'
CITUS_USAGE_SECRET_KEY = 'wZw8cfBuuklIskVG'


# Store/DNA Citus
CITUS_STORE_CITUS_DB_HOSTS = [('10.2.6.141', 5432)]
CITUS_STORE_CITUS_DB_NAME = "aa_store_db"
CITUS_STORE_CITUS_DB_ACCESS_ID = "citus_bdp_prod_app_int_qa"
CITUS_STORE_CITUS_DB_SECRET_KEY = "wZw8cfBuuklIskVG"
CITUS_STORE_CITUS_DB_CONNECTION_CAPACITY = 10
CITUS_STORE_CITUS_DB_SEMAPHORE_TIMEOUT = 7201



# metaDB Citus
CITUS_METADB_CITUS_DB_HOSTS = [('b2b-prod-uds-storage-meta-db-new.crlexxwtzodp.us-east-1.rds.amazonaws.com', 5432)]
CITUS_METADB_CITUS_DB_NAME = "metadb"
CITUS_METADB_CITUS_DB_ACCESS_ID = "app_meta_qa"
CITUS_METADB_CITUS_DB_SECRET_KEY = "IEdwiF2hmqzdKK43"
CITUS_METADB_CITUS_DB_CONNECTION_CAPACITY = 10
CITUS_METADB_CITUS_DB_SEMAPHORE_TIMEOUT = 5432



# ELB:pg-n-slave-4edc958bda550bbc.elb.us-east-1.amazonaws.com
# User:app_bdp_usage_qa
# Port:5433
# Database names:
# aa_android
# aa_amazon
# category_service

# ------------------------------------------
# db check - DEBUG ONLY - need to be removed
# ------------------------------------------
# DEFAULT_RECIPIENTS = "tom@appannie.com"
# PAGERDUTY_RECIPIENTS = "tom@appannie.com"

# %%
# !/usr/bin/env python
# coding=utf-8
# Copyright (c) 2017 App Annie Inc. All rights reserved.
"""
For production
"""
TEST = False
RUNNING_ENV = 'prod'
PG_METADB_HOSTS = [('b2b-prod-uds-storage-meta-db-new.crlexxwtzodp.us-east-1.rds.amazonaws.com', 5432)]
PG_METADB_ACCESS_ID = 'datapipeline_uds_writer'
PG_METADB_SECRET_KEY = '$mfbKd^&#D&6w6jX'
PG_METADB_NAME = 'metadb'
PG_METADB_CONNECTION_CAPACITY = 10
PG_METADB_SEMAPHORE_TIMEOUT = 7201
BACKGROUND_SERVICES_RETRY_COUNT = 5
KINESIS_METADATA_NAME = "B2C-PROD-DATA-PIPELINE-METADATA-KINESIS"
ES_METADATA_HOSTS = [('vpc-b2c-prod-dp-metadata-aes-2xenisytvftmqz5igpcwz6bkcu.us-east-1.es.amazonaws.com', 443)]
ES_METADATA_ACCESS_ID = 'AKIARIYIV4POVFTHLAFV'
ES_METADATA_SECRET_KEY = '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'
ES_METADATA_CONNECTION_CAPACITY = 10
ES_METADATA_SEMAPHORE_TIMEOUT = 7201
SLACK_USER_ID_MAPPING = {
    "XIEYUANPENG": "UJ86V0ABY",
    "GAORIHE": "UG4R6ABCY",
    "ANRUI": "U6YR3M0RF",
    "QA": "UL8AEA3KP",
    "GUANJIAN": "UHS7J9B6F",
    "XINGYUKUN": "U397U9LKW",
    "YIMING": "U6B8RJ404",
    "DEFAULT": "UJ86V0ABY",
    "YUYUANZHANG": "UJHHR5VMX"
}
ES_METADATA_INTERFACE = {
    "engine": "ES",
    "database": "metadata",
    "index_pattern": "datapipeline-job-monitoring-{type}",
    "index_settings": {
        "index.number_of_shards": ""
    },
    "doc_type": "_doc",
    "doc_id_fields": ["id"],
    "doc_fields_mapping": {}
}
SENTRY_RATING_DSN = "https://072c176e54884673b4aebffb0ff5c610:7415cdbdd8a048609b13facad83d6ae4@" \
                    "sentry.smart-sense.org/50"
PRODUCT_SERVICE_ENDPOINT = "http://prod-aa-product-service-internal.appannie.org/v1/query"
DIMENSION_SERVICE_ENDPOINT = "http://prod-aa-dimension-service-internal.appannie.org/v1/query"
MICRO_SERVICE_ACCESS_ID = "ms-fe"
MICRO_SERVICE_SECRET_KEY = "eV6zZJWXQrEs"
MICRO_SERVICE_RETRY_COUNT = 1
MICRO_SERVICE_RETRY_INTERVAL = 0
ES_APP_INT_ACCESS_ID = 'bdp_qa'
ES_APP_INT_SECRET_KEY = '577TwEzU3NK#'
ES_APP_INT_HOSTS = [('http://internal-aa-int-sdk-elasticsearch-621265199.us-east-1.elb.amazonaws.com', 19200)]
PG_DAILY_EST_CLUSTER = 'dailyest'
PG_DAILY_EST_HOSTS = [('internal-aa-prod-plproxy-internal-4-329644124.us-east-1.elb.amazonaws.com', 7432)]
PG_DAILY_EST_NAME = 'dailyest'
PG_DAILY_EST_ACCESS_ID = 'app_bdp_usage_qa'
PG_DAILY_EST_SECRET_KEY = '2mHdFW6%#REu'
PG_DAILY_EST_NODE_NUM = 8
PG_USAGE_CLUSTER = 'cohort'
PG_USAGE_HOSTS = [('internal-aa-prod-plproxy-internal-2-31838298.us-east-1.elb.amazonaws.com', 7432)]
PG_USAGE_NAME = 'cohort'
PG_USAGE_ACCESS_ID = 'app_bdp_usage_qa'
PG_USAGE_SECRET_KEY = '2mHdFW6%#REu'
PG_USAGE_NODE_NUM = 8
PG_DNA_HOSTS = [('10.2.26.136', 6432)]
PG_DNA_NAME = 'dna'
PG_DNA_ACCESS_ID = 'app_bdp_usage_qa'
PG_DNA_SECRET_KEY = '2mHdFW6%#REu'
PG_AA_HOSTS = [('10.2.26.136', 6432)]
PG_AA_NAME = 'aa'
PG_AA_ACCESS_ID = 'app_bdp_usage_qa'
PG_AA_SECRET_KEY = '2mHdFW6%#REu'
# Amazon App PG
PG_AA_AMAZON_HOSTS = [('pg-n-slave-4edc958bda550bbc.elb.us-east-1.amazonaws.com', 5433)]
PG_AA_AMAZON_NAME = 'aa_amazon'
PG_AA_AMAZON_ACCESS_ID = 'app_bdp_usage_qa'
PG_AA_AMAZON_SECRET_KEY = '2mHdFW6%#REu'
#  PG AA Android
PG_AA_ANDROID_HOSTS = [('pg-n-slave-4edc958bda550bbc.elb.us-east-1.amazonaws.com', 5433)]
PG_AA_ANDROID_NAME = 'aa_android'
PG_AA_ANDROID_ACCESS_ID = 'app_bdp_usage_qa'
PG_AA_ANDROID_SECRET_KEY = '2mHdFW6%#REu'
# App Store Rank Citus
CITUS_AA_CITUS_DB_HOSTS = [('10.2.10.132', 5432)]
CITUS_AA_CITUS_DB_ACCESS_ID = 'citus_bdp_usage_qa'
CITUS_AA_CITUS_DB_SECRET_KEY = 'dNzWtSV3pKTx'
CITUS_AA_CITUS_DB_NAME = 'aa_citus_db'
CITUS_AA_CITUS_DB_CONNECTION_CAPACITY = 2
CITUS_AA_CITUS_DB_SEMAPHORE_TIMEOUT = 7201
# ASO Citus
CITUS_ASO_STORE_HOSTS = [('internal-aa-citus-mkt-elb-1511434527.us-east-1.elb.amazonaws.com', 7432)]
CITUS_ASO_STORE_NAME = 'aa_mkt_db'
CITUS_ASO_STORE_ACCESS_ID = 'citus_mkt_qa'
CITUS_ASO_STORE_SECRET_KEY = 'rn*Wh%osCl2C'
CITUS_ASO_STORE_CONNECTION_CAPACITY = 10
CITUS_ASO_STORE_SEMAPHORE_TIMEOUT = 7201
# MKT Citus
CITUS_MKT_HOSTS = [('internal-aa-citus-mkt-elb-1511434527.us-east-1.elb.amazonaws.com', 7432)]
CITUS_MKT_NAME = 'aa_mkt_db'
CITUS_MKT_ACCESS_ID = 'citus_mkt_qa'
CITUS_MKT_SECRET_KEY = 'rn*Wh%osCl2C'
CITUS_MKT_CONNECTION_CAPACITY = 10
CITUS_MKT_SEMAPHORE_TIMEOUT = 7201
# UDS General
ES_UDS_GENERAL_HOSTS = [('http://internal-aa-int-uds-elasticsearch-124841367.us-east-1.elb.amazonaws.com', 19200)]
ES_UDS_GENERAL_ACCESS_ID = 'app_bdp_usage_qa'
ES_UDS_GENERAL_SECRET_KEY = 'euIGw5c6cP3D'
ES_UDS_GENERAL_CONNECTION_CAPACITY = 1
ES_UDS_GENERAL_SEMAPHORE_TIMEOUT = 36000
# ASO ES
ES_ASO_HOSTS = [('http://internal-aa-prod-int-elasticsearch-v5-1589259492.us-east-1.elb.amazonaws.com', 19200)]
ES_ASO_ACCESS_ID = 'app_bdp_usage_qa'
ES_ASO_SECRET_KEY = 'euIGw5c6cP3D'
ES_ASO_CONNECTION_CAPACITY = 1
ES_ASO_SEMAPHORE_TIMEOUT = 36000
# ASO SOV ES
ES_ASO_SOV_HOSTS = [('http://internal-aa-prod-int-elasticsearch-v5-1589259492.us-east-1.elb.amazonaws.com', 19200)]
ES_ASO_SOV_ACCESS_ID = 'app_bdp_usage_qa'
ES_ASO_SOV_SECRET_KEY = 'euIGw5c6cP3D'
ES_ASO_SOV_CONNECTION_CAPACITY = 2
ES_ASO_SOV_SEMAPHORE_TIMEOUT = 60
# ASO Citus
CITUS_ASO_CITUS_DB_HOSTS = [('internal-aa-citus-mkt-elb-1511434527.us-east-1.elb.amazonaws.com', 7432)]
CITUS_ASO_CITUS_DB_NAME = 'aa_mkt_db'
CITUS_ASO_CITUS_DB_ACCESS_ID = 'citus_mkt_qa'
CITUS_ASO_CITUS_DB_SECRET_KEY = 'rn*Wh%osCl2C'
CITUS_ASO_CITUS_DB_CONNECTION_CAPACITY = 10
CITUS_ASO_CITUS_DB_SEMAPHORE_TIMEOUT = 7201
# Advanced Review Citus
CITUS_ADVANCEDREVIEW_CITUS_DB_HOSTS = [('10.2.10.132', 5432)]
CITUS_ADVANCEDREVIEW_CITUS_DB_NAME = 'aa_citus_db'
CITUS_ADVANCEDREVIEW_CITUS_DB_CONNECTION_CAPACITY = 10
CITUS_ADVANCEDREVIEW_CITUS_DB_SEMAPHORE_TIMEOUT = 7201
CITUS_ADVANCEDREVIEW_CITUS_DB_ACCESS_ID = 'citus_mkt_qa'
CITUS_ADVANCEDREVIEW_CITUS_DB_SECRET_KEY = 'rn*Wh%osCl2C'

ES_ADV_REVIEW_HOSTS = [('http://internal-internel-review-es-v7-1286999769.us-east-1.elb.amazonaws.com', 19200)]
ES_ADV_REVIEW_ACCESS_ID = 'bdp_qa'
ES_ADV_REVIEW_SECRET_KEY = '6trmJcZBJrKWdtN2'
ES_ADV_REVIEW_CONNECTION_CAPACITY = 15
ES_ADV_REVIEW_SEMAPHORE_TIMEOUT = 7200

# not used
# ES_APP_SS_HOSTS = [('http://internal-aa-int-ss-review-elasticsearch-126620990.us-east-1.elb.amazonaws.com', 19200)]
# ES_APP_SS_ACCESS_ID = 'bdp_prod_app_ss'
# ES_APP_SS_SECRET_KEY = 'r0RiD5q6ykLl'
# ELB:pg-n-slave-4edc958bda550bbc.elb.us-east-1.amazonaws.com
# User:app_bdp_usage_qa
# Port:5433
# Database names:
# aa_android
# aa_amazon
# category_service
# ------------------------------------------
# db check - DEBUG ONLY - need to be removed
# ------------------------------------------
# DEFAULT_RECIPIENTS = "tom@appannie.com"
# PAGERDUTY_RECIPIENTS = "tom@appannie.com"

# Game IQ Cross Genre Citus
CITUS_GAME_IQ_CROSS_GENRE_CITUS_DB_HOSTS = [('10.2.10.132', 5432)]
CITUS_GAME_IQ_CROSS_GENRE_CITUS_DB_NAME = "aa_citus_db"
CITUS_GAME_IQ_CROSS_GENRE_CITUS_DB_ACCESS_ID = "citus_bdp_usage_qa"
CITUS_GAME_IQ_CROSS_GENRE_CITUS_DB_SECRET_KEY = "dNzWtSV3pKTx"
CITUS_GAME_IQ_CROSS_GENRE_CITUS_DB_CONNECTION_CAPACITY = 10
CITUS_GAME_IQ_CROSS_GENRE_CITUS_DB_SEMAPHORE_TIMEOUT = 7201

# %%
# %%sh
# curl -u bdp_qa:6trmJcZBJrKWdtN2 -XGet http://internal-internel-review-es-v7-1286999769.us-east-1.elb.amazonaws.com:19200/_cat/indices/*

# %%
# %%sh
