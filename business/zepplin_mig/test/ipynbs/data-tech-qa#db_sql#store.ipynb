# %%
# %spark.pyspark

import psycopg2
import datetime



citus_dsn_ = (
    "dbname='{db}' user='{user}' password='{password}' "
    "host='{host}' port='{port}'".format(
        db="aa_store_db",
        user="citus_bdp_prod_app_int_qa",
        host="10.2.6.141",
        password="wZw8cfBuuklIskVG",
        port=5432
    )
)



sql = "SELECT date,device_code,count(distinct(app_id)) FROM store.store_est_fact_v6  WHERE date between '201{}-01-01' AND '201{}-01-01' GROUP BY date,device_code ORDER BY date ASC;"

def query(dsn, sql):
    with psycopg2.connect(dsn) as conn:
        conn.autocommit = True
        with conn.cursor() as cur:
            cur.execute(sql)
            result = cur.fetchall()
            conn.commit()
    return result

print "%table {}\t{}\t{}".format( "date", "device_code", "count")

for i in range (1,9):
    test_result = query(citus_dsn_, sql.format(i, i+1))

    for result in test_result:
        date,device_code,count = result
        print "{}\t{}\t{}".format(date.strftime("%Y-%m-%d"), device_code, count)

# %%
# %sh
aws s3 ls s3://b2c-prod-dca-store-estimates/store_est/v_final/DAY/2010-09-01/ios/sbe_est_app/143441/ | grep -v "_SUCCESS"
aws s3 ls s3://b2c-prod-dca-store-estimates/store_est/v_final/DAY/2011-09-01/ios/sbe_est_app/143441/ | grep -v "_SUCCESS"
aws s3 ls s3://b2c-prod-dca-store-estimates/store_est/v_final/DAY/2012-09-01/ios/sbe_est_app/143441/ | grep -v "_SUCCESS"
aws s3 ls s3://b2c-prod-dca-store-estimates/store_est/v_final/DAY/2013-09-01/ios/sbe_est_app/143441/ | grep -v "_SUCCESS"
aws s3 ls s3://b2c-prod-dca-store-estimates/store_est/v_final/DAY/2014-09-01/ios/sbe_est_app/143441/ | grep -v "_SUCCESS"
aws s3 ls s3://b2c-prod-dca-store-estimates/store_est/v_final/DAY/2015-09-01/ios/sbe_est_app/143441/ | grep -v "_SUCCESS"
aws s3 ls s3://b2c-prod-dca-store-estimates/store_est/v_final/DAY/2016-09-01/ios/sbe_est_app/143441/ | grep -v "_SUCCESS"
aws s3 ls s3://b2c-prod-dca-store-estimates/store_est/v_final/DAY/2017-09-01/ios/sbe_est_app/143441/ | grep -v "_SUCCESS"
aws s3 ls s3://b2c-prod-dca-store-estimates/store_est/v_final/DAY/2018-09-01/ios/sbe_est_app/143441/ | grep -v "_SUCCESS"

# %%
# %%sh
#
# aws s3 ls s3://b2c-prod-dca-store-estimates/store_est/v_final/DAY/2011-01-03/ios/market_size/0/

# %%
# %%sh
