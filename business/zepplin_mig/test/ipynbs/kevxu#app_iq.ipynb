# %%
# %%sh
#
# PGPASSWORD='9KRMPySxvw9elJqk' psql -h udw-aurora-prod.cluster-ro-crlexxwtzodp.us-east-1.rds.amazonaws.com -U app_aurora_bdp_qa -d aa_intelligence_production -p 5432 << EOF
#
# select * from ADL_MASTER.DIM_TAG_RELATION_V2 where TAG_TYPE_CODE != 'custom' and IQ_TYPE_CODE != 'custom' and parent_tag_key != 400013 and product_key = 1000600000437356;
#
# EOF

# %%
# %%sh
#
# PGPASSWORD='2mHdFW6%#REu' psql -h 10.2.26.136  -U app_bdp_usage_qa -d dna -p 6432 << EOF
#
# \d;
#
# select * from dna_genre_product_mapping where product_id in (1000600000487220);
#
# select * from dna_genre_id_unified_product_mapping where unified_product_id in (20600003409228, 1057968965, 1223397201, 20600012370624, 1000600000763050, 1472240319, 1000600000487220, 20600009838393, 1000600000608876) order by unified_product_id;
#
# EOF

# %%
# %%sh
