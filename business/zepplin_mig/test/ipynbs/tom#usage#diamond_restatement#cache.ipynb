# %%
spark.

# %%
# %%sh
#
# # aws s3 ls s3://b2c-prod-int-cache-top-chart/usage_segment_by_age_gender/v4/weekly/2013-01-12/AU/android-all/all/all/top_chart.txt
#
# # aws s3 ls s3://b2c-prod-int-cache-top-chart/usage_segment_by_age_gender/v4/weekly/2013-01-12/ --recursive --summarize | grep "Total Objects:"
# # aws s3 ls s3://b2c-prod-int-cache-top-chart/usage_segment_by_age_gender/v4/daily/2021-01-19/ --recursive --summarize | grep "Total Objects:"
#
#
# #aws s3 ls s3://b2c-prod-int-cache-top-chart/usage_segment_by_age_gender/v5/monthly/2021-03-31/ID/android-phone/gte25/male/top_chart.txt
#
# aws s3 ls s3://b2c-prod-int-cache-top-chart/usage_segment_by_age_gender/v4/monthly/2021-03-31/ID/android-phone/gte25/male/top_chart.txt
# aws s3 ls s3://b2c-prod-int-cache-top-chart/usage_segment_by_age_gender/v5/monthly/2021-03-31/ID/android-phone/gte25/male/top_chart.txt
#
# aws s3 ls --recursive --summarize  s3://b2c-prod-int-cache-top-chart/usage_segment_by_age_gender/v5/monthly/2021-03-31/

# %%
# %%sh
#
#
# echo -e "%table date \t version \t count"
#
# d=$(date +'%Y-%m-%d')
#
# for date_delta in {${max_days}..1}; do
#   date=$(date -I -d "$d - $date_delta day")
#   (aws s3 ls --recursive --summarize  s3://b2c-prod-int-cache-top-chart/usage_segment_by_age_gender/v5/weekly/$date/ | grep "Total Size:" | grep -v "Total Size: 0" |  awk '{ print "'$date'","\t","v5","\t",$3 }')  || echo "$date \t -100"
#   (aws s3 ls --recursive --summarize  s3://b2c-prod-int-cache-top-chart/usage_segment_by_age_gender/v4/weekly/$date/ | grep "Total Size:" | grep -v "Total Size: 0" |  awk '{ print "'$date'","\t","v4","\t",$3 }')  || echo "$date \t -100"
#
# done

# %%
# %%sh
#
#
# echo -e "%table date \t version \t count"
#
# d=$(date +'%Y-%m-%d')
#
# for date_delta in {${max_days}..1}; do
#   date=$(date -I -d "$d - $date_delta day")
#   (aws s3 ls --recursive --summarize  s3://b2c-prod-int-cache-top-chart/usage_segment_by_age_gender/v5/weekly/$date/ | grep "Total Objects:" | grep -v "Total Objects: 0" |  awk '{ print "'$date'","\t","v5","\t",$3 }')  || echo "$date \t -100"
#   (aws s3 ls --recursive --summarize  s3://b2c-prod-int-cache-top-chart/usage_segment_by_age_gender/v4/weekly/$date/ | grep "Total Objects:" | grep -v "Total Objects: 0" |  awk '{ print "'$date'","\t","v4","\t",$3 }')  || echo "$date \t -100"
#
# done

# %%
# %%sh
#
#
# echo -e "%table date \t version \t count"
#
# d=$(date +'%Y-%m-%d')
#
# for date_delta in {${max_days}..1}; do
#   date=$(date -I -d "$d - $date_delta day")
#   (aws s3 ls --recursive --summarize  s3://b2c-prod-int-cache-top-chart/usage_segment_by_age_gender/v5/monthly/$date/ | grep "Total Objects:" | grep -v "Total Objects: 0" |  awk '{ print "'$date'","\t","v5","\t",$3 }')  || echo "$date \t -100"
#   (aws s3 ls --recursive --summarize  s3://b2c-prod-int-cache-top-chart/usage_segment_by_age_gender/v4/monthly/$date/ | grep "Total Objects:" | grep -v "Total Objects: 0" |  awk '{ print "'$date'","\t","v4","\t",$3 }')  || echo "$date \t -100"
#
# done

# %%
# %%sh
#
#
# echo -e "%table date \t version \t count"
#
# d=$(date +'%Y-%m-%d')
#
# for date_delta in {${max_days}..1}; do
#   date=$(date -I -d "$d - $date_delta day")
#   (aws s3 ls --recursive --summarize  s3://b2c-prod-int-cache-top-chart/usage_usage_penetration/v5/weekly/$date/ | grep "Total Objects:" | grep -v "Total Objects: 0" |  awk '{ print "'$date'","\t","v5","\t",$3 }')  || echo "$date \t -100"
#   (aws s3 ls --recursive --summarize  s3://b2c-prod-int-cache-top-chart/usage_usage_penetration/v4/weekly/$date/ | grep "Total Objects:" | grep -v "Total Objects: 0" |  awk '{ print "'$date'","\t","v4","\t",$3 }')  || echo "$date \t -100"
#
# done

# %%
# %%sh
#
#
# echo -e "%table date \t version \t count"
#
# d=$(date +'%Y-%m-%d')
#
# for date_delta in {${max_days}..1}; do
#   date=$(date -I -d "$d - $date_delta day")
#   (aws s3 ls --recursive --summarize  s3://b2c-prod-int-cache-top-chart/usage_usage_penetration/v5/monthly/$date/ | grep "Total Objects:" | grep -v "Total Objects: 0" |  awk '{ print "'$date'","\t","v5","\t",$3 }')  || echo "$date \t -100"
#   (aws s3 ls --recursive --summarize  s3://b2c-prod-int-cache-top-chart/usage_usage_penetration/v4/monthly/$date/ | grep "Total Objects:" | grep -v "Total Objects: 0" |  awk '{ print "'$date'","\t","v4","\t",$3 }')  || echo "$date \t -100"
#
# done

# %%
# %%sh
#
# PGPASSWORD='9KRMPySxvw9elJqk' psql -h udw-aurora-prod.cluster-ro-crlexxwtzodp.us-east-1.rds.amazonaws.com -U app_aurora_bdp_qa -d aa_intelligence_production -p 5432 << EOF
#
# \dv adl_usage_paid_internal.fact_usage_basic_v1
#
#
# --select * from adl_usage_paid_internal.fact_usage_basic_v1 where date='2020-01-01' and product_key=284882215 limit 5;
#
#
# select granularity_code,date,count(1) from adl_usage_paid_internal.fact_usage_basic_v1 where date between '2018-06-03'  and '2021-08-07' and product_key in( 284882215, 20600000009072) group by granularity_code,date order by granularity_code,date;
#
#
# EOF

# %%
# %%sh
#
# PGPASSWORD='9KRMPySxvw9elJqk' psql -h udw-aurora-prod.cluster-ro-crlexxwtzodp.us-east-1.rds.amazonaws.com -U app_aurora_bdp_qa -d aa_intelligence_production -p 5432 << EOF
#
# \dv adl_usage_paid_internal.fact_usage_basic_v1
#
#
# select * from adl_usage_paid_internal.fact_usage_basic_v1 where date='2021-03-31' and product_key=284882215 and country_code='ID' and device_code='ios-phone' limit 5;
#
#
# EOF

# %%
# %%sh
#
# PGPASSWORD='9KRMPySxvw9elJqk' psql -h udw-aurora-prod.cluster-ro-crlexxwtzodp.us-east-1.rds.amazonaws.com -U app_aurora_bdp_qa -d aa_intelligence_production -p 5432 << EOF
#
# \dv adl_usage_paid_internal.fact_usage_retention_v1
#
#
# select * from adl_usage_paid.fact_usage_retention_v1 where date='2021-03-31' and product_key=284882215 and country_code='ID' and device_code='ios-phone' limit 5;
#
# select date, granularity_code, count(*) from adl_usage_paid.fact_usage_retention_v1  where date between '2021-03-01' and '2021-09-01' group by granularity_code, date order by  granularity_code, date;
#
# EOF

# %%
# %%sh
