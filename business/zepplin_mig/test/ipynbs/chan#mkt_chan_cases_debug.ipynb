# %%
# %%sh
#
# PGPASSWORD='rn*Wh%osCl2C' psql -h internal-aa-citus-mkt-elb-1511434527.us-east-1.elb.amazonaws.com  -U citus_mkt_qa -d aa_mkt_db -p 7432 << EOF
#
# select *  from market.market_creative_cat_rank_fact_v1 limit 1;
# select *  from market.market_creative_adapp_seen_fact_v1 limit 1;
# select *  from market.market_creative_log_fact_v1 limit 1;
# select *  from market.market_creative_adapp_fact_v2 limit 1;
#
#
# EOF

# %%
# %%sh
# PGPASSWORD='rn*Wh%osCl2C' psql -h internal-aa-citus-mkt-elb-1511434527.us-east-1.elb.amazonaws.com   -U citus_mkt_qa -d aa_mkt_db -p 7432 << EOF
#
#
# select date ,count(DISTINCT(country_code))  from market.market_creative_log_fact_v1
# where  ad_app_id=930452496 and creative_id=90100000082153 and country_code != 'WW' and device_code = 'ios-phone' and date >='2016-06-01' and date <='2016-06-30'
# group by date
# ;
#
# select  DISTINCT date , country_code from  market.market_creative_log_fact_v1
# where  ad_app_id=930452496 and creative_id=90100000082153 and country_code != 'WW' and device_code = 'ios-phone' and date in ('2016-06-04','2016-06-11','2016-06-18','2016-06-25')
# ;
#
#
# select date,country_count , country_list  from market.market_creative_adapp_fact_v2
# where  ad_app_id=930452496 and creative_id=90100000082153 and country_code = 'WW' and granularity = 'weekly' and device_code = 'ios-phone' and ad_platform_id = 1
#  and date >='2016-06-01' and date <='2016-06-30'
# ;
#
#
# select date,country_count , country_list  from market.market_creative_adapp_fact_v2
# where  ad_app_id=930452496 and creative_id=90100000082153 and country_code = 'WW' and granularity = 'monthly' and device_code = 'ios-phone' and ad_platform_id = 1
#  and date >='2016-06-01' and date <='2016-06-30'
# ;
#
#
#
#
# EOF

# %%
# %%sh
#
# PGPASSWORD='rn*Wh%osCl2C' psql -h internal-aa-citus-mkt-elb-1511434527.us-east-1.elb.amazonaws.com   -U citus_mkt_qa -d aa_mkt_db -p 7432 << EOF
#
# /*
# select date ,count(DISTINCT(country_code))  from market.market_creative_log_fact_v1
# where  ad_app_id=930452496 and creative_id=90100000082153 and country_code != 'WW' and device_code = 'ios-phone' and date >='2016-06-01' and date <='2016-06-30'
# group by date
# ;
#
#
# select  ad_app_id, creative_id  from  market.market_creative_log_fact_v1
# where  country_code = 'WW' and ad_platform_id =1 and device_code = 'ios-phone' and date > '2019-01-01'
# group by  ad_app_id, creative_id
# having count(DISTINCT(ad_platform_id)) >3
# limit 10
# ;
# */
#
#
# select *  from market.market_creative_adapp_fact_v2
# where ad_platform_count > 3 and date = '2020-05-02' and device_code = 'ios-phone' and  ad_app_id=1460422450 and creative_id =90100015236012
# ;
#
# select *  from  market.market_creative_log_fact_v1
# where device_code = 'ios-phone' and date = '2020-05-02' and ad_app_id=1460422450 and creative_id =90100015236012
# ;
#
#
# /*
# select date,country_count , country_list  from market.market_creative_adapp_fact_v2
# where  ad_app_id=930452496 and creative_id=90100000082153 and country_code = 'WW' and granularity = 'weekly' and device_code = 'ios-phone' and ad_platform_id = 1
#  and date >='2016-06-01' and date <='2016-06-30'
# ;
#
#
# select date,country_count , country_list  from market.market_creative_adapp_fact_v2
# where  ad_app_id=930452496 and creative_id=90100000082153 and country_code = 'WW' and granularity = 'monthly' and device_code = 'ios-phone' and ad_platform_id = 1
#  and date >='2016-06-01' and date <='2016-06-30'
# ;
# */
#
#
#
#
# EOF

# %%
# %%sh
