# %%
# %%sh
# PGPASSWORD='rn*Wh%osCl2C' psql -h internal-aa-citus-mkt-elb-1511434527.us-east-1.elb.amazonaws.com -x  -U citus_mkt_qa -d aa_mkt_db -p 7432 << EOF
#
#  -- select creative_count from market.market_adapp_fact_v1 where granularity='monthly' AND device_code = 'ios-phone' AND  country_code = 'BR' AND date='2020-03-31' AND ad_app_id=284035177 and ad_platform_id=325;
#
#  -- select count(distinct country_code) from  market.market_creative_adapp_fact_v1 where granularity='weekly' and date='2015-04-11';
#
# -- select * from market.market_creative_adapp_fact_v2 where ad_platform_id=1  and ad_app_id ...  limit 1;
# select * from market.market_creative_adapp_fact_v2   limit 1;
#
#
#
#
#
# EOF

# %%
# %%sh
# PGPASSWORD='rn*Wh%osCl2C' psql -h internal-aa-citus-mkt-elb-1511434527.us-east-1.elb.amazonaws.com -x -U citus_mkt_qa -d aa_mkt_db -p 7432 << EOF
#
# select *  from market.market_creative_adapp_fact_v2
# ;
#
# select device_code,country_code,granularity,date,ad_platform_id,ad_app_id,creative_id,pub_app_count,pub_app_count  from market.market_creative_adapp_fact_v2
# where
#     pub_app_count  = 0
#     OR pub_app_count  is null
#     limit 10;
#
# EOF

# %%
# %%sh
# PGPASSWORD='rn*Wh%osCl2C' psql -h internal-aa-citus-mkt-elb-1511434527.us-east-1.elb.amazonaws.com  -U citus_mkt_qa -d aa_mkt_db -p 7432 << EOF
#
#
# select device_code,country_code,granularity,date,ad_platform_id,ad_app_id,creative_id,ad_platform_count,ad_platform_list  from market.market_creative_adapp_fact_v2
# where
#     (ad_platform_count  = 0 AND ad_platform_list is not null)
#     OR (ad_platform_count  != 0 AND ad_platform_list is  null)
#     OR (ad_platform_count  is null  AND ad_platform_list is not null)
#     OR array_length(string_to_array(ad_platform_list, ','),1) <> ad_platform_count
#
#     limit 10;
# EOF

# %%
# %%sh
# PGPASSWORD='rn*Wh%osCl2C' psql -h internal-aa-citus-mkt-elb-1511434527.us-east-1.elb.amazonaws.com  -U citus_mkt_qa -d aa_mkt_db -p 7432 << EOF
#
# select device_code,country_code,granularity,date,ad_platform_id,ad_app_id,creative_id,pub_app_count,pub_app_list  from market.market_creative_adapp_fact_v2
# where
#     (pub_app_count  = 0 AND pub_app_list is not null)
#     OR (pub_app_count  != 0 AND pub_app_list is  null)
#     OR (pub_app_count  is null AND pub_app_list is not null)
#     OR array_length(string_to_array(pub_app_list, ','),1) <> pub_app_count
#
#     limit 10;
# EOF

# %%
# %%sh
# PGPASSWORD='rn*Wh%osCl2C' psql -h internal-aa-citus-mkt-elb-1511434527.us-east-1.elb.amazonaws.com  -U citus_mkt_qa -d aa_mkt_db -p 7432 << EOF
#
# select device_code,country_code,granularity,date,ad_platform_id,ad_app_id,creative_id,pub_app_count,pub_app_count,country_count,country_list  from market.market_creative_adapp_fact_v2
# where
#      (country_count  = 0 AND country_list is not null)
#     OR (country_count  != 0 AND country_list is  null)
#     OR (country_count  is null AND country_list is not null)
#     OR array_length(string_to_array(country_list, ','),1) <> country_count
#     limit 10;
#
# EOF

# %%
# %%sh
# PGPASSWORD='rn*Wh%osCl2C' psql -h internal-aa-citus-mkt-elb-1511434527.us-east-1.elb.amazonaws.com  -U citus_mkt_qa -d aa_mkt_db -p 7432 << EOF
#
# select device_code,country_code,granularity,date,ad_platform_id,ad_app_id,creative_id,pub_app_count,pub_app_list  from market.market_creative_adapp_fact_v2
# where
# pub_app_count is null AND pub_app_list is not null
#
#     limit 10;
#
#
# EOF

# %%
# %%sh
#
# %sss

# %%
# %%sh
#
# PGPASSWORD='rn*Wh%osCl2C' psql -h internal-aa-citus-mkt-elb-1511434527.us-east-1.elb.amazonaws.com  -U citus_mkt_qa -d aa_mkt_db -p 7432 << EOF
#
# select *  from market.market_creative_cat_rank_fact_v1 limit 1;
# select *  from market.market_creative_adapp_seen_fact_v1 limit 1;
# select *  from market.market_creative_log_fact_v1 limit 1;
# select *  from market.market_creative_adapp_fact_v2 limit 1;
#
#
# EOF

# %%
# %%sh
# PGPASSWORD='rn*Wh%osCl2C' psql -h internal-aa-citus-mkt-elb-1511434527.us-east-1.elb.amazonaws.com -x -U citus_mkt_qa -d aa_mkt_db -p 7432 << EOF
#
# select *  from market.market_creative_adapp_fact_v2
# where (creative_share_of_ad_platform is null and creative_share_of_advertiser is not null)
# limit 10;
#
#
# EOF

# %%
# %%sh
#
#
# PGPASSWORD='rn*Wh%osCl2C' psql -h internal-aa-citus-mkt-elb-1511434527.us-east-1.elb.amazonaws.com  -U citus_mkt_qa -d aa_mkt_db -p 7432 << EOF
#
#
# select *  from market.market_creative_adapp_seen_fact_v1
# where
# creative_id= 90100003269338  AND ad_app_id = 1400072268 AND device_code = 'ios-phone' AND ad_platform_id=142
# ;
#
#
#
# EOF

# %%
# %%sh
#
# PGPASSWORD='rn*Wh%osCl2C' psql -h internal-aa-citus-mkt-elb-1511434527.us-east-1.elb.amazonaws.com  -U citus_mkt_qa -d aa_mkt_db -p 7432 << EOF
#
# /*
# select count(distinct(ad_app_id)) from market.market_creative_adapp_seen_fact_v1 where country_code = 'WW' and ad_app_id not in (select distinct(ad_app_id) from market.market_creative_adapp_seen_fact_v1 where country_code != 'WW');
# */
#
# /*
# select * from  market.market_creative_cat_rank_fact_v1 limit 1;
#
#
#
#
#
#
#
#
#
# select ad_app_id, creative_id ,category_id, count(*)  from market.market_creative_cat_rank_fact_v1
# WHERE country_code != 'WW'
# AND device_code = 'ios-phone' AND granularity='monthly' AND date = '2015-04-30'
# Group by ad_app_id,creative_id,category_id having count(*) != 2
# order by count(*) desc
# limit 10;
# */
#
# /*
#
# select ad_app_id, creative_id ,category_id, count(*)  from market.market_creative_cat_rank_fact_v1
# WHERE
#  device_code = 'ios-phone' AND granularity='monthly' AND date = '2019-01-31'
# Group by ad_app_id,creative_id,category_id -- having count(*) = 2
# order by count(*) desc
# limit 10;
# */
#
#
#
# select *  from market.market_creative_cat_rank_fact_v1
# WHERE
#  device_code = 'ios-phone' AND granularity='monthly' AND date = '2019-01-31'   AND creative_id= 90100003269338  AND ad_app_id = 1400072268  AND category_id = 100016
# ;
#
#
# select device_code,country_code,granularity,date,ad_platform_id,ad_app_id,creative_id,pub_app_count,pub_app_count,country_count,country_list  from market.market_creative_adapp_fact_v2
# where
#  device_code = 'ios-phone' AND granularity='monthly' AND date = '2019-01-31'   AND creative_id= 90100003269338  AND ad_app_id = 1400072268
#  ;
#
# /*
# select *  from market.market_creative_cat_rank_fact_v1
# WHERE country_code != 'WW'
# AND device_code = 'ios-phone' AND granularity='monthly' AND date = '2015-04-30'  AND creative_id= 90100000133517  AND ad_app_id = 839703707 AND category_id = 100002
# limit 10;
# */
#
#
#
#
# EOF

# %%
# %%sh
# PGPASSWORD='rn*Wh%osCl2C' psql -h internal-aa-citus-mkt-elb-1511434527.us-east-1.elb.amazonaws.com  -U citus_mkt_qa -d aa_mkt_db -p 7432 << EOF
#
# select * from market.market_creative_cat_rank_fact_v1 where country_code='WW' limit 1;
# select * from market.market_creative_adapp_seen_fact_v1 where country_code='WW' limit 1;
# select * from market.market_creative_adapp_fact_v2 where country_code='WW' limit 1;
#
#
#
# EOF

# %%
from applications.db_check_v1.cases.market.test_market_regression import TestMarketCountIssueWeeklyRegression, \
    TestMarketCountIssueMonthlyRegression
from applications.db_check_v1.cases.market.constants import COUNTRY_CODE_BASIC, AD_APP_ID    
from applications.db_check_v1.common.db_check_utils import _get_date_from_refresh_routing_config, query    

from conf.settings import CITUS_MKT_NAME, CITUS_MKT_ACCESS_ID, \
    CITUS_MKT_SECRET_KEY, CITUS_MKT_HOSTS

# PGPASSWORD='rn*Wh%osCl2C' psql -h internal-aa-citus-mkt-elb-1511434527.us-east-1.elb.amazonaws.com  -U citus_mkt_qa -d aa_mkt_db -p 7432 << EOF
CITUS_MKT_NAME='aa_mkt_db'
CITUS_MKT_ACCESS_ID= 'citus_mkt_qa'
CITUS_MKT_HOSTS=[('internal-aa-citus-mkt-elb-1511434527.us-east-1.elb.amazonaws.com',7432)]
CITUS_MKT_SECRET_KEY='rn*Wh%osCl2C'

citus_dsn = (
    "dbname='{db}' user='{user}' password='{password}' "
    "host='{host}' port='{port}'".format(
        db=CITUS_MKT_NAME,
        user=CITUS_MKT_ACCESS_ID,
        host=CITUS_MKT_HOSTS[0][0],
        password=CITUS_MKT_SECRET_KEY,
        port=CITUS_MKT_HOSTS[0][1]
    )
)
    
    
sql = """select * from market.market_creative_adapp_fact_v2 limit 1"""
result = query(citus_dsn, sql)
print(result)

for 11000
