# %%
data = spark.read.parquet("s3://aardvark-prod-pdx-mdm-to-int/city_level/city_info/routine/granularity=monthly/date=2018-12-31/")show(10)

# %%
# %%sh
# aws s3 ls s3://aardvark-prod-pdx-mdm-to-int/city_level/city_info/routine/granularity=monthly/date=2018-12-31/

# %%
# %%sh
