# %%
aws s3 ls s3://aardvark-prod-dca-data/oss/CAVIAR_KEYWORD_METRICS/version=1.0.0/range_type=DAY/date=2021-02-22/platform_id=2/country=AU/metric=cpc/

# %%
# %%sh
# aws s3 ls s3://aardvark-prod-dca-data/oss/CAVIAR_KEYWORD_METRICS/version=1.0.0/range_type=DAY/date=2021-02-22/platform_id=2/country=US/metric=cpc/

# %%
spark.read.parquet("s3://aardvark-prod-dca-data/oss/CAVIAR_KEYWORD_METRICS/version=1.0.0/range_type=DAY/date=2021-02-22/platform_id=2/country=US/metric=cpc/").show(10)

# %%
spark.read.parquet("s3://aardvark-prod-dca-data/oss/DOWNLOAD_CHANNEL_KPI/version=v1.0.0/range_type=DAY/date=2021-02-19/platform=ios/").filter("app_id=284882215").show(10)
