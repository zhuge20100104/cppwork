# %%
# %%sh
#
# aws s3 ls s3://b2b-prod-int-data-pipeline-unified/unified/app-int.download-attribution.v1/metric/month=2016-08/date=2016-08-28/device_id=1001/
#
#
# # aws s3 ls s3://b2c-prod-data-pipeline-unified-store-paid/unified/download-attribution.v1/fact/
# # aws s3 ls s3://b2c-prod-data-pipeline-unified-store-paid/_obselete/download-attribution.v1/fact/
# # aws s3 ls s3://b2c-prod-data-pipeline-unified-store-paid/legacy_unified_backup/app-int.download-attribution.v1/fact/

# %%
spark.read.parquet("s3://b2b-prod-int-data-pipeline-unified/unified/app-int.download-attribution.v1/metric/month=2016-08/").show()
