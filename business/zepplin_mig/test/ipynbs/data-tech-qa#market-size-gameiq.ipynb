# %%
 # %sh

PGPASSWORD='2mHdFW6%#REu' psql -h internal-aa-prod-plproxy-internal-4-329644124.us-east-1.elb.amazonaws.com -U app_bdp_usage_qa -d dailyest -p 7432 << EOF 

select date, sum(scount) from plproxy.execute_select_nestloop(\$proxy\$ 
    select date, count(*) as scount
    from aa.genre_store_daily_estimate
    where 
        date between '2019-01-01' and '2019-12-31'

    group by date
\$proxy\$) tbl ( date DATE, scount BIGINT) group by date order by date asc;

EOF

# %%
# %%sh
