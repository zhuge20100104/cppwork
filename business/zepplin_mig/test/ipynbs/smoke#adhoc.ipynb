# %%
# %%sh
#
#
# ls -al /tmp/

# %%
# %python

import pytest

pytest.main(["cases/batch/"])

# %%
from common.cases_parser.yaml_case_parser import YamlFileParser


# import inspect
# print(inspect.getfile(YamlFileParser))
# import os
# print(os.environ)


import pytest

pytest.main(["cases/batch/"])

# %%
# %python
