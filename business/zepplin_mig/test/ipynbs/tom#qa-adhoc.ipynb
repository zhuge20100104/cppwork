# %%
# %sh
# meta_creative_pub_2002_143465_121_201708
# aws s3 ls s3://b2c-prod-data-pipeline-unified-market/unified/
aws s3 ls s3://b2c-prod-data-pipeline-unified-market/unified/app-tech.market.legacy-pub_app_ad_app_detail_estimate.v1/fact/granularity=weekly/month=2018-06/device_id=2002/store_id=0/network_id=1/


mkt.weekly_pub_app_ad_app_detail_estimate_2002_0_1_201810

# %%
# %%sh
#
# aws s3 ls --recursive s3://b2c-prod-data-pipeline-unified-market/unified/app-tech.market.legacy-pub_app_ad_app_estimate.v1/fact/ | head -n 100
#
# # aws s3 ls s3://b2c-prod-data-pipeline-unified-market/unified/app-tech.market.legacy-pub_app_ad_app_detail_estimate.v1/fact/granularity=monthly/month=2015-04/device_id=1000/

# %%
# print spark.read.parquet('s3://b2c-prod-data-pipeline-unified-market/unified/app-tech.market.legacy-meta_creative.v1/dimension/device_id=1001/store_id=35/part-1001-35.c000.gz.parquet').
# print spark.read.parquet('s3://b2c-prod-data-pipeline-unified-market/unified/app-tech.market.legacy-creative_extension_map.v1/dimension/_partition=_default_partition/part-_default_partition.c000.gz.parquet').count()



s3_list ={"creative_estimate":"s3://b2c-prod-data-pipeline-unified-market/unified/app-tech.market.legacy-creative_estimate.v1/fact/granularity=weekly/device_id=2002/store_id=143481/network_id=201/",
"creative_category":"s3://b2c-prod-data-pipeline-unified-market/unified/app-tech.market.legacy-creative_category.v1/fact/granularity=monthly/device_id=2002/store_id=143452/",
"pub_app_category":"s3://b2c-prod-data-pipeline-unified-market/unified/app-tech.market.legacy-pub_app_category.v1/fact/granularity=monthly/device_id=1001/store_id=11/",
"pub_app_ad_app_detail_estimate":"s3://b2c-prod-data-pipeline-unified-market/unified/app-tech.market.legacy-pub_app_ad_app_detail_estimate.v1/fact/granularity=monthly/month=2015-04/device_id=1001/store_id=10/",
"pub_app_ad_app_estimate":"s3://b2c-prod-data-pipeline-unified-market/unified/app-tech.market.legacy-pub_app_ad_app_estimate.v1/fact/granularity=monthly/month=2015-04/device_id=1002/store_id=10/network_id=1/",
"meta_creative":"s3://b2c-prod-data-pipeline-unified-market/unified/app-tech.market.legacy-meta_creative.v1/dimension/device_id=1001/store_id=11/",
"ad_app_pub_app_estimate":"s3://b2c-prod-data-pipeline-unified-market/unified/app-tech.market.legacy-ad_app_pub_app_estimate.v1/fact/granularity=monthly/device_id=1001/store_id=11/",
"adpo_detail_estimate":"s3://b2c-prod-data-pipeline-unified-market/unified/app-tech.market.legacy-adpo_detail_estimate.v1/fact/granularity=monthly/device_id=1000/",
"s3_path_creative_id_map":"s3://b2c-prod-data-pipeline-unified-market/unified/app-tech.market.legacy-s3_path_creative_id_map.v1/fact/granularity=monthly/device_id=1000/",
"creative_extension_map":"s3://b2c-prod-data-pipeline-unified-market/unified/app-tech.market.legacy-creative_extension_map.v1/fact/",
"ad_app_estimate":"s3://b2c-prod-data-pipeline-unified-market/unified/app-tech.market.legacy-ad_app_estimate.v1/fact/granularity=monthly/device_id=1001/store_id=11/",
"ad_app_detail_estimate":"s3://b2c-prod-data-pipeline-unified-market/unified/app-tech.market.legacy-ad_app_detail_estimate.v1/fact/granularity=monthly/device_id=1001/store_id=11/",
"meta_creative_campaign":"s3://b2c-prod-data-pipeline-unified-market/unified/app-tech.market.legacy-meta_creative_campaign.v1/fact/month=2018-01/device_id=2002/store_id=143503/network_id=121/",
"adpo_estimate":"s3://b2c-prod-data-pipeline-unified-market/unified/app-tech.market.legacy-adpo_estimate.v1/fact/granularity=monthly/device_id=1000/",
"pub_app_estimate":"s3://b2c-prod-data-pipeline-unified-market/unified/app-tech.market.legacy-pub_app_estimate.v1/fact/granularity=monthly/device_id=1001/store_id=11/",
"pub_app_ad_app_date_range_estimate":"s3://b2c-prod-data-pipeline-unified-market/unified/app-tech.market.legacy-pub_app_ad_app_date_range_estimate.v1/fact/device_id=1002/store_id=49/",
"pub_app_detail_estimate":"s3://b2c-prod-data-pipeline-unified-market/unified/app-tech.market.legacy-pub_app_detail_estimate.v1/fact/granularity=monthly/device_id=1001/store_id=11/",
"creative_detail_estimate":"s3://b2c-prod-data-pipeline-unified-market/unified/app-tech.market.legacy-creative_detail_estimate.v1/fact/granularity=monthly/device_id=1001/store_id=11/",
"ad_app_pub_estimate":"s3://b2c-prod-data-pipeline-unified-market/unified/app-tech.market.legacy-ad_app_pub_estimate.v1/fact/granularity=monthly/device_id=1001/store_id=11/",
"ad_app_category":"s3://b2c-prod-data-pipeline-unified-market/unified/app-tech.market.legacy-ad_app_category.v1/fact/granularity=monthly/device_id=1001/store_id=11/",
"creative_ad_estimate":"s3://b2c-prod-data-pipeline-unified-market/unified/app-tech.market.legacy-creative_ad_estimate.v1/fact/granularity=monthly/device_id=1001/store_id=11/",
"meta_creative_pub":"s3://b2c-prod-data-pipeline-unified-market/unified/app-tech.market.legacy-meta_creative_pub.v1/fact/month=2018-11/device_id=2001/store_id=143503/network_id=316/"}


for table in s3_list:
    try:
        df = spark.read.parquet(s3_list[table])
        items = df.limit(1).collect()
    
        for d in df.schema:
            if d.name in ["insert_id", "delete_id", "_version", "dimension_id"]:
                continue
            print "{},{},{},{}".format(table,d.name,d.dataType, items[0][d.name])
    except:
         print "{},{}".format(table, "error")

# %%
# %%sh
#
# PGPASSWORD=2mHdFW6%#REu psql -h 10.2.6.245 -p 5434 -Uapp_bdp_usage_qa -d mkt_est << EOF
# \d+ mkt.meta_creative_pub_;
#
# select * from mkt.monthly_ad_app_estimate_1001_1 limit 1;

# %%
# %%sh
# // dblist = [('10.2.6.27', 5433), ('10.2.6.245', 5434), ('10.2.6.42', 5435), ('10.2.6.148', 5436), ('10.2.6.49', 5437), ('10.2.6.52', 5438), ('10.2.6.187', 5439), ('10.2.6.254', 5440)]
#
#
# PGPASSWORD=2mHdFW6%#REu psql -h 10.2.6.245 -p 5434 -Uapp_bdp_usage_qa -d mkt_est << EOF
# select column_name from information_schema.columns where table_name = 'store_app_rank_fact_v1';

# %%
# %%sh
#
# PGPASSWORD=2mHdFW6%#REu psql -h 10.2.6.27 -p 5433 -Uapp_bdp_usage_qa -d mkt_est << EOF
# \d+ mkt.weekly_creative_estimate;
# select * from mkt.weekly_creative_estimate limit 1;

# %%
# %%sh
#
# PGPASSWORD=2mHdFW6%#REu psql -h 10.2.6.27 -p 5433 -Uapp_bdp_usage_qa -d mkt_est << EOF
# \d+ mkt.weekly_creative_estimate;
# \x
# select * from mkt.weekly_creative_estimate_1001_1_1 limit 1;

# %%
print 1

# %%
from itertools import product
from pyspark.sql import types as T
from pyspark.storagelevel import StorageLevel


list_1 = [1,2,3,4,5]
list_2 = ["a","b","c","d","e"]
partition_list = product(list_1, list_2)
schema = T.StructType([T.StructField("partition", T.StringType(), True)])

def test_partition(partition):
    return [str(partition)]


rdd = spark.sparkContext.parallelize(partition_list, 5).flatMap(lambda partition: test_partition(partition))

rdd.collect()

# %%
# %%sh
#
# // wc -l /tmp/*
#
# cat /tmp/creative_estimate_2019-08-24_00-46-25*| grep -v "0,NA,0"

# %%
# %%sh
#
# aws s3 ls s3://b2c-prod-data-pipeline-unified-market/unified/app-tech.market.legacy-creative_category.v1/fact/granularity=weekly/device_id=1002/store_id=1/
# aws s3 ls s3://b2c-prod-data-pipeline-unified-market/unified/app-tech.market.legacy-creative_category.v1/fact/granularity=weekly/device_id=1002/store_id=56/

# %%
# %%sh
# wc -l /tmp/pub_app_ad_app_estimate_2019-08-25_01-50-05_thread*
# ls -al /tmp/pub_app_ad_app_estimate_2019-08-25_01-50-05_thread*
# date

# %%
# %%sh
#
# wc -l /tmp/db2_pub_app_ad_app_estimate_*

# %%
# %sh

PGPASSWORD='2mHdFW6%#REu' psql -h pg-n-slave-4edc958bda550bbc.elb.us-east-1.amazonaws.com -U app_bdp_usage_qa -d category_service -p 5433 << EOF 
\d 

select * from category limit  1;
EOF

# %%
# %sh

PGPASSWORD='2mHdFW6%#REu' psql -h 10.2.26.136 -U app_bdp_usage_qa -d aa -p 6432 << EOF 
\d
\d+ aa_rating

select * from aa_rating limit 1;

EOF

# %%
PG_AA_RATING_HOSTS = [('10.2.26.56', 6432)]
PG_AA_RATING_ACCESS_ID = 
PG_AA_RATING_SECRET_KEY = 
PG_AA_RATING_NAME = 'aa'

PG_AA_ANDROID_RATING_HOSTS = [('10.2.25.229', 6432)]
PG_AA_ANDROID_RATING_ACCESS_ID = 
PG_AA_ANDROID_RATING_SECRET_KEY = 
PG_AA_ANDROID_RATING_NAME = 'aa_android'
