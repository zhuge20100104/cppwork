# %%
dimension/dimension/%sh

# aws s3 ls s3://b2c-prod-data-pipeline-unified-aso/unified/app-tech.aso.search-visibility.v1/
# aws s3 ls s3://b2c-prod-data-pipeline-unified-aso/unified/app-tech.aso.keyword-trafficshare.v1/fact/granularity=daily/date=2019-12-29/
# aws s3 ls s3://b2c-prod-data-pipeline-unified-aso/unified/app-tech.aso.keyword-difficulty-search-volume.v1/fact/granularity=daily/date=2019-12-29/

# %%
# %%sh

# %%
# %%sh
#
#
# aws s3 ls --recursive s3://b2c-prod-data-pipeline-unified-market/unified/market.pubapp-fact.v1/  | grep '2020-01-03' | head -n 1
# aws s3 ls --recursive s3://b2c-prod-data-pipeline-unified-market/unified/market.pub-app-impression.v1/  | grep '2020-01-03' | head -n 1
# aws s3 ls --recursive s3://b2c-prod-data-pipeline-unified-market/unified/market.pub-app-category-rank.v1/  | grep '2020-01-03' | head -n 1
# aws s3 ls --recursive s3://b2c-prod-data-pipeline-unified-dna/unified/dna.dna_universal_app_mapping.v1/  | grep '2020-01-03' | head -n 1
# aws s3 ls --recursive s3://b2c-prod-data-pipeline-unified-dna/unified/dna.dna_universal_company_office.v1/  | grep '2020-01-03' | head -n 1
# aws s3 ls --recursive s3://b2c-prod-data-pipeline-unified-dna/unified/dna.dna_universal_company.v1/  | grep '2020-01-03' | head -n 1
# aws s3 ls --recursive s3://b2c-prod-data-pipeline-unified-dna/unified/dna.in_app_dna_info_mapping.v1/  | grep '2020-01-03' | head -n 1
# aws s3 ls --recursive s3://b2c-prod-data-pipeline-unified-featured/unified/featured.apps.v2/  | grep '2020-01-03' | head -n 1
# aws s3 ls --recursive s3://b2c-prod-data-pipeline-unified-featured/unified/featured.categories.v1/  | grep '2020-01-03' | head -n 1
# aws s3 ls --recursive s3://b2c-prod-data-pipeline-unified-featured/unified/featured.games.v2/  | grep '2020-01-03' | head -n 1
# aws s3 ls --recursive s3://b2c-prod-data-pipeline-unified-featured/unified/featured.iap.v1/  | grep '2020-01-03' | head -n 1
# aws s3 ls --recursive s3://b2c-prod-data-pipeline-unified-featured/unified/featured.today.v2/  | grep '2020-01-03' | head -n 1
# aws s3 ls --recursive s3://b2c-prod-data-pipeline-unified-market/unified/market.legacy-s3_path_creative_id_map.v1/  | grep '2020-01-03' | head -n 1
# aws s3 ls --recursive s3://b2c-prod-data-pipeline-unified-market/unified/market.legacy-pub_app_estimate.v1/  | grep '2020-01-03' | head -n 1
# aws s3 ls --recursive s3://b2c-prod-data-pipeline-unified-market/unified/market.legacy-pub_app_detail_estimate.v1/  | grep '2020-01-03' | head -n 1
# aws s3 ls --recursive s3://b2c-prod-data-pipeline-unified-market/unified/market.legacy-pub_app_category.v1/  | grep '2020-01-03' | head -n 1
# aws s3 ls --recursive s3://b2c-prod-data-pipeline-unified-market/unified/market.legacy-pub_app_ad_app_estimate.v1/  | grep '2020-01-03' | head -n 1
# aws s3 ls --recursive s3://b2c-prod-data-pipeline-unified-market/unified/market.legacy-pub_app_ad_app_detail_estimate.v1/  | grep '2020-01-03' | head -n 1
# aws s3 ls --recursive s3://b2c-prod-data-pipeline-unified-market/unified/market.legacy-pub_app_ad_app_date_range_estimate.v1/  | grep '2020-01-03' | head -n 1
# aws s3 ls --recursive s3://b2c-prod-data-pipeline-unified-market/unified/market.legacy-meta_creative.v1/  | grep '2020-01-03' | head -n 1
# aws s3 ls --recursive s3://b2c-prod-data-pipeline-unified-market/unified/market.legacy-meta_creative_pub.v1/  | grep '2020-01-03' | head -n 1
# aws s3 ls --recursive s3://b2c-prod-data-pipeline-unified-market/unified/market.legacy-meta_creative_campaign.v1-old/  | grep '2020-01-03' | head -n 1
# aws s3 ls --recursive s3://b2c-prod-data-pipeline-unified-market/unified/market.legacy-meta_creative_campaign.v1/  | grep '2020-01-03' | head -n 1
# aws s3 ls --recursive s3://b2c-prod-data-pipeline-unified-market/unified/market.legacy-creative_extension_map.v1/  | grep '2020-01-03' | head -n 1
# aws s3 ls --recursive s3://b2c-prod-data-pipeline-unified-market/unified/market.legacy-creative_estimate.v1/  | grep '2020-01-03' | head -n 1
# aws s3 ls --recursive s3://b2c-prod-data-pipeline-unified-market/unified/market.legacy-creative_detail_estimate.v1/  | grep '2020-01-03' | head -n 1
# aws s3 ls --recursive s3://b2c-prod-data-pipeline-unified-mobileweb-free/unified/mobileweb.domain.v2/  | grep '2020-01-03' | head -n 1
# aws s3 ls --recursive s3://b2c-prod-data-pipeline-unified-mobileweb-paid/unified/mobile-web.app-cross-domain.v1/  | grep '2020-01-03' | head -n 1
# aws s3 ls --recursive s3://b2c-prod-data-pipeline-unified-mobileweb-paid/unified/mobile-web.basic.v1/  | grep '2020-01-03' | head -n 1
# aws s3 ls --recursive s3://b2c-prod-data-pipeline-unified-mobileweb-paid/unified/mobile-web.cross-app.v1/  | grep '2020-01-03' | head -n 1
# aws s3 ls --recursive s3://b2c-prod-data-pipeline-unified-mobileweb-paid/unified/mobile-web.cross-domain.v1/  | grep '2020-01-03' | head -n 1
# aws s3 ls --recursive s3://b2c-prod-data-pipeline-unified-mobileweb-paid/unified/mobile-web.deduplicated.v1/  | grep '2020-01-03' | head -n 1
# aws s3 ls --recursive s3://b2c-prod-data-pipeline-unified-mobileweb-paid/unified/mobile-web.domain-browser.v1/  | grep '2020-01-03' | head -n 1
# aws s3 ls --recursive s3://b2c-prod-data-pipeline-unified-mobileweb-paid/unified/mobile-web.domain-outbound.v1/  | grep '2020-01-03' | head -n 1
# aws s3 ls --recursive s3://b2c-prod-data-pipeline-unified-mobileweb-paid/unified/mobile-web.domain-referral.v1/  | grep '2020-01-03' | head -n 1
# aws s3 ls --recursive s3://b2c-prod-data-pipeline-unified-mobileweb-paid/unified/mobile-web.domain-retention.v1/  | grep '2020-01-03' | head -n 1
# aws s3 ls --recursive s3://b2c-prod-data-pipeline-unified-mobileweb-paid/unified/mobile-web.ranking.v1/  | grep '2020-01-03' | head -n 1
# aws s3 ls --recursive s3://b2c-prod-data-pipeline-unified-rating/unified/rating.v4/  | grep '2020-01-03' | head -n 1
# aws s3 ls --recursive s3://b2c-prod-data-pipeline-unified-sdk/unified/sdk.category-ranking.v1/  | grep '2020-01-03' | head -n 1
# aws s3 ls --recursive s3://b2c-prod-data-pipeline-unified-sdk/unified/sdk.history.v1/  | grep '2020-01-03' | head -n 1
# aws s3 ls --recursive s3://b2c-prod-data-pipeline-unified-sdk/unified/sdk.overall.v1/  | grep '2020-01-03' | head -n 1
# aws s3 ls --recursive s3://b2c-prod-data-pipeline-unified-store-free/unified/store.app.v1/  | grep '2020-01-03' | head -n 1
# aws s3 ls --recursive s3://b2c-prod-data-pipeline-unified-store-paid/unified/download-attribution.v1/  | grep '2020-01-03' | head -n 1
# aws s3 ls --recursive s3://b2c-prod-data-pipeline-unified-store-paid/unified/store.app-blackhorse-report-csv.v1/  | grep '2020-01-03' | head -n 1
# aws s3 ls --recursive s3://b2c-prod-data-pipeline-unified-store-paid/unified/store.app-blackhorse-report.v1/  | grep '2020-01-03' | head -n 1
# aws s3 ls --recursive s3://b2c-prod-data-pipeline-unified-store-paid/unified/store.app-blackhorse.v1/  | grep '2020-01-03' | head -n 1
# aws s3 ls --recursive s3://b2c-prod-data-pipeline-unified-store-paid/unified/store.app-est-category-rank.v1/  | grep '2020-01-03' | head -n 1
# aws s3 ls --recursive s3://b2c-prod-data-pipeline-unified-store-paid/unified/store.app-est-category-rank.v2/  | grep '2020-01-03' | head -n 1
# aws s3 ls --recursive s3://b2c-prod-data-pipeline-unified-store-paid/unified/store.app-est.v1/  | grep '2020-01-03' | head -n 1
# aws s3 ls --recursive s3://b2c-prod-data-pipeline-unified-store-paid/unified/store.app-est.v2/  | grep '2020-01-03' | head -n 1
# aws s3 ls --recursive s3://b2c-prod-data-pipeline-unified-tomcat/unified/tomcat.connect-advertising-app.v2/  | grep '2020-01-03' | head -n 1
# aws s3 ls --recursive s3://b2c-prod-data-pipeline-unified-tomcat/unified/tomcat.connect-analytics-app.v2/  | grep '2020-01-03' | head -n 1
# aws s3 ls --recursive s3://b2c-prod-data-pipeline-unified-tomcat/unified/tomcat.connect-publisher.v2/  | grep '2020-01-03' | head -n 1
# aws s3 ls --recursive s3://b2c-prod-data-pipeline-unified-tomcat/unified/tomcat.dna-relation.v2/  | grep '2020-01-03' | head -n 1
# aws s3 ls --recursive s3://b2c-prod-data-pipeline-unified-tomcat/unified/tomcat.publisher.v2/  | grep '2020-01-03' | head -n 1
# aws s3 ls --recursive s3://b2c-prod-data-pipeline-unified-tomcat/unified/tomcat.ss-app.v2/  | grep '2020-01-03' | head -n 1
# aws s3 ls --recursive s3://b2c-prod-data-pipeline-unified-tomcat/unified/tomcat.ss-publisher.v2/  | grep '2020-01-03' | head -n 1
# aws s3 ls --recursive s3://b2c-prod-data-pipeline-unified-tomcat/unified/tomcat.staging-publisher-auto-matched.v2/  | grep '2020-01-03' | head -n 1
# aws s3 ls --recursive s3://b2c-prod-data-pipeline-unified-tomcat/unified/tomcat.staging-publisher-dna-flagged.v2/  | grep '2020-01-03' | head -n 1
# aws s3 ls --recursive s3://b2c-prod-data-pipeline-unified-tomcat/unified/tomcat.thirdparty-company.v2/  | grep '2020-01-03' | head -n 1
# aws s3 ls --recursive s3://b2c-prod-data-pipeline-unified-usage/unified/city-level-usage.v1/  | grep '2020-01-03' | head -n 1
# aws s3 ls --recursive s3://b2c-prod-data-pipeline-unified-dna/unified/dna_migration.v1/  | grep '2020-01-03' | head -n 1
# aws s3 ls --recursive s3://b2c-prod-data-pipeline-unified-dna/unified/dna.dna_aa_category_app.v1/  | grep '2020-01-03' | head -n 1
# aws s3 ls --recursive s3://b2c-prod-data-pipeline-unified-dna/unified/dna.dna_app_mapping.v1/  | grep '2020-01-03' | head -n 1
# aws s3 ls --recursive s3://b2c-prod-data-pipeline-unified-dna/unified/dna.dna_category.v1/  | grep '2020-01-03' | head -n 1
# aws s3 ls --recursive s3://b2c-prod-data-pipeline-unified-dna/unified/dna.dna_company_app_automation_config.v1/  | grep '2020-01-03' | head -n 1
# aws s3 ls --recursive s3://b2c-prod-data-pipeline-unified-dna/unified/dna.dna_company_whois.v1/  | grep '2020-01-03' | head -n 1
# aws s3 ls --recursive s3://b2c-prod-data-pipeline-unified-dna/unified/dna.dna_config.v1/  | grep '2020-01-03' | head -n 1
# aws s3 ls --recursive s3://b2c-prod-data-pipeline-unified-dna/unified/dna.dna_deleted_universal_app_mapping.v1/  | grep '2020-01-03' | head -n 1
# aws s3 ls --recursive s3://b2c-prod-data-pipeline-unified-dna/unified/dna.dna_deleted_universal_company_mapping.v1/  | grep '2020-01-03' | head -n 1
# aws s3 ls --recursive s3://b2c-prod-data-pipeline-unified-dna/unified/dna.dna_deleted_universal_domain_mapping.v1/  | grep '2020-01-03' | head -n 1
# aws s3 ls --recursive s3://b2c-prod-data-pipeline-unified-dna/unified/dna.dna_excluded_terms.v1/  | grep '2020-01-03' | head -n 1
# aws s3 ls --recursive s3://b2c-prod-data-pipeline-unified-dna/unified/dna.dna_franchise_app_mapping.v1/  | grep '2020-01-03' | head -n 1
# aws s3 ls --recursive s3://b2c-prod-data-pipeline-unified-dna/unified/dna.dna_franchise.v1/  | grep '2020-01-03' | head -n 1
# aws s3 ls --recursive s3://b2c-prod-data-pipeline-unified-dna/unified/dna.dna_report_generator.v1/  | grep '2020-01-03' | head -n 1
# aws s3 ls --recursive s3://b2c-prod-data-pipeline-unified-dna/unified/dna.dna_sdk_operate_log.v1/  | grep '2020-01-03' | head -n 1
# aws s3 ls --recursive s3://b2c-prod-data-pipeline-unified-dna/unified/dna.dna_sdk_signature.v1/  | grep '2020-01-03' | head -n 1
# aws s3 ls --recursive s3://b2c-prod-data-pipeline-unified-dna/unified/dna.dna_sdk_type.v1/  | grep '2020-01-03' | head -n 1
# aws s3 ls --recursive s3://b2c-prod-data-pipeline-unified-dna/unified/dna.dna_sdk.v1/  | grep '2020-01-03' | head -n 1
# aws s3 ls --recursive s3://b2c-prod-data-pipeline-unified-dna/unified/dna.dna_top_performers_app.v1/  | grep '2020-01-03' | head -n 1
# aws s3 ls --recursive s3://b2c-prod-data-pipeline-unified-dna/unified/dna.dna_universal_app_mapping_copy.v1/  | grep '2020-01-03' | head -n 1
# aws s3 ls --recursive s3://b2c-prod-data-pipeline-unified-dna/unified/dna.dna_universal_app_stats.v1/  | grep '2020-01-03' | head -n 1
# aws s3 ls --recursive s3://b2c-prod-data-pipeline-unified-dna/unified/dna.dna_universal_app.v1/  | grep '2020-01-03' | head -n 1
# aws s3 ls --recursive s3://b2c-prod-data-pipeline-unified-dna/unified/dna.dna_universal_company_contact.v1/  | grep '2020-01-03' | head -n 1
# aws s3 ls --recursive s3://b2c-prod-data-pipeline-unified-dna/unified/dna.dna_universal_company_info.v1/  | grep '2020-01-03' | head -n 1
# aws s3 ls --recursive s3://b2c-prod-data-pipeline-unified-dna/unified/dna.dna_universal_company_mapping.v1/  | grep '2020-01-03' | head -n 1
# aws s3 ls --recursive s3://b2c-prod-data-pipeline-unified-dna/unified/dna.dna_universal_company_parent.v1/  | grep '2020-01-03' | head -n 1
# aws s3 ls --recursive s3://b2c-prod-data-pipeline-unified-dna/unified/dna.dna_universal_company_stats.v1/  | grep '2020-01-03' | head -n 1
# aws s3 ls --recursive s3://b2c-prod-data-pipeline-unified-dna/unified/dna.dna_universal_company_summary.v1/  | grep '2020-01-03' | head -n 1
# aws s3 ls --recursive s3://b2c-prod-data-pipeline-unified-dna/unified/dna.dna_universal_domain_mapping.v1/  | grep '2020-01-03' | head -n 1
# aws s3 ls --recursive s3://b2c-prod-data-pipeline-unified-dna/unified/dna.in_city_country_mapping.v1/  | grep '2020-01-03' | head -n 1
# aws s3 ls --recursive s3://b2c-prod-data-pipeline-unified-dna/unified/dna.in_company_product_mapping.v1/  | grep '2020-01-03' | head -n 1
# aws s3 ls --recursive s3://b2c-prod-data-pipeline-unified-dna/unified/dna.in_company_publisher_mapping.v1/  | grep '2020-01-03' | head -n 1
# aws s3 ls --recursive s3://b2c-prod-data-pipeline-unified-dna/unified/dna.in_company_sdk_mapping.v1/  | grep '2020-01-03' | head -n 1
# aws s3 ls --recursive s3://b2c-prod-data-pipeline-unified-dna/unified/dna.in_company_unified_product_mapping.v1/  | grep '2020-01-03' | head -n 1
# aws s3 ls --recursive s3://b2c-prod-data-pipeline-unified-dna/unified/dna.in_direct_company_unified_product_mapping.v1/  | grep '2020-01-03' | head -n 1
# aws s3 ls --recursive s3://b2c-prod-data-pipeline-unified-dna/unified/dna.in_domain_category_mapping.v1/  | grep '2020-01-03' | head -n 1
# aws s3 ls --recursive s3://b2c-prod-data-pipeline-unified-dna/unified/dna.in_parent_company_company_mapping.v1/  | grep '2020-01-03' | head -n 1
# aws s3 ls --recursive s3://b2c-prod-data-pipeline-unified-dna/unified/dna.in_parent_company_product_mapping.v1/  | grep '2020-01-03' | head -n 1
# aws s3 ls --recursive s3://b2c-prod-data-pipeline-unified-dna/unified/dna.in_parent_company_publisher_mapping.v1/  | grep '2020-01-03' | head -n 1
# aws s3 ls --recursive s3://b2c-prod-data-pipeline-unified-dna/unified/dna.in_parent_company_unified_product_mapping.v1/  | grep '2020-01-03' | head -n 1
# aws s3 ls --recursive s3://b2c-prod-data-pipeline-unified-dna/unified/dna.in_sdk_product_mapping.v1/  | grep '2020-01-03' | head -n 1
# aws s3 ls --recursive s3://b2c-prod-data-pipeline-unified-dna/unified/dna.in_unified_product_domain_mapping.v1/  | grep '2020-01-03' | head -n 1
# aws s3 ls --recursive s3://b2c-prod-data-pipeline-unified-dna/unified/dna.in_unified_product_product_mapping.v1/  | grep '2020-01-03' | head -n 1
# aws s3 ls --recursive s3://b2c-prod-data-pipeline-unified-dna/unified/dna.productized_index_config.v1/  | grep '2020-01-03' | head -n 1
# aws s3 ls --recursive s3://b2c-prod-data-pipeline-unified-dna/unified/dna.productized_index_universal_app_to_drop.v1/  | grep '2020-01-03' | head -n 1
# aws s3 ls --recursive s3://b2c-prod-data-pipeline-unified-dna/unified/dna.productized_index_universal_app.v1/  | grep '2020-01-03' | head -n 1
# aws s3 ls --recursive s3://b2c-prod-data-pipeline-unified-dna/unified/dna.productized_index_universal_company.v1/  | grep '2020-01-03' | head -n 1
# aws s3 ls --recursive s3://b2c-prod-data-pipeline-unified-dna/unified/dna.publisher_match_result.v1/  | grep '2020-01-03' | head -n 1
# aws s3 ls --recursive s3://b2c-prod-data-pipeline-unified-dna/unified/dna.publisher_match_run_info.v1/  | grep '2020-01-03' | head -n 1
# aws s3 ls --recursive s3://b2c-prod-data-pipeline-unified-featured/unified/featured.apps.v4/  | grep '2020-01-03' | head -n 1
# aws s3 ls --recursive s3://b2c-prod-data-pipeline-unified-featured/unified/featured.categories.v4/  | grep '2020-01-03' | head -n 1
# aws s3 ls --recursive s3://b2c-prod-data-pipeline-unified-featured/unified/featured.games.v4/  | grep '2020-01-03' | head -n 1
# aws s3 ls --recursive s3://b2c-prod-data-pipeline-unified-featured/unified/featured.iap.v4/  | grep '2020-01-03' | head -n 1
# aws s3 ls --recursive s3://b2c-prod-data-pipeline-unified-featured/unified/featured.today.v4/  | grep '2020-01-03' | head -n 1
# aws s3 ls --recursive s3://b2c-prod-data-pipeline-unified-market/unified/market.legacy-creative_category.v1/  | grep '2020-01-03' | head -n 1
# aws s3 ls --recursive s3://b2c-prod-data-pipeline-unified-market/unified/market.legacy-creative_ad_estimate.v1/  | grep '2020-01-03' | head -n 1
# aws s3 ls --recursive s3://b2c-prod-data-pipeline-unified-market/unified/market.legacy-campaign_id_map.v1/  | grep '2020-01-03' | head -n 1
# aws s3 ls --recursive s3://b2c-prod-data-pipeline-unified-market/unified/market.legacy-adpo_estimate.v1/  | grep '2020-01-03' | head -n 1
# aws s3 ls --recursive s3://b2c-prod-data-pipeline-unified-market/unified/market.legacy-adpo_detail_estimate.v1/  | grep '2020-01-03' | head -n 1
# aws s3 ls --recursive s3://b2c-prod-data-pipeline-unified-market/unified/market.legacy-ad_app_pub_estimate.v1/  | grep '2020-01-03' | head -n 1
# aws s3 ls --recursive s3://b2c-prod-data-pipeline-unified-market/unified/market.legacy-ad_app_pub_app_estimate.v1/  | grep '2020-01-03' | head -n 1
# aws s3 ls --recursive s3://b2c-prod-data-pipeline-unified-market/unified/market.legacy-ad_app_estimate.v1/  | grep '2020-01-03' | head -n 1
# aws s3 ls --recursive s3://b2c-prod-data-pipeline-unified-market/unified/market.legacy-ad_app_detail_estimate.v1/  | grep '2020-01-03' | head -n 1
# aws s3 ls --recursive s3://b2c-prod-data-pipeline-unified-market/unified/market.legacy-ad_app_category.v1/  | grep '2020-01-03' | head -n 1
# aws s3 ls --recursive s3://b2c-prod-data-pipeline-unified-market/unified/market.creative-meta.v1/  | grep '2020-01-03' | head -n 1
# aws s3 ls --recursive s3://b2c-prod-data-pipeline-unified-market/unified/market.creative-log.v1/  | grep '2020-01-03' | head -n 1
# aws s3 ls --recursive s3://b2c-prod-data-pipeline-unified-market/unified/market.creative-id-mapping.v1/  | grep '2020-01-03' | head -n 1
# aws s3 ls --recursive s3://b2c-prod-data-pipeline-unified-market/unified/market.creative-fact.v1/  | grep '2020-01-03' | head -n 1
# aws s3 ls --recursive s3://b2c-prod-data-pipeline-unified-market/unified/market.creative-category-rank.v1/  | grep '2020-01-03' | head -n 1
# aws s3 ls --recursive s3://b2c-prod-data-pipeline-unified-market/unified/market.creative-adapp-visibility.v1/  | grep '2020-01-03' | head -n 1
# aws s3 ls --recursive s3://b2c-prod-data-pipeline-unified-market/unified/market.campaign-id-mapping.v1/  | grep '2020-01-03' | head -n 1
# aws s3 ls --recursive s3://b2c-prod-data-pipeline-unified-market/unified/market.adapp-publisher-fact.v1/  | grep '2020-01-03' | head -n 1
# aws s3 ls --recursive s3://b2c-prod-data-pipeline-unified-market/unified/market.adapp-pubapp-visibility.v1/  | grep '2020-01-03' | head -n 1
# aws s3 ls --recursive s3://b2c-prod-data-pipeline-unified-market/unified/market.adapp-pubapp-fact.v1/  | grep '2020-01-03' | head -n 1
# aws s3 ls --recursive s3://b2c-prod-data-pipeline-unified-market/unified/market.adapp-fact.v1/  | grep '2020-01-03' | head -n 1
# aws s3 ls --recursive s3://b2c-prod-data-pipeline-unified-market/unified/market.ad-platform-impression.v1/  | grep '2020-01-03' | head -n 1
# aws s3 ls --recursive s3://b2c-prod-data-pipeline-unified-market/unified/market.ad-app-impression.v1/  | grep '2020-01-03' | head -n 1
# aws s3 ls --recursive s3://b2c-prod-data-pipeline-unified-market/unified/market.ad-app-category-rank.v1/  | grep '2020-01-03' | head -n 1
# aws s3 ls --recursive s3://b2c-prod-data-pipeline-unified-aso/unified/aso.search-visibility.v1/  | grep '2020-01-03' | head -n 1
# aws s3 ls --recursive s3://b2c-prod-data-pipeline-unified-aso/unified/aso.keyword-trafficshare.v1/  | grep '2020-01-03' | head -n 1
# aws s3 ls --recursive s3://b2c-prod-data-pipeline-unified-aso/unified/aso.keyword-difficulty-search-volume.v1/  | grep '2020-01-03' | head -n 1
# aws s3 ls --recursive s3://b2c-prod-data-pipeline-unified-mobileweb-free/unified/mobileweb.domain.v1/  | grep '2020-01-03' | head -n 1
# aws s3 ls --recursive s3://b2c-prod-data-pipeline-unified-rating/unified/rating.filldata.v1/  | grep '2020-01-03' | head -n 1
# aws s3 ls --recursive s3://b2c-prod-data-pipeline-unified-rating/unified/rating.filldata.v2/  | grep '2020-01-03' | head -n 1
# aws s3 ls --recursive s3://b2c-prod-data-pipeline-unified-rating/unified/rating.fixed.v2/  | grep '2020-01-03' | head -n 1
# aws s3 ls --recursive s3://b2c-prod-data-pipeline-unified-rating/unified/rating.fixed.v3/  | grep '2020-01-03' | head -n 1
# aws s3 ls --recursive s3://b2c-prod-data-pipeline-unified-rating/unified/rating.historical.v1/  | grep '2020-01-03' | head -n 1
# aws s3 ls --recursive s3://b2c-prod-data-pipeline-unified-rating/unified/rating.historical.v2/  | grep '2020-01-03' | head -n 1

# %%
# %%sh
#
# aws s3api list-objects --bucket 'b2c-prod-data-pipeline-unified-market' --prefix 'unified/market.pubapp-fact.v1' --query  'Contents[?LastModified>=`2020-01-03`][Key]' | grep '2020' | head -n 1

# %%
# %%sh
#
# aws s3api list-objects --bucket 'b2c-prod-data-pipeline-unified-mobileweb-free' --prefix 'unified/mobileweb.domain.v2' --query  'Contents[?LastModified>=`2019-12-31`][].{Key:Key}' | grep 'Key' >> /tmp/tom-log.txt && echo 'pass' || echo 'fail'
# aws s3api list-objects --bucket 'b2c-prod-data-pipeline-unified-store-paid' --prefix 'unified/download-attribution.v1' --query  'Contents[?LastModified>=`2019-12-31`][].{Key:Key}' | grep 'Key' >> /tmp/tom-log.txt && echo 'pass' || echo 'fail'
# aws s3api list-objects --bucket 'b2c-prod-data-pipeline-unified-store-paid' --prefix 'unified/store.app-blackhorse-report-csv.v1' --query  'Contents[?LastModified>=`2019-12-31`][].{Key:Key}' | grep 'Key' >> /tmp/tom-log.txt && echo 'pass' || echo 'fail'
# aws s3api list-objects --bucket 'b2c-prod-data-pipeline-unified-store-paid' --prefix 'unified/store.app-blackhorse-report.v1' --query  'Contents[?LastModified>=`2019-12-31`][].{Key:Key}' | grep 'Key' >> /tmp/tom-log.txt && echo 'pass' || echo 'fail'
# aws s3api list-objects --bucket 'b2c-prod-data-pipeline-unified-store-paid' --prefix 'unified/store.app-blackhorse.v1' --query  'Contents[?LastModified>=`2019-12-31`][].{Key:Key}' | grep 'Key' >> /tmp/tom-log.txt && echo 'pass' || echo 'fail'
# aws s3api list-objects --bucket 'b2c-prod-data-pipeline-unified-store-paid' --prefix 'unified/store.app-est-category-rank.v1' --query  'Contents[?LastModified>=`2019-12-31`][].{Key:Key}' | grep 'Key' >> /tmp/tom-log.txt && echo 'pass' || echo 'fail'
# aws s3api list-objects --bucket 'b2c-prod-data-pipeline-unified-store-paid' --prefix 'unified/store.app-est-category-rank.v2' --query  'Contents[?LastModified>=`2019-12-31`][].{Key:Key}' | grep 'Key' >> /tmp/tom-log.txt && echo 'pass' || echo 'fail'
# aws s3api list-objects --bucket 'b2c-prod-data-pipeline-unified-store-paid' --prefix 'unified/store.app-est.v1' --query  'Contents[?LastModified>=`2019-12-31`][].{Key:Key}' | grep 'Key' >> /tmp/tom-log.txt && echo 'pass' || echo 'fail'
# aws s3api list-objects --bucket 'b2c-prod-data-pipeline-unified-store-paid' --prefix 'unified/store.app-est.v2' --query  'Contents[?LastModified>=`2019-12-31`][].{Key:Key}' | grep 'Key' >> /tmp/tom-log.txt && echo 'pass' || echo 'fail'

# %%
# %%sh
#
# # aws s3 ls s3://b2c-prod-data-pipeline-unified-store-paid/unified/download-attribution.v1/fact/month=2019-12/
# # aws s3 ls s3://b2c-prod-data-pipeline-unified-store-paid/unified/store.app-blackhorse-report-csv.v1/fact/date=2019-12-28/
# aws s3 ls s3://b2c-prod-data-pipeline-unified-tomcat/unified/tomcat.connect-advertising-app.v2/dimension/date=2020-01-01/

# %%
# %%sh
#
#
# # aws s3 ls s3://b2c-prod-data-pipeline-unified-mobileweb-free/unified/mobileweb.domain.v2
# aws s3 ls s3://b2c-prod-data-pipeline-unified-store-paid/unified/download-attribution.v1
# aws s3 ls s3://b2c-prod-data-pipeline-unified-store-paid/unified/store.app-blackhorse-report-csv.v1
# aws s3 ls s3://b2c-prod-data-pipeline-unified-store-paid/unified/store.app-blackhorse-report.v1
# aws s3 ls s3://b2c-prod-data-pipeline-unified-store-paid/unified/store.app-blackhorse.v1
# aws s3 ls s3://b2c-prod-data-pipeline-unified-store-paid/unified/store.app-est-category-rank.v1
# aws s3 ls s3://b2c-prod-data-pipeline-unified-store-paid/unified/store.app-est-category-rank.v2
# aws s3 ls s3://b2c-prod-data-pipeline-unified-store-paid/unified/store.app-est.v1
# aws s3 ls s3://b2c-prod-data-pipeline-unified-store-paid/unified/store.app-est.v2
# aws s3 ls s3://b2c-prod-data-pipeline-unified-tomcat/unified/tomcat.connect-advertising-app.v2
# aws s3 ls s3://b2c-prod-data-pipeline-unified-tomcat/unified/tomcat.connect-analytics-app.v2
# aws s3 ls s3://b2c-prod-data-pipeline-unified-tomcat/unified/tomcat.connect-publisher.v2
# aws s3 ls s3://b2c-prod-data-pipeline-unified-tomcat/unified/tomcat.dna-relation.v2
# aws s3 ls s3://b2c-prod-data-pipeline-unified-tomcat/unified/tomcat.publisher.v2
# aws s3 ls s3://b2c-prod-data-pipeline-unified-tomcat/unified/tomcat.ss-app.v2
# aws s3 ls s3://b2c-prod-data-pipeline-unified-tomcat/unified/tomcat.ss-publisher.v2
# aws s3 ls s3://b2c-prod-data-pipeline-unified-tomcat/unified/tomcat.staging-publisher-auto-matched.v2
# aws s3 ls s3://b2c-prod-data-pipeline-unified-tomcat/unified/tomcat.staging-publisher-dna-flagged.v2
# aws s3 ls s3://b2c-prod-data-pipeline-unified-tomcat/unified/tomcat.thirdparty-company.v2

# %%
# %%sh
#
# # aws s3 ls s3://b2c-prod-data-pipeline-unified-store-paid/unified/store.app-est-category-rank.v1
# # aws s3 ls s3://b2c-prod-data-pipeline-unified-store-paid/unified/store.app-est-category-rank.v2
# # aws s3 ls s3://b2c-prod-data-pipeline-unified-store-paid/unified/store.app-est.v1
# aws s3 ls s3://b2c-prod-data-pipeline-unified-store-paid/unified/store.app-est.v2/fact/granularity=daily/date=2019-12-28/device_code=android-all/
# date

# %%
# %%sh
