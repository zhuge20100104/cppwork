# %%
# %%sh
# aws s3 ls s3://aardvark-prod-pdx-mdm-to-int/usage_retention/

# %%
baisc_path = "s3://aardvark-prod-pdx-mdm-to-int/basic_kpi/version=1.0.0/range_type=DAY/date=2018-01-04/platform=1/"
city_path = "s3://aardvark-prod-pdx-mdm-to-int/city_level/report/routine/version=1.0.0/granularity=monthly/date=2018-01-31/country_code=US/"
app_retention_path = "s3://aardvark-prod-pdx-mdm-to-int/usage_retention/batch=retention_batch_D7_routine/version=v3.0.0/range_type=MONTH/date=2019-09-30/"
domain_retention_path = "s3://b2c-prod-dca-mobile-web-to-int/oss/MOBILE_WEB_DOMAIN_RETENTION_METRICS/version=v1.0.0/granularity=MONTH/date=2019-01-31/"
cross_genre_path = "s3://aardvark-prod-dca-data/oss/GAME_CROSS_GENRE_KPI_PARQUET/version=1.0.6/range_type=MONTH/date=2019-01-31/platform=1/"
domain_browser_path = "s3://b2c-prod-dca-mobile-web-to-int/oss/MOBILE_WEB_DOMAIN_BROWSER_METRICS/version=v1.0.0/granularity=MONTH/date=2019-01-31/platform=1/"
cross_genre_unified_path = "s3://b2c-prod-data-pipeline-unified-usage/unified/usage.genre-cross.v1/fact/granularity=monthly/date=2020-06-30/"

# df1 = spark.read.option("basePath", "s3://b2c-prod-data-pipeline-unified-usage/unified/usage.genre-cross.v1/fact").parquet(retention_path).createOrReplaceTempView("test")
df1 = spark.read.parquet(domain_retention_path).createOrReplaceTempView("test")
spark.sql("SELECT * FROM test order by value asc limit 10").show()

# %%
df1 = spark.read.parquet(city_path).createOrReplaceTempview("test")
 spark.sql("select * from test where metric_name=TV").show(10)
