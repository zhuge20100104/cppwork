# %%
spark.read.parquet("s3://aardvark-prod-pdx-mdm-to-int/usage_retention/batch=retention_batch_D14/version=v3.0.0/range_type=MONTH/date=2019-11-30/metric_name=RRD14/platform=1/part-00000-2c545a13-23bf-4620-874f-277a7ebc6624.c000.snappy.parquet").show(10)
