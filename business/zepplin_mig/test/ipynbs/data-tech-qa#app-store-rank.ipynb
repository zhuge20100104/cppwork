# %%
import psycopg2
import datetime

citus_dsn_ = (
    "dbname='{db}' user='{user}' password='{password}' "
    "host='{host}' port='{port}'".format(
        db="aa_citus_db",
        user="citus_bdp_usage_qa",
        host="10.2.10.132",
        password="dNzWtSV3pKTx",
        port=5432
    )
)

# %%
# %md
# -------------BELLOW IS DB DATA-------------

# %%
import psycopg2
import datetime

today = datetime.datetime.today()
date_delta = z.input("max_days")
date_start = today + datetime.timedelta(0-int(date_delta)-1)


sql = 'SELECT date, device_code,count(app_id)  FROM store.store_app_rank_fact_v1  WHERE ( date between \'{date_start}\' AND \'{today}\'  ) AND ( granularity = \'hourly\' ) AND ( hour = 23 ) GROUP BY date, device_code ORDER BY date ASC'.format(date_start=date_start, today=today)

def query(dsn, sql):
    with psycopg2.connect(dsn) as conn:
        conn.autocommit = True
        with conn.cursor() as cur:
            cur.execute(sql)
            result = cur.fetchall()
            conn.commit()
    return result
    
test_result = query(citus_dsn_, sql)
print "%table {}\t{}\t{}".format( "date", "device_code", "count")

for result in test_result:
    date,device_code,count = result
    print "{}\t{}\t{}".format(date.strftime("%Y-%m-%d"), device_code, count)

# %%
# %%sh
#
# echo -e "%table date \t count \t country_code \t device_code"
#
# d=$(date +'%Y-%m-%d')
#
# for date_delta in {${max_days}..1}; do
#   date=$(date -I -d "$d - $date_delta day")
#   aws s3 ls s3://prod_appannie_android/country-ranks/$date/23/ | grep -v md5 | grep -v SUCCESS | awk '{ print "'$date'","\t",$3,"\t",$4,"\t","gp" }';
#   aws s3 ls s3://prod_appannie_ios/country-ranks/$date/23/ | grep -v md5 | grep -v SUCCESS | awk '{ print "'$date'","\t",$3,"\t", $4,"\t","ios" }';
#   aws s3 ls s3://prod_appannie_ios/mac/country-ranks/$date/23/ | grep -v md5 | grep -v SUCCESS | awk '{ print "'$date'","\t",$3,"\t", $4,"\t","mac" }';
#   aws s3 ls s3://prod_appannie_appletv/country-ranks/$date/23/ | grep -v md5 | grep -v SUCCESS | awk '{ print "'$date'","\t",$3,"\t", $4,"\t","tv" }';
#   aws s3 ls s3://prod_appannie_amazon/country-ranks/$date/23/ | grep -v md5 | grep -v SUCCESS | awk '{ print "'$date'","\t",$3,"\t", $4,"\t","amazon" }';
#
# done

# %%
# %%sh
#
# echo -e "%table date \t count \t device_code"
#
# d=$(date +'%Y-%m-%d')
#
# for date_delta in {${max_days}..1}; do
#   date=$(date -I -d "$d - $date_delta day")
#   aws s3 ls --recursive --summarize  s3://prod_appannie_android/country-ranks/$date/ | grep "Total Size:" |  awk '{ print "'$date'","\t",$3,"\t","gp" }'  || true
#   aws s3 ls --recursive --summarize  s3://prod_appannie_ios/country-ranks/$date/ | grep "Total Size:" |  awk '{ print "'$date'","\t",$3,"\t","ios" }'  || true
#   aws s3 ls --recursive --summarize  s3://prod_appannie_ios/mac/country-ranks/$date/ | grep "Total Size:" |  awk '{ print "'$date'","\t",$3,"\t","mac" }'  || true
#   aws s3 ls --recursive --summarize   s3://prod_appannie_appletv/country-ranks/$date/ | grep "Total Size:" |  awk '{ print "'$date'","\t",$3,"\t","tv" }'  || true
#   aws s3 ls --recursive --summarize  s3://prod_appannie_amazon/country-ranks/$date/ | grep "Total Size:" |  awk '{ print "'$date'","\t",$3,"\t","amz" }' || true
#
# done

# %%
# %%sh
# aws s3 ls --summarize --recursive s3://prod_appannie_android/country-ranks/2020-02-01/ | grep "Total Size:" |  awk '{ print "'$date'","\t",$3,"\t","gp" }';

# %%
import psycopg2
import datetime

today = datetime.datetime.today()
date_delta = z.input("max_days")
date_start = today + datetime.timedelta(0-int(date_delta)-1)


sql = 'SELECT date, country_code,count(app_id)  FROM store.store_app_rank_fact_v1  WHERE ( date between \'{date_start}\' AND \'{today}\'  ) AND ( granularity = \'hourly\' ) AND ( device_code = \'android-all\' ) AND ( hour = 23 ) GROUP BY date, country_code ORDER BY date ASC'.format(date_start=date_start, today=today)

def query(dsn, sql):
    with psycopg2.connect(dsn) as conn:
        conn.autocommit = True
        with conn.cursor() as cur:
            cur.execute(sql)
            result = cur.fetchall()
            conn.commit()
    return result
    
test_result = query(citus_dsn_, sql)
print( "%table {}\t{}\t{}".format( "date", "country_code", "count"))

for result in test_result:
    date,country_code,count = result
    print("{}\t{}\t{}".format(date.strftime("%Y-%m-%d"), country_code, count))

# %%
import psycopg2
import datetime

today = datetime.datetime.today()
date_delta = z.input("max_days")
date_start = today + datetime.timedelta(0-int(date_delta)-1)


sql = 'SELECT date, country_code,count(app_id)  FROM store.store_app_rank_fact_v1  WHERE ( date between \'{date_start}\' AND \'{today}\'  ) AND ( granularity = \'hourly\' ) AND ( device_code != \'android-all\' ) AND ( hour = 23 ) GROUP BY date, country_code ORDER BY date ASC'.format(date_start=date_start, today=today)

def query(dsn, sql):
    with psycopg2.connect(dsn) as conn:
        conn.autocommit = True
        with conn.cursor() as cur:
            cur.execute(sql)
            result = cur.fetchall()
            conn.commit()
    return result
    
test_result = query(citus_dsn_, sql)
print "%table {}\t{}\t{}".format( "date", "country_code", "count")

for result in test_result:
    date,country_code,count = result
    print "{}\t{}\t{}".format(date.strftime("%Y-%m-%d"), country_code, count)

# %%
# %md
# -------------BELLOW IS RAW DATA-------------

# %%
# %%sh
#
# echo -e "%table date \t count \t country"
#
# d=$(date +'%Y-%m-%d')
#
# for date_delta in {${max_days}..1}; do
#   date=$(date -I -d "$d - $date_delta day")
#   aws s3 ls s3://prod_appannie_android/country-ranks/$date/23/ | grep -v md5 | grep -v SUCCESS | awk '{ print "'$date'","\t",$3,"\t", $4 }';
# done

# %%
# %%sh
#
# echo -e "%table date \t count \t country"
#
# d=$(date +'%Y-%m-%d')
#
# for date_delta in {${max_days}..1}; do
#   date=$(date -I -d "$d - $date_delta day")
#   aws s3 ls s3://prod_appannie_ios/country-ranks/$date/23/ | grep -v md5 | grep -v SUCCESS | awk '{ print "'$date'","\t",$3,"\t", $4 }';
# done

# %%
# %%sh

# %%
import psycopg2
import datetime

date_start = z.input("date_start")
date_end = z.input("date_end")
date_delta = (datetime.datetime.strptime(date_end, '%Y-%m-%d')-datetime.datetime.strptime(date_start, '%Y-%m-%d')).days

MAX=30
if date_delta > MAX:
    raise RuntimeError("date delta should < {}".format(30))

sql = 'SELECT date, device_code,count(app_id)  FROM store.store_app_rank_fact_v1 WHERE ( date between \'{date_start}\' AND \'{date_end}\'  ) AND ( granularity = \'hourly\' ) AND ( hour = 23 ) GROUP BY date, device_code ORDER BY date ASC'.format(date_start=date_start, date_end=date_end)

def query(dsn, sql):
    with psycopg2.connect(dsn) as conn:
        conn.autocommit = True
        with conn.cursor() as cur:
            cur.execute(sql)
            result = cur.fetchall()
            conn.commit()
    return result
    
test_result = query(citus_dsn_, sql)
print "%table {}\t{}\t{}".format( "date", "device_code", "count")

for result in test_result:
    date,device_code,count = result
    print "{}\t{}\t{}".format(date.strftime("%Y-%m-%d"), device_code, count)

# %%
# %%sh
#
# echo -e "%table date \t count \t country_code \t device_code"
#
# date=${date_start}
# date_end=$(date -I -d "${date_end} + 1 day")
#
# while [ "$date" != $date_end ]; do
#   aws s3 ls s3://prod_appannie_android/country-ranks/$date/23/ | grep -v md5 | grep -v SUCCESS | awk '{ print "'$date'","\t",$3,"\t",$4,"\t","android" }';
#   aws s3 ls s3://prod_appannie_ios/country-ranks/$date/23/ | grep -v md5 | grep -v SUCCESS | awk '{ print "'$date'","\t",$3,"\t", $4,"\t","ios" }';
#   date=$(date -I -d "$date + 1 day")
# done

# %%
# %%sh
#
#
# aws s3 ls --recursive s3://prod_appannie_amazon/country-ranks/2021-03-01/ | grep -v md5 | grep -v SUCCESS

# %%
# %%sh
# # aws s3 ls s3://b2c-prod-data-pipeline-unified-store-free/unified/app-tech.store.app-rank.v2/fact/date=2019-10-04/device_code=mac-os-mac/
# # aws s3 ls s3://b2c-prod-data-pipeline-unified-store-free/unified/app-tech.store.app-rank.v2/fact/date=2019-10-04/device_code=android-all/
# # aws s3 ls s3://b2c-prod-data-pipeline-unified-store-free/unified/app-tech.store.app-rank.v2/fact/date=2019-10-04/device_code=ios-phone/
# # aws s3 ls s3://b2c-prod-data-pipeline-unified-store-free/unified/app-tech.store.app-rank.v2/fact/date=2019-10-04/device_code=ios-tablet/
# # aws s3 ls s3://b2c-prod-data-pipeline-unified-store-free/unified/app-tech.store.app-rank.v2/fact/date=2019-10-04/device_code=tv-os-tv/
#
# export CHECK_DATE=2019-11-19
# aws s3 ls s3://b2c-prod-data-pipeline-unified-store-free/unified/app-tech.store.app-rank.v1/fact/date=$CHECK_DATE/device_code=mac-os-mac/
# aws s3 ls s3://b2c-prod-data-pipeline-unified-store-free/unified/app-tech.store.app-rank.v1/fact/date=$CHECK_DATE/device_code=android-all/
# aws s3 ls s3://b2c-prod-data-pipeline-unified-store-free/unified/app-tech.store.app-rank.v1/fact/date=$CHECK_DATE/device_code=ios-phone/ || true
# aws s3 ls s3://b2c-prod-data-pipeline-unified-store-free/unified/app-tech.store.app-rank.v1/fact/date=$CHECK_DATE/device_code=ios-tablet/ || true
# aws s3 ls s3://prod_appannie_android/country-ranks/$CHECK_DATE/23/US | grep -v 'md5'
# aws s3 ls s3://prod_appannie_ios/country-ranks/$CHECK_DATE/23/143441 | grep -v 'md5'
# aws s3 ls s3://prod_appannie_ios/mac/country-ranks/$CHECK_DATE/23/143441 | grep -v 'md5'
# aws s3 ls s3://prod_appannie_appletv/country-ranks/$CHECK_DATE/23/US | grep -v 'md5'

# %%
import psycopg2
import datetime
import pandas as pd

citus_dsn_ = (
    "dbname='{db}' user='{user}' password='{password}' "
    "host='{host}' port='{port}'".format(
        db="aa_citus_db",
        user="citus_bdp_usage_qa",
        host="10.2.10.132",
        password="dNzWtSV3pKTx",
        port=5432
    )
)

def query(dsn, sql):
    with psycopg2.connect(dsn) as conn:
        conn.autocommit = True
        with conn.cursor() as cur:
            cur.execute(sql)
            result = cur.fetchall()
            conn.commit()
    return result

def get_date_list(begin_date, end_date, freq):
    date_list = [x.strftime('%Y-%m-%d') for x in list(pd.date_range(start=begin_date, end=end_date, freq=freq))]
    return date_list

begin_date = datetime.datetime.strptime("2012-12-26", '%Y-%m-%d')
end_date = datetime.datetime.strptime("2019-12-04", '%Y-%m-%d')
DATE_LIST = get_date_list(begin_date, end_date, "D")



metrics = ["free_download", "new_paid_download", "revenue", "paid_download", "new_free_download"]
device_list = ["ios-phone","ios-tablet","android-all","tv-os-tv","mac-os-mac"]
print "%table {}\t{}\t{}".format("date","device","count")

for date_str in DATE_LIST:
    date_count = {"ios-phone":0,"ios-tablet":0,"android-all":0,"tv-os-tv":0,"mac-os-mac":0 }
    
    for metric in metrics:
        sql = 'SELECT date, device_code, country_code, category_id, count({metric}),max({metric}) FROM store.store_app_rank_fact_v1  WHERE date = \'{date_str}\' AND ( granularity = \'hourly\' ) AND ( hour = 23 ) AND ({metric} is not null)  GROUP BY country_code, date, device_code, country_code, category_id ORDER BY date ASC'.format(
            metric=metric, date_str=date_str)

        test_result = query(citus_dsn_, sql)
        for result in test_result:
            date, device_code, country_code, category_id, count, max = result
            if count != 0 and count != max:
                date_count[device_code] += 1
                # print ",".join([date.strftime("%Y-%m-%d"), device_code, country_code, str(category_id), metric, str(count),str(max)])
    for key in device_list:
        print "\t".join([date_str, key, str(date_count[key])])

print "end"

# %%
# %%sh
#
# # aws s3 ls s3://b2c-prod-data-pipeline-unified-store-free/unified/app-tech.store.app-rank.v1/fact/date=2019-12-26/
#
# # aws s3 ls s3://b2c-prod-data-pipeline-unified-store-free/unified/app-tech.store.app-rank.v2/fact/date=2014-02-09/
#
# aws s3 ls s3://prod_appannie_android/country-ranks/2013-02-28/23/

# %%
# %%sh
#
#
# PGPASSWORD='dNzWtSV3pKTx' psql -h 10.2.10.132 -U citus_bdp_usage_qa -d aa_citus_db -p 5432 << EOF
# --SELECT * from store.store_app_rank_fact_v1 where date ='2020-03-20' AND category_id=200000 AND country_code='US' AND device_code='mac-os-mac' limit  1000;
# --SELECT count(free_download) as count_free, count(paid_download) as count_paid from store.store_app_rank_fact_v1 where date ='2020-03-20' AND device_code='mac-os-mac';
# --SELECT count(free_download) as count_free, count(paid_download) as count_paid, count(revenue) as count_grossing, date from store.store_app_rank_fact_v1 where date between '2020-03-01' AND '2020-03-20' AND device_code='mac-os-mac' group by date order by date DESC;
#
# --SELECT date,count(app_id) from store.store_app_rank_fact_v1 where date >'2020-06-01' AND device_code='android-all' AND category_id between 700000 and 790000 group by date order by date desc;
#
# SELECT * from store.store_app_rank_fact_v1 where date='2020-07-12' and app_id=1273366668 and country_code='IN'and device_code='ios-phone' limit 5;
# EOF

# %%
spark.sparkContext.addPyFile("/home/hadoop/bdp/application/libs/python/dependencies.zip")
spark.sparkContext.addPyFile("/home/hadoop/bdp/application/code.zip")
import pandas as pd
pd.set_option('expand_frame_repr', False)

# %%
import sys
import datetime
import traceback
import unittest
from applications.db_check_v1.common.html_report_test_runner import HTMLTestRunner
from applications.db_check_v1.cases.store.app_rank_v1.test_app_rank_v1 import TestAppStoreRankDaily


def debug(case_list):
    std_out_origin= sys.stdout
    std_err_origin= sys.stderr
    try:
        suite =  unittest.TestSuite()
        for case in case_list:
            suite.addTest(case)
        runner = unittest.TextTestRunner(verbosity=2, buffer=True)
        runner.run(suite)
    except Exception as ex:
        print dir(ex)
        print ex.message
        traceback.print_exception(type(ex), ex, ex.__traceback__)
    finally:
        sys.stdout = std_out_origin
        sys.stderr = std_err_origin

test_case_list = [ ] # pass 

date_list = [datetime.datetime(2020, 6, 8)]

print date_list
for t_date in date_list:
    test_case_list.append(TestAppStoreRankDaily(trigger_datetime=t_date, methodName='test_app_store_rank_amazon_etl_completeness'))


debug(test_case_list)
