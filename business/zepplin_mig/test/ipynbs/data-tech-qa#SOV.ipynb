# %%
# %%sh
#
# echo 'This is for Data in ES'

# %%
from datetime import datetime
import datetime
from elasticsearch import Elasticsearch
import json
from aaintdatapipeline.application.app_qa.data_validation_v1.pysparktest import PySparkTest
import unittest
import random
from aaintdatapipeline.application.app_qa.data_validation_v1.utils import (get_aso_keyword_sov_raw_df_root,
                                                                           get_aso_keyword_sov_unified_df_root,
                                                                            )
from aaintdatapipeline.core.loader import es
from aaintdatapipeline.core.urn import Urn
from pyspark.sql.types import *

def get_es_search_data( query, country_code):
    res = es.search(index="aso-kpi-sov_search_ads_keyword_fact_v1_daily_{}*".format(country_code.lower()), body=query)
    return res

urn = Urn(
    namespace='app-qa.daily-check.v1',
    owner='app_qa'
)

def get_es_search_result(query):
    common_config = {
        "database": "aso_sov"
    }
    con_es= es.connection(urn, common_config)
    res = con_es.search(index="aso-kpi-sov_search_ads_keyword_fact_v1_*", body=query)
    return res

def get_device_count():
    today = datetime.datetime.today()
    date_delta = z.input("previously_days")
    date_start = today + datetime.timedelta(0-int(date_delta)-1)
    print date_start.date()
    print today.date()

    print "%table {}\t{}\t{}\t ".format( "db_date", "device_code_db" , "all_count_db")
    query={"query":{"bool":{"must":[{"range":{"date":{"gte":date_start.date(),"lte":today.date()}}}]}},"aggs":{"aggregate_keyword":{"terms":{"field":"date","order":{"_term":"desc"},"size":2000},"aggs":{"device":{"terms":{"field":"device_code","order":{"_term":"desc"},"size":2000}}}}},"size":0}
    result={}
    data_list=[]
    db_count = get_es_search_result(query)
    range_length = len(db_count["aggregations"]["aggregate_keyword"]["buckets"])
    for i in range(0,range_length):
        db_date=db_count["aggregations"]["aggregate_keyword"]["buckets"][i]["key_as_string"]
        for x in range (0,3):
            device_code_db = db_count["aggregations"]["aggregate_keyword"]["buckets"][i]["device"]["buckets"][x]["key"]
            all_count_db = db_count["aggregations"]["aggregate_keyword"]["buckets"][i]["device"]["buckets"][x]["doc_count"]
            print "{}\t{}\t{}\t".format(db_date, device_code_db, all_count_db)


get_device_count()

# %%
from datetime import datetime
import datetime
from elasticsearch import Elasticsearch
import json
from aaintdatapipeline.application.app_qa.data_validation_v1.pysparktest import PySparkTest
import unittest
import random
from aaintdatapipeline.application.app_qa.data_validation_v1.utils import (get_aso_keyword_sov_raw_df_root,
                                                                           get_aso_keyword_sov_unified_df_root,
                                                                            )
from aaintdatapipeline.core.loader import es
from aaintdatapipeline.core.urn import Urn
from pyspark.sql.types import *


urn = Urn(
    namespace='app-qa.daily-check.v1',
    owner='app_qa'
)

def get_es_search_result(country, query):
    common_config = {
        "database": "aso_sov"
    }
    con_es= es.connection(urn, common_config)
    res = con_es.search(index="aso-kpi-sov_search_ads_keyword_fact_v1_daily_{}*".format(country.lower()), body=query)
    return res

def get_device_count():
    today = datetime.datetime.today()
    date_delta = z.input("previously_days")
    date_start = today + datetime.timedelta(0-int(date_delta)-1)
    print date_start.date()
    print today.date()

    query={"query":{"bool":{"must":[{"range":{"date": {"gte":date_start.date(),"lte":today.date()}}},{"match":{"device_code":"ios-tablet"}}]}},"aggs":{"aggregate_keyword":{"terms":{"field":"date","order":{"_term":"desc"},"size":2000},"aggs":{"device":{"terms":{"field":"device_code","order":{"_term":"desc"},"size":2000}}}}},"size":1}
    result={}
    data_list=[]
    country_code_list = [
        "US",
        "GB",
        "JP",
        "KR",
        "DE",
        "CA",
        "MX",
        "AU",
        "IN",
        "ID",
        "FR",
        "IT",
        "ES",
        "TH",
        "TW",
        "HK",
        "SE",
        "DK",
        "NO",
        "FI",
        "NZ"]
        
    print "%table {}\t{}\t{}\t ".format( "db_date", "country" , "all_count_db")
    for country in country_code_list:
        db_count = get_es_search_result(country , query)
        range_length = len(db_count["aggregations"]["aggregate_keyword"]["buckets"])
        for i in range(0,range_length):
            db_date=db_count["aggregations"]["aggregate_keyword"]["buckets"][i]["key_as_string"]
            all_count_db = db_count["aggregations"]["aggregate_keyword"]["buckets"][i]["device"]["buckets"][0]["doc_count"]
            print "{}\t{}\t{}\t".format(db_date, country, all_count_db)


get_device_count()

# %%
from datetime import datetime
import datetime
from elasticsearch import Elasticsearch
import json
from aaintdatapipeline.application.app_qa.data_validation_v1.pysparktest import PySparkTest
import unittest
import random
from aaintdatapipeline.application.app_qa.data_validation_v1.utils import (get_aso_keyword_sov_raw_df_root,
                                                                           get_aso_keyword_sov_unified_df_root,
                                                                            )
from aaintdatapipeline.core.loader import es
from aaintdatapipeline.core.urn import Urn
from pyspark.sql.types import *


urn = Urn(
    namespace='app-qa.daily-check.v1',
    owner='app_qa'
)

def get_es_search_result(country, query):
    common_config = {
        "database": "aso_sov"
    }
    con_es= es.connection(urn, common_config)
    res = con_es.search(index="aso-kpi-sov_search_ads_keyword_fact_v1_daily_{}*".format(country.lower()), body=query)
    return res

def get_device_count():
    today = datetime.datetime.today()
    date_delta = z.input("previously_days")
    date_start = today + datetime.timedelta(0-int(date_delta)-1)
    print date_start.date()
    print today.date()

    query={"query":{"bool":{"must":[{"range":{"date": {"gte":date_start.date(),"lte":today.date()}}},{"match":{"device_code":"ios-phone"}}]}},"aggs":{"aggregate_keyword":{"terms":{"field":"date","order":{"_term":"desc"},"size":2000},"aggs":{"device":{"terms":{"field":"device_code","order":{"_term":"desc"},"size":2000}}}}},"size":1}
    result={}
    data_list=[]
    country_code_list = [
        "US",
        "GB",
        "JP",
        "KR",
        "DE",
        "CA",
        "MX",
        "AU",
        "IN",
        "ID",
        "FR",
        "IT",
        "ES",
        "TH",
        "TW",
        "HK",
        "SE",
        "DK",
        "NO",
        "FI",
        "NZ"]
        
    print "%table {}\t{}\t{}\t ".format( "db_date", "country" , "all_count_db")
    for country in country_code_list:
        db_count = get_es_search_result(country , query)
        range_length = len(db_count["aggregations"]["aggregate_keyword"]["buckets"])
        for i in range(0,range_length):
            db_date=db_count["aggregations"]["aggregate_keyword"]["buckets"][i]["key_as_string"]
            all_count_db = db_count["aggregations"]["aggregate_keyword"]["buckets"][i]["device"]["buckets"][0]["doc_count"]
            print "{}\t{}\t{}\t".format(db_date, country, all_count_db)


get_device_count()

# %%
from datetime import datetime
import datetime
from elasticsearch import Elasticsearch
import json
from aaintdatapipeline.application.app_qa.data_validation_v1.pysparktest import PySparkTest
import unittest
import random
from aaintdatapipeline.application.app_qa.data_validation_v1.utils import (get_aso_keyword_sov_raw_df_root,
                                                                           get_aso_keyword_sov_unified_df_root,
                                                                            )
from aaintdatapipeline.core.loader import es
from aaintdatapipeline.core.urn import Urn
from pyspark.sql.types import *


urn = Urn(
    namespace='app-qa.daily-check.v1',
    owner='app_qa'
)

def get_es_search_result(country, query):
    common_config = {
        "database": "aso_sov"
    }
    con_es= es.connection(urn, common_config)
    res = con_es.search(index="aso-kpi-sov_search_ads_keyword_fact_v1_daily_{}*".format(country.lower()), body=query)
    return res

def get_device_count():
    today = datetime.datetime.today()
    date_delta = z.input("previously_days")
    date_start = today + datetime.timedelta(0-int(date_delta)-1)
    print date_start.date()
    print today.date()

    query={"query":{"bool":{"must":[{"range":{"date": {"gte":date_start.date(),"lte":today.date()}}},{"match":{"device_code":"android-all"}}]}},"aggs":{"aggregate_keyword":{"terms":{"field":"date","order":{"_term":"desc"},"size":2000},"aggs":{"device":{"terms":{"field":"device_code","order":{"_term":"desc"},"size":2000}}}}},"size":1}
    result={}
    data_list=[]
    country_code_list = [
        "US",
        "GB",
        "JP",
        "KR",
        "DE",
        "CA",
        "BR",
        "MX",
        "RU",
        "AU",
        "IN",
        "ID",
        "FR",
        "IT",
        "ES",
        "TH",
        "TW",
        "HK",
        "TR",
        "SE",
        "DK",
        "NO",
        "FI",
        "NZ"]
        
    print "%table {}\t{}\t{}\t ".format( "db_date", "country" , "all_count_db")
    for country in country_code_list:
        db_count = get_es_search_result(country , query)
        range_length = len(db_count["aggregations"]["aggregate_keyword"]["buckets"])
        for i in range(0,range_length):
            db_date=db_count["aggregations"]["aggregate_keyword"]["buckets"][i]["key_as_string"]
            all_count_db = db_count["aggregations"]["aggregate_keyword"]["buckets"][i]["device"]["buckets"][0]["doc_count"]
            print "{}\t{}\t{}\t".format(db_date, country, all_count_db)


get_device_count()

# %%
# %%sh
# echo 'IOS daily Raw Data'
