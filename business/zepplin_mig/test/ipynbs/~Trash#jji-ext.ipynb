# %%
# %%sh
# aws s3 ls s3://b2c-prod-data-pipeline-unified-usage/unified/usage.basic-kpi.v1/fact/

# %%
# %%sh
# aws s3 ls s3://b2c-prod-data-pipeline-unified-usage/unified/usage.basic-kpi.v1/fact/granularity=daily/date=2015-12-27/

# %%
spark.read.parquet("s3://b2c-prod-data-pipeline-unified-usage/unified/usage.basic-kpi.v1/fact/granularity=daily/date=2015-12-27/").show()

# %%
df = spark.read.parquet("s3://b2c-prod-data-pipeline-unified-usage/unified/usage.basic-kpi.v1/fact/granularity=daily/date=2015-12-27/")
print df.count()

# %%
# %%sh
# aws s3 ls s3://aardvark-prod-pdx-mdm-to-int/basic_kpi/version=v3.0.0/range_type=DAY/date=2019-11-22/platform=2/

# %%
spark.read.parquet("s3://aardvark-prod-pdx-mdm-to-int/basic_kpi/version=v3.0.0/range_type=DAY/date=2019-11-22/platform=2/").show()

# %%
df = spark.read.parquet("s3://aardvark-prod-pdx-mdm-to-int/basic_kpi/version=v3.0.0/range_type=DAY/date=2019-11-22/platform=2/")
print df.count()

# %%
df = spark.read.parquet("s3://aardvark-prod-pdx-mdm-to-int/basic_kpi/version=v3.0.0/range_type=DAY/date=2019-11-22/platform=2/")
df.createOrReplaceTempView("table1")
spark.sql("SELECT * from table1 where country='CN' ").show()

# %%
df1 = spark.read.parquet("s3://aardvark-prod-pdx-mdm-to-int/basic_kpi/version=v3.0.0/range_type=DAY/date=2019-11-22/platform=2/")
print df1.columns
df2 = spark.read.parquet("s3://b2c-prod-data-pipeline-unified-usage/unified/usage.basic-kpi.v1/fact/granularity=daily/date=2015-12-27/")
print df2.columns

# %%
df1 = spark.read.parquet("s3://aardvark-prod-pdx-mdm-to-int/basic_kpi/version=v3.0.0/range_type=DAY/date=2019-11-22/platform=2/")
df1.select('country').distinct().show()

# %%
df = spark.read.parquet("s3://b2c-prod-data-pipeline-unified-usage/unified/usage.basic-kpi.v1/fact/granularity=daily/date=2015-12-27/")
df.orderBy(df.est_average_active_users.desc()).show(10)
