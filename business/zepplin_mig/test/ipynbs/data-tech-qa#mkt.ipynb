# %%
import psycopg2
import datetime
from conf.settings import CITUS_MKT_NAME, CITUS_MKT_ACCESS_ID, \
    CITUS_MKT_HOSTS, CITUS_MKT_SECRET_KEY, CITUS_MKT_HOSTS


citus_dsn = (
    "dbname='{db}' user='{user}' password='{password}' "
    "host='{host}' port='{port}'".format(
        db=CITUS_MKT_NAME,
        user=CITUS_MKT_ACCESS_ID,
        host=CITUS_MKT_HOSTS[0][0],
        password=CITUS_MKT_SECRET_KEY,
        port=CITUS_MKT_HOSTS[0][1]
    )
)

def query(dsn, sql):
    with psycopg2.connect(dsn) as conn:
        conn.autocommit = True
        with conn.cursor() as cur:
            cur.execute(sql)
            result = cur.fetchall()
            conn.commit()
    return result

# %%
import psycopg2
import datetime

today = datetime.datetime.today()
date_delta = z.input("max_days")
date_start = today + datetime.timedelta(0-int(date_delta)-1)

print "%table {}\t{}\t{}".format("table", "date", "count")

tables = ["market_creative_meta_dimension_v1"]
for table in tables:
    
    dbsql = "SELECT update_date,count(*) FROM market.{table} WHERE update_date between '{date_start}' AND '{today}' GROUP BY update_date ORDER BY update_date ASC".format(table=table, date_start=date_start, today=today)

    test_result = query(citus_dsn, dbsql)
    

    for result in test_result:
        date,count = result
        print "{}\t{}\t{}".format(table, date.strftime("%Y-%m-%d"), count)

# %%
import psycopg2
import datetime

today = datetime.datetime.today()
date_delta = z.input("max_days")
date_start = today + datetime.timedelta(0-int(date_delta)-1)

tables = [
    "market_creative_adapp_fact_v1",
    "market_adapp_pubapp_fact_v1",
    "market_adapp_fact_v1",
    "market_adapp_publisher_fact_v1",
    "market_pubapp_fact_v1",
]

print "%table {}\t{}\t{}\t{}\t{}".format("table", "date", "country_count", "device_count", "ad_platform_count")

for table in tables:
    
    sql = "SELECT date,count(DISTINCT(country_code)),count(DISTINCT(device_code)),count(DISTINCT(ad_platform_id)) FROM market.{table} WHERE date between '{date_start}' AND '{today}' GROUP BY date ORDER BY date ASC".format(table=table, date_start=date_start, today=today)

    test_result = query(citus_dsn, sql)

    for result in test_result:
        date,c_count,d_count,a_count = result
        print "{}\t{}\t{}\t{}\t{}".format(table, date.strftime("%Y-%m-%d"), c_count, d_count, a_count)

# %%
import psycopg2
import datetime

today = datetime.datetime.today()
date_delta = z.input("max_days")
date_start = today + datetime.timedelta(0-int(date_delta)-1)

tables = [
    "market_creative_adapp_seen_fact_v1",
    "market_adapp_pubapp_seen_fact_v1"
]

print "%table {}\t{}\t{}\t{}\t{}".format("table", "first_seen_date", "country_count", "device_count", "ad_platform_count")

for table in tables:
    
    sql = "SELECT first_seen_date,count(DISTINCT(country_code)),count(DISTINCT(device_code)),count(DISTINCT(ad_platform_id)) FROM market.{table} WHERE first_seen_date between '{date_start}' AND '{today}' GROUP BY first_seen_date ORDER BY first_seen_date ASC".format(table=table, date_start=date_start, today=today)

    test_result = query(citus_dsn, sql)

    for result in test_result:
        date,c_count,d_count,a_count = result
        print "{}\t{}\t{}\t{}\t{}".format(table, date.strftime("%Y-%m-%d"), c_count, d_count, a_count)

# %%
import psycopg2
import datetime

today = datetime.datetime.today()
date_delta = z.input("max_days")
date_start = today + datetime.timedelta(0-int(date_delta)-1)

tables = [
    "market_creative_adapp_seen_fact_v1",
    "market_adapp_pubapp_seen_fact_v1"
]

print "%table {}\t{}\t{}\t{}\t{}".format("table", "last_seen_date", "country_count", "device_count", "ad_platform_count")

for table in tables:
    
    sql = "SELECT last_seen_date,count(DISTINCT(country_code)),count(DISTINCT(device_code)),count(DISTINCT(ad_platform_id)) FROM market.{table} WHERE first_seen_date between '{date_start}' AND '{today}' GROUP BY last_seen_date ORDER BY last_seen_date ASC".format(table=table, date_start=date_start, today=today)

    test_result = query(citus_dsn, sql)

    for result in test_result:
        date,c_count,d_count,a_count = result
        print "{}\t{}\t{}\t{}\t{}".format(table, date.strftime("%Y-%m-%d"), c_count, d_count, a_count)

# %%
import psycopg2
import datetime

today = datetime.datetime.today()
date_delta = z.input("max_days")
date_start = today + datetime.timedelta(0-int(date_delta)-1)

tables = [
    "market_creative_log_fact_v1",
]

print "%table {}\t{}\t{}\t{}\t{}".format("table", "date", "country_count", "device_count", "ad_platform_count")

for table in tables:
    
    sql = "SELECT date,count(DISTINCT(country_code)),count(DISTINCT(device_code)),count(DISTINCT(ad_platform_id)) FROM market.{table} WHERE date between '{date_start}' AND '{today}' GROUP BY date ORDER BY date ASC".format(table=table, date_start=date_start, today=today)

    test_result = query(citus_dsn, sql)

    for result in test_result:
        date,c_count,d_count,a_count = result
        print "{}\t{}\t{}\t{}\t{}".format(table, date.strftime("%Y-%m-%d"), c_count, d_count, a_count)

# %%
import psycopg2
import datetime

today = datetime.datetime.today()
date_delta = z.input("max_days")
date_start = today + datetime.timedelta(0-int(date_delta)-1)

tables = [
    "market_creative_cat_rank_fact_v1",
    "market_adapp_cat_rank_fact_v1",
    "market_pubapp_cat_rank_fact_v1",
]

print "%table {}\t{}\t{}\t{}\t{}".format("table", "date", "country_count", "device_count", "category_id")

for table in tables:
    
    sql = "SELECT date,count(DISTINCT(country_code)),count(DISTINCT(device_code)),count(DISTINCT(category_id)) FROM market.{table} WHERE date between '{date_start}' AND '{today}' GROUP BY date ORDER BY date ASC".format(table=table, date_start=date_start, today=today)

    test_result = query(citus_dsn, sql)

    for result in test_result:
        date,c_count,d_count,a_count = result
        print "{}\t{}\t{}\t{}\t{}".format(table, date.strftime("%Y-%m-%d"), c_count, d_count, a_count)

# %%
import psycopg2
import datetime

today = datetime.datetime.today()
date_delta = z.input("max_days")
date_start = today + datetime.timedelta(0-int(date_delta)-1)

tables = [
    "market_creative_log_fact_v1",
]

print "%table {}\t{}\t{}\t{}".format("table", "date", "platform_id", "count")

for table in tables:
    
    sql = "SELECT date,ad_platform_id,count(ad_platform_id) FROM market.{table} WHERE date between '{date_start}' AND '{today}' GROUP BY date,ad_platform_id ORDER BY date ASC".format(table=table, date_start=date_start, today=today)

    test_result = query(citus_dsn, sql)

    for result in test_result:
        date,country_code,count = result
        print "{}\t{}\t{}\t{}".format(table, date.strftime("%Y-%m-%d"), country_code, count)

# %%
# %%sh
#
# aws s3 ls s3://b2c-prod-data-pipeline-unified-market/unified/app-tech.market.creative-id-mapping.v1/dimension/_partition=_default_partition/

# %%
# %%sh
# PGPASSWORD='rn*Wh%osCl2C' psql -h internal-aa-citus-mkt-elb-1511434527.us-east-1.elb.amazonaws.com  -U citus_mkt_qa -d aa_mkt_db -p 7432 << EOF
#
# -- SELECT ad_platform_id, count(ad_platform_id) FROM market.market_creative_log_fact_v1 where date='2020-04-29' AND ad_platform_id in (328, 101000, 311000) GROUP BY ad_platform_id;
#
# -- SELECT * FROM market.market_creative_log_fact_v1 where date='2020-10-02' limit 2;
# SELECT * FROM market.market_creative_log_fact_v1 where date='2020-10-03' limit 2;
#
# -- SELECT * FROM market.market_creative_adapp_seen_fact_v1 where last_seen_date='2020-10-02' limit 2;
# SELECT * FROM market.market_creative_adapp_seen_fact_v1 where last_seen_date='2020-10-03' limit 2;
#
# SELECT * FROM market.market_creative_map_dimension_v1 WHERE update_date ='2020-10-03' limit 1;
# SELECT * FROM market.market_campaign_map_dimension_v1 WHERE update_date ='2020-10-03' limit 1;
# SELECT * FROM market.market_creative_meta_dimension_v1 WHERE update_date ='2020-10-03' limit 1;
#
#
# EOF

# %%
# spark.read.parquet("s3://prod.appannie.mktint.data/market_log_fact/granularity=DAY/date=2020-04-29/country_code=US/").filter("network_id=101000").show(1)

spark.read.parquet("s3://b2c-prod-data-pipeline-unified-market/unified/market.creative-log.v2/fact/date=2020-04-29/device_code=ios-tablet/").filter("ad_platform_id=101000").show(5)
spark.read.parquet("s3://b2c-prod-data-pipeline-unified-market/unified/market.creative-log.v2/fact/date=2020-04-29/device_code=ios-tablet/").filter("ad_platform_id!=101000").show(5)

print spark.read.parquet("s3://b2c-prod-data-pipeline-unified-market/unified/market.creative-log.v2/fact/date=2020-04-29/device_code=ios-tablet/").count()
print spark.read.parquet("s3://b2c-prod-data-pipeline-unified-market/unified/market.creative-log.v2/fact/date=2020-04-29/device_code=ios-tablet/").filter("_identifier='120200430040347398'").count()
print spark.read.parquet("s3://b2c-prod-data-pipeline-unified-market/unified/market.creative-log.v2/fact/date=2020-04-29/device_code=ios-tablet/").filter("_identifier='120200501020920528'").count()


#print spark.read.parquet("s3://b2c-prod-data-pipeline-unified-market/unified/market.creative-log.v2/fact/date=2020-04-27/device_code=ios-tablet/").groupBy("_identifier").count().show()
#print spark.read.parquet("s3://b2c-prod-data-pipeline-unified-market/unified/market.creative-log.v2/fact/date=2020-04-28/device_code=ios-tablet/").groupBy("_identifier").count().show()
#print spark.read.parquet("s3://b2c-prod-data-pipeline-unified-market/unified/market.creative-log.v2/fact/date=2020-04-29/device_code=ios-tablet/").groupBy("_identifier").count().show()
#print spark.read.parquet("s3://b2c-prod-data-pipeline-unified-market/unified/market.creative-log.v2/fact/date=2020-04-30/device_code=ios-tablet/").groupBy("_identifier").count().show()

# %%
# %%sh
#
# # aws s3 ls s3://prod.appannie.mktint.data/market_log_fact/granularity=DAY/date=2020-04-29/country_code=US/
# aws s3 ls s3://b2c-prod-data-pipeline-unified-market/unified/market.creative-log.v2/fact/date=2020-04-29/device_code=ios-tablet/

# %%
# Copyright (c) 2018 App Annie Inc. All rights reserved.

"""
DB Check modules
"""

import datetime
import unittest

from aadatapipelinecore.core.monitoring.pipeline_monitor import running, fail, task_success
from aadatapipelinecore.core.urn import Urn
from aadatapipelinecore.core.utils.identifier import package_id
from aadatapipelinecore.core.utils.spark import canned_spark, stop

from applications.db_check_v1.cases.store.genre_est_v1.test_game_iq_market_size_full_restatement import \
    TestGameIQMarketSizeFullRestatement
from applications.db_check_v1.cases.advanced_review.test_advainced_review import TestAdvancedReview
from applications.db_check_v1.cases.usage.genre_cross_v1.test_game_iq_cross_genre import TestGameIQCrossGenre
from applications.db_check_v1.cases.advanced_review.test_topic_join_review import TestTopicJoinReview
from applications.db_check_v1.cases.aso.test_aso import TestASO, TestASOSOVDataDaily, TestASOMetrics
from applications.db_check_v1.cases.market.test_market import TestMarketDimensionDaily, \
    TestMarketLogsFactAndSeenDaily, TestMarketMonthlyCheck, TestMarketWeeklyCheck
from applications.db_check_v1.cases.mobile_web.test_mobile_web import TestMobileWebDaily, \
    TestMobileWebWeekly, \
    TestMobileWebMonthly, TestMobileWebRetention, TestMobilWebDomainMeta
from applications.db_check_v1.cases.sdk.test_sdk import TestSDKDaily, TestSDKWeekly, TestSDKMonthly
from applications.db_check_v1.cases.store.app_rank_v1.test_app_rank_v1 import TestAppStoreRankDaily
from applications.db_check_v1.cases.store.app_rank_v1.test_app_store_rank import TestAppStoreRank
from applications.db_check_v1.cases.store.download_attribution.test_download_attribution import \
    TestDownloadAttribution
from applications.db_check_v1.cases.store.market_size_v1.test_market_size_v1 import TestMarketSizeWeekly
from applications.db_check_v1.cases.usage.test_city_level import TestCityLevelWeekly, TestCityLevelMonthly
from applications.db_check_v1.common.html_report_test_runner import HTMLTestRunner
from applications.db_check_v1.common.utils import send_db_check_email


def send_message():
    log_file = "/tmp/db_check.log"
    with open(log_file, "w") as html_file:
        suite = unittest.TestSuite()
        suite.addTests(unittest.TestLoader().loadTestsFromTestCase(TestMarketDimensionDaily))
        suite.addTests(unittest.TestLoader().loadTestsFromTestCase(TestMarketLogsFactAndSeenDaily))
        suite.addTests(unittest.TestLoader().loadTestsFromTestCase(TestMarketWeeklyCheck))
        suite.addTests(unittest.TestLoader().loadTestsFromTestCase(TestMarketMonthlyCheck))
        suite.addTests(unittest.TestLoader().loadTestsFromTestCase(TestGameIQMarketSizeFullRestatement))
        # runner = unittest.TextTestRunner(file, verbosity=2, buffer=True)

        runner = HTMLTestRunner(
            stream=html_file,
            title='DB Test Report',
            description='This db_check the report output by Tech Team.'
        )

        failed_count = 0
        result_list = runner.run(suite).result
        for result in result_list:
            if result[0] == 1 or result[0] == 2:
                failed_count += 1

    with open(log_file, 'r') as html_file:
        today = datetime.date.today()
        str_today = today.strftime("%Y-%m-%d")

        title = "Data Refresh Check Report - " + str_today + " - "
        if failed_count == 0:
            title += "Passed"
        else:
            title += "Failed"
        send_db_check_email(title, html_file.read())


send_message()

# %%
from bdce.common.utils import update_application_code
update_application_code(
    spark, role="BDP-PROD-APP-INT-QA", application_name="aa-int-qa-db-check"
)
spark.sparkContext.addPyFile("/tmp/zeppelin_application_code/libs/python/dependencies.zip")
